# %% [markdown]
# <a href="https://colab.research.google.com/github/fambargh/projectmastery/blob/master/segbs4_differepoch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install -U git+https://github.com/albu/albumentations --no-cache-dir
# Out:
# Collecting git+https://github.com/albu/albumentations
#   Cloning https://github.com/albu/albumentations to /tmp/pip-req-build-3mgsj32z
#   Running command git clone -q https://github.com/albu/albumentations /tmp/pip-req-build-3mgsj32z
# Requirement already satisfied, skipping upgrade: numpy>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (1.17.4)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (1.3.3)
# Requirement already satisfied, skipping upgrade: imgaug<0.2.7,>=0.2.5 in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (0.2.6)
# Requirement already satisfied, skipping upgrade: PyYAML in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (3.13)
# Requirement already satisfied, skipping upgrade: opencv-python>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (4.1.2.30)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (1.12.0)
# Requirement already satisfied, skipping upgrade: scikit-image>=0.11.0 in /usr/local/lib/python3.6/dist-packages (from imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (0.15.0)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (3.1.2)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (4.3.0)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (1.1.1)
# Requirement already satisfied, skipping upgrade: imageio>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.4.1)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.4)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (1.1.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (0.10.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.4.5)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.6.1)
# Requirement already satisfied, skipping upgrade: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=4.3.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (0.46)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (4.4.1)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from kiwisolver>=1.0.1->matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (42.0.2)
# Building wheels for collected packages: albumentations
#   Building wheel for albumentations (setup.py) ... done
#   Created wheel for albumentations: filename=albumentations-0.4.4-cp36-none-any.whl size=61973 sha256=4482b0394ba0c5f3643e9cb3782138671417a6659c6eaf2df17563f83dea36ee
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s3ib07rb/wheels/45/8b/e4/2837bbcf517d00732b8e394f8646f22b8723ac00993230188b
# Successfully built albumentations
# Installing collected packages: albumentations
#   Found existing installation: albumentations 0.4.4
#     Uninstalling albumentations-0.4.4:
#       Successfully uninstalled albumentations-0.4.4
# Successfully installed albumentations-0.4.4

# %%
# Install required libs
# !pip install -U --pre segmentation-models --user
# Out:
# Collecting segmentation-models
#   Downloading https://files.pythonhosted.org/packages/70/14/090ea95a4f69c453731d9df3feff0a08e0dea0e8dff932dc4839ec4dab5c/segmentation_models-1.0.0-py3-none-any.whl
# Collecting efficientnet==1.0.0
#   Downloading https://files.pythonhosted.org/packages/97/82/f3ae07316f0461417dc54affab6e86ab188a5a22f33176d35271628b96e0/efficientnet-1.0.0-py3-none-any.whl
# Collecting image-classifiers==1.0.0
#   Downloading https://files.pythonhosted.org/packages/81/98/6f84720e299a4942ab80df5f76ab97b7828b24d1de5e9b2cbbe6073228b7/image_classifiers-1.0.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from segmentation-models) (1.0.8)
# Requirement already satisfied, skipping upgrade: scikit-image in /usr/local/lib/python3.6/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.15.0)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (2.8.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.17.4)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1.2)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (4.3.0)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.1.1)
# Requirement already satisfied, skipping upgrade: imageio>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.4.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.3.3)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.4)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.12.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.6.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.4.5)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (1.1.0)
# Requirement already satisfied, skipping upgrade: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=4.3.0->scikit-image->efficientnet==1.0.0->segmentation-models) (0.46)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image->efficientnet==1.0.0->segmentation-models) (4.4.1)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from kiwisolver>=1.0.1->matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (42.0.2)
# Installing collected packages: efficientnet, image-classifiers, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 segmentation-models-1.0.0

# %%
from zipfile import ZipFile
filename = "total.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
from zipfile import ZipFile
filename = "annotate_cup3.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
import os
import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
x_train_dir = '/content/image_train/'
y_train_dir = '/content/annotation_cup_train/'

x_valid_dir = '/content/image_valid/'
y_valid_dir = '/content/annotation_cup_valid'

x_test_dir = '/content/image_test/'
y_test_dir = '/content/annotation_cup_test/'

# %%
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x
    

# classes for data loading and preprocessing
class Dataset:
    """ Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    CLASSES = ['bg', 'oc','nolabeled']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        self.ids = os.listdir(images_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id) for image_id in self.ids]
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)
        
        # extract certain classes from mask (e.g. oc)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # add background if mask is not binary
        if mask.shape[-1] != 1:
            background = 1 - mask.sum(axis=-1, keepdims=True)
            mask = np.concatenate((mask, background), axis=-1)
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)
    
    
class Dataloder(keras.utils.Sequence):
    """Load data from dataset and form batches
    
    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integet number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """
    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

        self.on_epoch_end()

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        # transpose list of lists
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        return batch
    
    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# Lets look at data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['bg','oc','nolabeled'])

image, mask = dataset[5] # get some sample
visualize(
    image=image, 
    bg_mask=mask[..., 0].squeeze(),
    OC_mask=mask[..., 1].squeeze(),
    no_labeled_mask=mask[..., 2].squeeze(),
    background_mask=mask[..., 3].squeeze(),
)

# %%
import albumentations as A

# %%
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# define heavy augmentations
def get_training_augmentation():
    train_transform = [

        A.HorizontalFlip(p=0.5),

        A.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, shift_limit=0.1, p=1, border_mode=0),

        A.PadIfNeeded(min_height=128, min_width=128, always_apply=True, border_mode=0),
        A.RandomCrop(height=128, width=128, always_apply=True),

        A.IAAAdditiveGaussianNoise(p=0.2),
        A.IAAPerspective(p=0.5),

        A.OneOf(
            [
                A.CLAHE(p=1),
                A.RandomBrightness(p=1),
                A.RandomGamma(p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.IAASharpen(p=1),
                A.Blur(blur_limit=3, p=1),
                A.MotionBlur(blur_limit=3, p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.RandomContrast(p=1),
                A.HueSaturationValue(p=1),
            ],
            p=0.9,
        ),
        A.Lambda(mask=round_clip_0_1)
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 128"""
    test_transform = [
        A.PadIfNeeded(128, 128)
    ]
    return A.Compose(test_transform)

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

# %%
# Lets look at augmented data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['bg', 'oc','nolabeled'], augmentation=get_training_augmentation())

image, mask = dataset[12] # get some sample
visualize(
    image=image, 
    bg_mask=mask[..., 0].squeeze(),
    OC_mask=mask[..., 1].squeeze(),
    no_labeled_mask=mask[..., 2].squeeze(),
    background_mask=mask[..., 3].squeeze(),
)
# Out:
# /usr/local/lib/python3.6/dist-packages/albumentations/augmentations/transforms.py:2910: UserWarning: Using lambda is incompatible with multiprocessing. Consider using regular functions or partial().
#   "Using lambda is incompatible with multiprocessing. "

# %%
import segmentation_models as sm
# Out:
# Segmentation Models: using `keras` framework.

# %%
BACKBONE = 'seresnet50'
BATCH_SIZE = 4
CLASSES = ['oc']
#LR = 0.01
#EPOCHS = 2
preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
assert train_dataloader[0][0].shape == (BATCH_SIZE, 128, 128, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 128, 128, n_classes)

# define callbacks for learning rate scheduling and best checkpoints saving
callbacks = [
    keras.callbacks.ModelCheckpoint('./best_model.h5', save_weights_only=True, save_best_only=True, mode='min'),
    keras.callbacks.ReduceLROnPlateau(),
]
# Out:
# /usr/local/lib/python3.6/dist-packages/albumentations/augmentations/transforms.py:2910: UserWarning: Using lambda is incompatible with multiprocessing. Consider using regular functions or partial().
#   "Using lambda is incompatible with multiprocessing. "

# %%
# study of eppoch number on metrics for segmentation problem
from keras.optimizers import SGD
from matplotlib import pyplot


# fit a model and plot learning curve
def fit_model(train_data, validimage,EPOCHS):
  # define network parameters
  n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
  activation = 'sigmoid' if n_classes == 1 else 'softmax'
  # define model
  model = sm.Unet(BACKBONE, classes=n_classes, activation=activation)
  opt = SGD()
  dice_loss = sm.losses.DiceLoss()
  focal_loss = sm.losses.BinaryFocalLoss() 
  total_loss = dice_loss + (1 * focal_loss)
  metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]
  model.compile(opt, total_loss, metrics)
  # fit model
  history = model.fit_generator(train_dataloader, 
                                steps_per_epoch=len(train_data), 
                                epochs=EPOCHS, 
                                #callbacks=callbacks, 
                                validation_data=validimage, 
                                validation_steps=len(validimage),
                                )
  # plot learning curves
  pyplot.plot(history.history['f1-score'], label='train')
  pyplot.plot(history.history['val_f1-score'], label='test')
  pyplot.title('f1_score_for_BS4_for_epochnum.='+str(EPOCHS), pad=-50)
  plt.ylabel('f1_score')
  plt.legend(['Train', 'Test'], loc='upper left')

# create learning curves for different epoch numbers
EPOCHS = [10,20,30,40,60,80,100]
for i in range(len(EPOCHS)):
  plt.figure(figsize=(30, 25))
  # determine the plot number
  plot_no = 420 + (i+1)
  pyplot.subplot(plot_no)
  # fit model and plot learning curves for an epoch number
  fit_model(train_dataloader, valid_dataloader, EPOCHS[i])
# show learning curves
pyplot.show()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/10
# 45/45 [==============================] - 27s 599ms/step - loss: 1.2173 - iou_score: 0.2917 - f1-score: 0.4261 - val_loss: 1.1899 - val_iou_score: 0.3292 - val_f1-score: 0.4411
# Epoch 2/10
# 45/45 [==============================] - 10s 221ms/step - loss: 0.8658 - iou_score: 0.4303 - f1-score: 0.5814 - val_loss: 0.8015 - val_iou_score: 0.4214 - val_f1-score: 0.5281
# Epoch 3/10
# 45/45 [==============================] - 10s 219ms/step - loss: 0.7241 - iou_score: 0.4868 - f1-score: 0.6335 - val_loss: 0.9010 - val_iou_score: 0.3825 - val_f1-score: 0.4990
# Epoch 4/10
# 45/45 [==============================] - 10s 221ms/step - loss: 0.6514 - iou_score: 0.5469 - f1-score: 0.6868 - val_loss: 0.6966 - val_iou_score: 0.4445 - val_f1-score: 0.5498
# Epoch 5/10
# 45/45 [==============================] - 10s 221ms/step - loss: 0.6267 - iou_score: 0.5652 - f1-score: 0.7000 - val_loss: 0.7777 - val_iou_score: 0.4153 - val_f1-score: 0.5241
# Epoch 6/10
# 45/45 [==============================] - 10s 220ms/step - loss: 0.5799 - iou_score: 0.5706 - f1-score: 0.7030 - val_loss: 0.5889 - val_iou_score: 0.4926 - val_f1-score: 0.5737
# Epoch 7/10
# 45/45 [==============================] - 10s 221ms/step - loss: 0.5510 - iou_score: 0.5829 - f1-score: 0.7192 - val_loss: 0.5409 - val_iou_score: 0.5183 - val_f1-score: 0.6005
# Epoch 8/10
# 45/45 [==============================] - 10s 220ms/step - loss: 0.5175 - iou_score: 0.6092 - f1-score: 0.7385 - val_loss: 0.4918 - val_iou_score: 0.5402 - val_f1-score: 0.6397
# Epoch 9/10
# 45/45 [==============================] - 10s 222ms/step - loss: 0.5013 - iou_score: 0.6049 - f1-score: 0.7396 - val_loss: 0.5985 - val_iou_score: 0.5089 - val_f1-score: 0.6219
# Epoch 10/10
# 45/45 [==============================] - 10s 222ms/step - loss: 0.4818 - iou_score: 0.6187 - f1-score: 0.7470 - val_loss: 0.5556 - val_iou_score: 0.5030 - val_f1-score: 0.5898
# Epoch 1/20
# 45/45 [==============================] - 25s 556ms/step - loss: 1.2437 - iou_score: 0.2063 - f1-score: 0.3210 - val_loss: 1.0597 - val_iou_score: 0.3276 - val_f1-score: 0.4402
# Epoch 2/20
# 45/45 [==============================] - 10s 222ms/step - loss: 0.9093 - iou_score: 0.3913 - f1-score: 0.5389 - val_loss: 0.9856 - val_iou_score: 0.3438 - val_f1-score: 0.4539
# Epoch 3/20
# 45/45 [==============================] - 10s 223ms/step - loss: 0.8017 - iou_score: 0.4491 - f1-score: 0.6000 - val_loss: 0.7020 - val_iou_score: 0.4613 - val_f1-score: 0.5727
# Epoch 4/20
# 45/45 [==============================] - 10s 222ms/step - loss: 0.7139 - iou_score: 0.4984 - f1-score: 0.6397 - val_loss: 0.6449 - val_iou_score: 0.4576 - val_f1-score: 0.5618
# Epoch 5/20
# 45/45 [==============================] - 10s 223ms/step - loss: 0.6320 - iou_score: 0.5340 - f1-score: 0.6731 - val_loss: 0.6062 - val_iou_score: 0.4805 - val_f1-score: 0.5796
# Epoch 6/20
# 45/45 [==============================] - 10s 223ms/step - loss: 0.5414 - iou_score: 0.5784 - f1-score: 0.7086 - val_loss: 0.5970 - val_iou_score: 0.4956 - val_f1-score: 0.5942
# Epoch 7/20
# 45/45 [==============================] - 10s 221ms/step - loss: 0.5974 - iou_score: 0.5605 - f1-score: 0.6992 - val_loss: 0.6367 - val_iou_score: 0.4434 - val_f1-score: 0.5193
# Epoch 8/20
# 45/45 [==============================] - 10s 222ms/step - loss: 0.5011 - iou_score: 0.6075 - f1-score: 0.7374 - val_loss: 0.5096 - val_iou_score: 0.5412 - val_f1-score: 0.6380
# Epoch 9/20
# 45/45 [==============================] - 10s 224ms/step - loss: 0.5232 - iou_score: 0.5946 - f1-score: 0.7291 - val_loss: 0.5765 - val_iou_score: 0.4937 - val_f1-score: 0.5775
# Epoch 10/20
# 45/45 [==============================] - 10s 222ms/step - loss: 0.5174 - iou_score: 0.6154 - f1-score: 0.7444 - val_loss: 0.5032 - val_iou_score: 0.5316 - val_f1-score: 0.6076
# Epoch 11/20
# 45/45 [==============================] - 10s 219ms/step - loss: 0.4987 - iou_score: 0.6081 - f1-score: 0.7369 - val_loss: 0.4892 - val_iou_score: 0.5705 - val_f1-score: 0.6801
# Epoch 12/20
# 45/45 [==============================] - 10s 222ms/step - loss: 0.4813 - iou_score: 0.6239 - f1-score: 0.7530 - val_loss: 0.4304 - val_iou_score: 0.5914 - val_f1-score: 0.6956
# Epoch 13/20
# 45/45 [==============================] - 10s 224ms/step - loss: 0.4781 - iou_score: 0.6395 - f1-score: 0.7662 - val_loss: 0.4257 - val_iou_score: 0.5886 - val_f1-score: 0.7075
# Epoch 14/20
# 45/45 [==============================] - 10s 221ms/step - loss: 0.5197 - iou_score: 0.6166 - f1-score: 0.7436 - val_loss: 0.3842 - val_iou_score: 0.6097 - val_f1-score: 0.7154
# Epoch 15/20
# 45/45 [==============================] - 10s 221ms/step - loss: 0.4412 - iou_score: 0.6508 - f1-score: 0.7726 - val_loss: 0.7351 - val_iou_score: 0.4292 - val_f1-score: 0.5351
# Epoch 16/20
# 45/45 [==============================] - 10s 221ms/step - loss: 0.4294 - iou_score: 0.6507 - f1-score: 0.7781 - val_loss: 0.3966 - val_iou_score: 0.6169 - val_f1-score: 0.7117
# Epoch 17/20
# 45/45 [==============================] - 10s 222ms/step - loss: 0.4545 - iou_score: 0.6402 - f1-score: 0.7676 - val_loss: 0.4175 - val_iou_score: 0.6236 - val_f1-score: 0.7227
# Epoch 18/20
# 45/45 [==============================] - 10s 221ms/step - loss: 0.3970 - iou_score: 0.6845 - f1-score: 0.8050 - val_loss: 0.6823 - val_iou_score: 0.4293 - val_f1-score: 0.5284
# Epoch 19/20
# 45/45 [==============================] - 10s 219ms/step - loss: 0.4256 - iou_score: 0.6526 - f1-score: 0.7794 - val_loss: 0.3664 - val_iou_score: 0.6332 - val_f1-score: 0.7312
# Epoch 20/20
# 45/45 [==============================] - 10s 222ms/step - loss: 0.3809 - iou_score: 0.6877 - f1-score: 0.8002 - val_loss: 0.4419 - val_iou_score: 0.5963 - val_f1-score: 0.7045
# Epoch 1/30
# 45/45 [==============================] - 28s 618ms/step - loss: 1.2835 - iou_score: 0.2520 - f1-score: 0.3852 - val_loss: 1.0478 - val_iou_score: 0.3360 - val_f1-score: 0.4525
# Epoch 2/30
# 45/45 [==============================] - 10s 226ms/step - loss: 0.8705 - iou_score: 0.4347 - f1-score: 0.5829 - val_loss: 0.7806 - val_iou_score: 0.4271 - val_f1-score: 0.5329
# Epoch 3/30
# 45/45 [==============================] - 10s 224ms/step - loss: 0.7266 - iou_score: 0.5078 - f1-score: 0.6553 - val_loss: 0.7136 - val_iou_score: 0.4445 - val_f1-score: 0.5591
# Epoch 4/30
# 45/45 [==============================] - 10s 223ms/step - loss: 0.6182 - iou_score: 0.5516 - f1-score: 0.6901 - val_loss: 0.5819 - val_iou_score: 0.5079 - val_f1-score: 0.6104
# Epoch 5/30
# 45/45 [==============================] - 10s 225ms/step - loss: 0.5493 - iou_score: 0.5785 - f1-score: 0.7178 - val_loss: 0.5556 - val_iou_score: 0.5165 - val_f1-score: 0.6006
# Epoch 6/30
# 45/45 [==============================] - 10s 224ms/step - loss: 0.5791 - iou_score: 0.5619 - f1-score: 0.7013 - val_loss: 0.5390 - val_iou_score: 0.5254 - val_f1-score: 0.6346
# Epoch 7/30
# 45/45 [==============================] - 10s 227ms/step - loss: 0.5390 - iou_score: 0.5875 - f1-score: 0.7245 - val_loss: 0.5077 - val_iou_score: 0.5385 - val_f1-score: 0.6386
# Epoch 8/30
# 45/45 [==============================] - 10s 224ms/step - loss: 0.4951 - iou_score: 0.6048 - f1-score: 0.7432 - val_loss: 0.5121 - val_iou_score: 0.5417 - val_f1-score: 0.6462
# Epoch 9/30
# 45/45 [==============================] - 10s 224ms/step - loss: 0.4554 - iou_score: 0.6296 - f1-score: 0.7601 - val_loss: 0.4591 - val_iou_score: 0.5716 - val_f1-score: 0.6651
# Epoch 10/30
# 45/45 [==============================] - 10s 226ms/step - loss: 0.4823 - iou_score: 0.6081 - f1-score: 0.7409 - val_loss: 0.7115 - val_iou_score: 0.4591 - val_f1-score: 0.5654
# Epoch 11/30
# 45/45 [==============================] - 10s 224ms/step - loss: 0.4643 - iou_score: 0.6191 - f1-score: 0.7438 - val_loss: 0.4894 - val_iou_score: 0.5557 - val_f1-score: 0.6498
# Epoch 12/30
# 45/45 [==============================] - 10s 223ms/step - loss: 0.4790 - iou_score: 0.6314 - f1-score: 0.7614 - val_loss: 0.4580 - val_iou_score: 0.5696 - val_f1-score: 0.6704
# Epoch 13/30
# 45/45 [==============================] - 10s 224ms/step - loss: 0.4025 - iou_score: 0.6599 - f1-score: 0.7869 - val_loss: 0.5234 - val_iou_score: 0.5578 - val_f1-score: 0.6654
# Epoch 14/30
# 45/45 [==============================] - 10s 224ms/step - loss: 0.4339 - iou_score: 0.6482 - f1-score: 0.7741 - val_loss: 0.4313 - val_iou_score: 0.5905 - val_f1-score: 0.6911
# Epoch 15/30
# 45/45 [==============================] - 10s 222ms/step - loss: 0.3774 - iou_score: 0.6893 - f1-score: 0.8066 - val_loss: 0.4080 - val_iou_score: 0.6004 - val_f1-score: 0.6960
# Epoch 16/30
# 45/45 [==============================] - 10s 225ms/step - loss: 0.4597 - iou_score: 0.6506 - f1-score: 0.7766 - val_loss: 0.3866 - val_iou_score: 0.6332 - val_f1-score: 0.7365
# Epoch 17/30
# 45/45 [==============================] - 10s 222ms/step - loss: 0.4459 - iou_score: 0.6409 - f1-score: 0.7672 - val_loss: 0.3638 - val_iou_score: 0.6365 - val_f1-score: 0.7407
# Epoch 18/30
# 45/45 [==============================] - 10s 224ms/step - loss: 0.3557 - iou_score: 0.6929 - f1-score: 0.8091 - val_loss: 0.3590 - val_iou_score: 0.6427 - val_f1-score: 0.7502
# Epoch 19/30
# 45/45 [==============================] - 10s 222ms/step - loss: 0.3637 - iou_score: 0.6994 - f1-score: 0.8148 - val_loss: 0.3880 - val_iou_score: 0.6306 - val_f1-score: 0.7352
# Epoch 20/30
# 45/45 [==============================] - 10s 223ms/step - loss: 0.3591 - iou_score: 0.6886 - f1-score: 0.8065 - val_loss: 0.3887 - val_iou_score: 0.6271 - val_f1-score: 0.7308
# Epoch 21/30
# 45/45 [==============================] - 10s 225ms/step - loss: 0.3630 - iou_score: 0.6867 - f1-score: 0.8071 - val_loss: 0.4230 - val_iou_score: 0.5987 - val_f1-score: 0.7048
# Epoch 22/30
# 45/45 [==============================] - 10s 222ms/step - loss: 0.3776 - iou_score: 0.7028 - f1-score: 0.8154 - val_loss: 0.3495 - val_iou_score: 0.6510 - val_f1-score: 0.7553
# Epoch 23/30
# 45/45 [==============================] - 10s 224ms/step - loss: 0.3334 - iou_score: 0.7223 - f1-score: 0.8328 - val_loss: 0.3735 - val_iou_score: 0.6529 - val_f1-score: 0.7544
# Epoch 24/30
# 45/45 [==============================] - 10s 224ms/step - loss: 0.3424 - iou_score: 0.7111 - f1-score: 0.8207 - val_loss: 0.3835 - val_iou_score: 0.6347 - val_f1-score: 0.7352
# Epoch 25/30
# 45/45 [==============================] - 10s 224ms/step - loss: 0.3476 - iou_score: 0.7065 - f1-score: 0.8207 - val_loss: 0.3316 - val_iou_score: 0.6768 - val_f1-score: 0.7737
# Epoch 26/30
# 45/45 [==============================] - 10s 225ms/step - loss: 0.3152 - iou_score: 0.7329 - f1-score: 0.8391 - val_loss: 0.3369 - val_iou_score: 0.6772 - val_f1-score: 0.7764
# Epoch 27/30
# 45/45 [==============================] - 10s 224ms/step - loss: 0.3290 - iou_score: 0.7126 - f1-score: 0.8250 - val_loss: 0.4158 - val_iou_score: 0.6418 - val_f1-score: 0.7506
# Epoch 28/30
# 45/45 [==============================] - 10s 222ms/step - loss: 0.3218 - iou_score: 0.7301 - f1-score: 0.8367 - val_loss: 0.3828 - val_iou_score: 0.6664 - val_f1-score: 0.7687
# Epoch 29/30
# 45/45 [==============================] - 10s 223ms/step - loss: 0.3148 - iou_score: 0.7166 - f1-score: 0.8267 - val_loss: 0.3318 - val_iou_score: 0.6617 - val_f1-score: 0.7647
# Epoch 30/30
# 45/45 [==============================] - 10s 222ms/step - loss: 0.2999 - iou_score: 0.7330 - f1-score: 0.8409 - val_loss: 0.3495 - val_iou_score: 0.6580 - val_f1-score: 0.7671
# Epoch 1/40
# 45/45 [==============================] - 31s 695ms/step - loss: 1.3786 - iou_score: 0.2661 - f1-score: 0.3983 - val_loss: 1.0982 - val_iou_score: 0.3505 - val_f1-score: 0.4589
# Epoch 2/40
# 45/45 [==============================] - 10s 226ms/step - loss: 0.8823 - iou_score: 0.4222 - f1-score: 0.5695 - val_loss: 0.9265 - val_iou_score: 0.3809 - val_f1-score: 0.5000
# Epoch 3/40
# 45/45 [==============================] - 10s 223ms/step - loss: 0.7656 - iou_score: 0.4995 - f1-score: 0.6423 - val_loss: 0.6834 - val_iou_score: 0.4787 - val_f1-score: 0.5947
# Epoch 4/40
# 45/45 [==============================] - 10s 224ms/step - loss: 0.7032 - iou_score: 0.5119 - f1-score: 0.6529 - val_loss: 0.6606 - val_iou_score: 0.4613 - val_f1-score: 0.5524
# Epoch 5/40
# 45/45 [==============================] - 10s 225ms/step - loss: 0.6728 - iou_score: 0.5176 - f1-score: 0.6617 - val_loss: 0.5713 - val_iou_score: 0.5193 - val_f1-score: 0.6148
# Epoch 6/40
# 45/45 [==============================] - 10s 223ms/step - loss: 0.5449 - iou_score: 0.5851 - f1-score: 0.7176 - val_loss: 0.6613 - val_iou_score: 0.4665 - val_f1-score: 0.5537
# Epoch 7/40
# 45/45 [==============================] - 10s 226ms/step - loss: 0.5444 - iou_score: 0.5849 - f1-score: 0.7181 - val_loss: 0.5182 - val_iou_score: 0.5465 - val_f1-score: 0.6428
# Epoch 8/40
# 45/45 [==============================] - 10s 227ms/step - loss: 0.5006 - iou_score: 0.5990 - f1-score: 0.7362 - val_loss: 0.5387 - val_iou_score: 0.5401 - val_f1-score: 0.6294
# Epoch 9/40
# 45/45 [==============================] - 10s 223ms/step - loss: 0.5072 - iou_score: 0.6100 - f1-score: 0.7445 - val_loss: 0.5021 - val_iou_score: 0.5433 - val_f1-score: 0.6345
# Epoch 10/40
# 45/45 [==============================] - 10s 225ms/step - loss: 0.5027 - iou_score: 0.6028 - f1-score: 0.7324 - val_loss: 0.4438 - val_iou_score: 0.6082 - val_f1-score: 0.7320
# Epoch 11/40
# 45/45 [==============================] - 10s 223ms/step - loss: 0.4656 - iou_score: 0.6335 - f1-score: 0.7649 - val_loss: 0.4257 - val_iou_score: 0.6027 - val_f1-score: 0.7162
# Epoch 12/40
# 45/45 [==============================] - 10s 222ms/step - loss: 0.4593 - iou_score: 0.6280 - f1-score: 0.7580 - val_loss: 0.4141 - val_iou_score: 0.6283 - val_f1-score: 0.7495
# Epoch 13/40
# 45/45 [==============================] - 10s 222ms/step - loss: 0.4641 - iou_score: 0.6447 - f1-score: 0.7694 - val_loss: 0.4802 - val_iou_score: 0.5513 - val_f1-score: 0.6348
# Epoch 14/40
# 45/45 [==============================] - 10s 223ms/step - loss: 0.4705 - iou_score: 0.6275 - f1-score: 0.7569 - val_loss: 0.3930 - val_iou_score: 0.6233 - val_f1-score: 0.7342
# Epoch 15/40
# 45/45 [==============================] - 10s 222ms/step - loss: 0.4136 - iou_score: 0.6595 - f1-score: 0.7827 - val_loss: 0.4410 - val_iou_score: 0.5829 - val_f1-score: 0.6807
# Epoch 16/40
# 45/45 [==============================] - 10s 225ms/step - loss: 0.3963 - iou_score: 0.6816 - f1-score: 0.8000 - val_loss: 0.4975 - val_iou_score: 0.5488 - val_f1-score: 0.6470
# Epoch 17/40
# 45/45 [==============================] - 10s 223ms/step - loss: 0.4009 - iou_score: 0.6665 - f1-score: 0.7897 - val_loss: 0.3862 - val_iou_score: 0.6210 - val_f1-score: 0.7274
# Epoch 18/40
# 45/45 [==============================] - 10s 224ms/step - loss: 0.4239 - iou_score: 0.6481 - f1-score: 0.7754 - val_loss: 0.3657 - val_iou_score: 0.6471 - val_f1-score: 0.7630
# Epoch 19/40
# 45/45 [==============================] - 10s 222ms/step - loss: 0.3900 - iou_score: 0.6707 - f1-score: 0.7895 - val_loss: 0.4966 - val_iou_score: 0.5899 - val_f1-score: 0.7061
# Epoch 20/40
# 45/45 [==============================] - 10s 224ms/step - loss: 0.4159 - iou_score: 0.6705 - f1-score: 0.7915 - val_loss: 0.3848 - val_iou_score: 0.6463 - val_f1-score: 0.7636
# Epoch 21/40
# 45/45 [==============================] - 10s 226ms/step - loss: 0.4011 - iou_score: 0.6723 - f1-score: 0.7933 - val_loss: 0.4637 - val_iou_score: 0.6045 - val_f1-score: 0.7221
# Epoch 22/40
# 45/45 [==============================] - 10s 224ms/step - loss: 0.3428 - iou_score: 0.7031 - f1-score: 0.8176 - val_loss: 0.3861 - val_iou_score: 0.6554 - val_f1-score: 0.7641
# Epoch 23/40
# 45/45 [==============================] - 10s 223ms/step - loss: 0.3610 - iou_score: 0.6987 - f1-score: 0.8131 - val_loss: 0.4487 - val_iou_score: 0.5623 - val_f1-score: 0.6615
# Epoch 24/40
# 45/45 [==============================] - 10s 224ms/step - loss: 0.3575 - iou_score: 0.6929 - f1-score: 0.8093 - val_loss: 0.3448 - val_iou_score: 0.6675 - val_f1-score: 0.7737
# Epoch 25/40
# 45/45 [==============================] - 10s 223ms/step - loss: 0.3450 - iou_score: 0.7029 - f1-score: 0.8166 - val_loss: 0.3581 - val_iou_score: 0.6600 - val_f1-score: 0.7602
# Epoch 26/40
# 45/45 [==============================] - 10s 223ms/step - loss: 0.3667 - iou_score: 0.6859 - f1-score: 0.8053 - val_loss: 0.3463 - val_iou_score: 0.6608 - val_f1-score: 0.7514
# Epoch 27/40
# 45/45 [==============================] - 10s 223ms/step - loss: 0.3101 - iou_score: 0.7316 - f1-score: 0.8382 - val_loss: 0.3235 - val_iou_score: 0.6842 - val_f1-score: 0.7891
# Epoch 28/40
# 45/45 [==============================] - 10s 222ms/step - loss: 0.3270 - iou_score: 0.7167 - f1-score: 0.8282 - val_loss: 0.3551 - val_iou_score: 0.6739 - val_f1-score: 0.7768
# Epoch 29/40
# 45/45 [==============================] - 10s 226ms/step - loss: 0.3070 - iou_score: 0.7346 - f1-score: 0.8409 - val_loss: 0.3664 - val_iou_score: 0.6608 - val_f1-score: 0.7585
# Epoch 30/40
# 45/45 [==============================] - 10s 223ms/step - loss: 0.3145 - iou_score: 0.7285 - f1-score: 0.8371 - val_loss: 0.3948 - val_iou_score: 0.6198 - val_f1-score: 0.7181
# Epoch 31/40
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2955 - iou_score: 0.7356 - f1-score: 0.8426 - val_loss: 0.4293 - val_iou_score: 0.5947 - val_f1-score: 0.7026
# Epoch 32/40
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2924 - iou_score: 0.7354 - f1-score: 0.8426 - val_loss: 0.3045 - val_iou_score: 0.6995 - val_f1-score: 0.7920
# Epoch 33/40
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2944 - iou_score: 0.7341 - f1-score: 0.8412 - val_loss: 0.3488 - val_iou_score: 0.6694 - val_f1-score: 0.7653
# Epoch 34/40
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2706 - iou_score: 0.7436 - f1-score: 0.8482 - val_loss: 0.3551 - val_iou_score: 0.6687 - val_f1-score: 0.7701
# Epoch 35/40
# 45/45 [==============================] - 10s 222ms/step - loss: 0.2983 - iou_score: 0.7422 - f1-score: 0.8469 - val_loss: 0.3431 - val_iou_score: 0.6739 - val_f1-score: 0.7726
# Epoch 36/40
# 45/45 [==============================] - 10s 224ms/step - loss: 0.3132 - iou_score: 0.7396 - f1-score: 0.8450 - val_loss: 0.2946 - val_iou_score: 0.6997 - val_f1-score: 0.7978
# Epoch 37/40
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2856 - iou_score: 0.7496 - f1-score: 0.8524 - val_loss: 0.3113 - val_iou_score: 0.6883 - val_f1-score: 0.7883
# Epoch 38/40
# 45/45 [==============================] - 10s 228ms/step - loss: 0.2793 - iou_score: 0.7370 - f1-score: 0.8410 - val_loss: 0.3050 - val_iou_score: 0.6875 - val_f1-score: 0.7871
# Epoch 39/40
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2792 - iou_score: 0.7424 - f1-score: 0.8478 - val_loss: 0.3136 - val_iou_score: 0.6777 - val_f1-score: 0.7833
# Epoch 40/40
# 45/45 [==============================] - 10s 223ms/step - loss: 0.3025 - iou_score: 0.7403 - f1-score: 0.8444 - val_loss: 0.2862 - val_iou_score: 0.7059 - val_f1-score: 0.8030
# Epoch 1/60
# 45/45 [==============================] - 33s 730ms/step - loss: 1.3665 - iou_score: 0.1381 - f1-score: 0.2326 - val_loss: 1.1462 - val_iou_score: 0.3087 - val_f1-score: 0.4285
# Epoch 2/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.9953 - iou_score: 0.3333 - f1-score: 0.4779 - val_loss: 0.9184 - val_iou_score: 0.3681 - val_f1-score: 0.4898
# Epoch 3/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.7605 - iou_score: 0.4865 - f1-score: 0.6345 - val_loss: 1.0285 - val_iou_score: 0.3637 - val_f1-score: 0.4901
# Epoch 4/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.6435 - iou_score: 0.5324 - f1-score: 0.6768 - val_loss: 0.7764 - val_iou_score: 0.4331 - val_f1-score: 0.5569
# Epoch 5/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.6541 - iou_score: 0.5181 - f1-score: 0.6661 - val_loss: 0.5514 - val_iou_score: 0.5389 - val_f1-score: 0.6219
# Epoch 6/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.5521 - iou_score: 0.5856 - f1-score: 0.7171 - val_loss: 0.5121 - val_iou_score: 0.5571 - val_f1-score: 0.6507
# Epoch 7/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.5268 - iou_score: 0.5874 - f1-score: 0.7228 - val_loss: 0.5195 - val_iou_score: 0.5336 - val_f1-score: 0.6213
# Epoch 8/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.5551 - iou_score: 0.5729 - f1-score: 0.7097 - val_loss: 0.4696 - val_iou_score: 0.5648 - val_f1-score: 0.6596
# Epoch 9/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.5344 - iou_score: 0.5895 - f1-score: 0.7265 - val_loss: 0.4745 - val_iou_score: 0.5525 - val_f1-score: 0.6526
# Epoch 10/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.5089 - iou_score: 0.6100 - f1-score: 0.7380 - val_loss: 0.5728 - val_iou_score: 0.5145 - val_f1-score: 0.6189
# Epoch 11/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.4791 - iou_score: 0.6270 - f1-score: 0.7591 - val_loss: 0.5012 - val_iou_score: 0.5677 - val_f1-score: 0.6760
# Epoch 12/60
# 45/45 [==============================] - 10s 225ms/step - loss: 0.4505 - iou_score: 0.6380 - f1-score: 0.7666 - val_loss: 0.4308 - val_iou_score: 0.5942 - val_f1-score: 0.7143
# Epoch 13/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.4387 - iou_score: 0.6710 - f1-score: 0.7932 - val_loss: 0.6751 - val_iou_score: 0.4488 - val_f1-score: 0.5631
# Epoch 14/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.5056 - iou_score: 0.6090 - f1-score: 0.7423 - val_loss: 0.6333 - val_iou_score: 0.4651 - val_f1-score: 0.5589
# Epoch 15/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.4129 - iou_score: 0.6683 - f1-score: 0.7900 - val_loss: 0.5372 - val_iou_score: 0.5358 - val_f1-score: 0.6346
# Epoch 16/60
# 45/45 [==============================] - 10s 225ms/step - loss: 0.4055 - iou_score: 0.6677 - f1-score: 0.7907 - val_loss: 0.3967 - val_iou_score: 0.6125 - val_f1-score: 0.7155
# Epoch 17/60
# 45/45 [==============================] - 10s 225ms/step - loss: 0.4181 - iou_score: 0.6706 - f1-score: 0.7930 - val_loss: 0.4422 - val_iou_score: 0.5882 - val_f1-score: 0.6868
# Epoch 18/60
# 45/45 [==============================] - 10s 223ms/step - loss: 0.3936 - iou_score: 0.6857 - f1-score: 0.8023 - val_loss: 0.3749 - val_iou_score: 0.6329 - val_f1-score: 0.7261
# Epoch 19/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.4084 - iou_score: 0.6621 - f1-score: 0.7822 - val_loss: 0.3860 - val_iou_score: 0.6347 - val_f1-score: 0.7347
# Epoch 20/60
# 45/45 [==============================] - 10s 225ms/step - loss: 0.3778 - iou_score: 0.6895 - f1-score: 0.8100 - val_loss: 0.3695 - val_iou_score: 0.6543 - val_f1-score: 0.7524
# Epoch 21/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.3811 - iou_score: 0.6874 - f1-score: 0.8074 - val_loss: 0.4182 - val_iou_score: 0.6309 - val_f1-score: 0.7451
# Epoch 22/60
# 45/45 [==============================] - 10s 225ms/step - loss: 0.3507 - iou_score: 0.6932 - f1-score: 0.8104 - val_loss: 0.3384 - val_iou_score: 0.6789 - val_f1-score: 0.7894
# Epoch 23/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.3670 - iou_score: 0.6915 - f1-score: 0.8078 - val_loss: 0.3376 - val_iou_score: 0.6671 - val_f1-score: 0.7727
# Epoch 24/60
# 45/45 [==============================] - 10s 225ms/step - loss: 0.3649 - iou_score: 0.6869 - f1-score: 0.8015 - val_loss: 0.3149 - val_iou_score: 0.6880 - val_f1-score: 0.7874
# Epoch 25/60
# 45/45 [==============================] - 10s 222ms/step - loss: 0.3514 - iou_score: 0.7009 - f1-score: 0.8157 - val_loss: 0.3364 - val_iou_score: 0.6624 - val_f1-score: 0.7593
# Epoch 26/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.3366 - iou_score: 0.7236 - f1-score: 0.8337 - val_loss: 0.4979 - val_iou_score: 0.5483 - val_f1-score: 0.6412
# Epoch 27/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.3519 - iou_score: 0.7157 - f1-score: 0.8257 - val_loss: 0.3234 - val_iou_score: 0.6870 - val_f1-score: 0.7802
# Epoch 28/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.3203 - iou_score: 0.7190 - f1-score: 0.8303 - val_loss: 0.3220 - val_iou_score: 0.6839 - val_f1-score: 0.7868
# Epoch 29/60
# 45/45 [==============================] - 10s 225ms/step - loss: 0.3434 - iou_score: 0.7136 - f1-score: 0.8258 - val_loss: 0.4066 - val_iou_score: 0.6533 - val_f1-score: 0.7594
# Epoch 30/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2834 - iou_score: 0.7510 - f1-score: 0.8538 - val_loss: 0.3696 - val_iou_score: 0.6566 - val_f1-score: 0.7588
# Epoch 31/60
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2939 - iou_score: 0.7295 - f1-score: 0.8371 - val_loss: 0.3245 - val_iou_score: 0.6876 - val_f1-score: 0.7799
# Epoch 32/60
# 45/45 [==============================] - 10s 227ms/step - loss: 0.2889 - iou_score: 0.7360 - f1-score: 0.8422 - val_loss: 0.3471 - val_iou_score: 0.6668 - val_f1-score: 0.7743
# Epoch 33/60
# 45/45 [==============================] - 10s 227ms/step - loss: 0.2914 - iou_score: 0.7380 - f1-score: 0.8433 - val_loss: 0.3077 - val_iou_score: 0.6932 - val_f1-score: 0.7942
# Epoch 34/60
# 45/45 [==============================] - 10s 228ms/step - loss: 0.3223 - iou_score: 0.7152 - f1-score: 0.8267 - val_loss: 0.3245 - val_iou_score: 0.6910 - val_f1-score: 0.8002
# Epoch 35/60
# 45/45 [==============================] - 10s 230ms/step - loss: 0.3044 - iou_score: 0.7292 - f1-score: 0.8390 - val_loss: 0.2962 - val_iou_score: 0.7088 - val_f1-score: 0.8114
# Epoch 36/60
# 45/45 [==============================] - 10s 229ms/step - loss: 0.2970 - iou_score: 0.7429 - f1-score: 0.8481 - val_loss: 0.3098 - val_iou_score: 0.6941 - val_f1-score: 0.7949
# Epoch 37/60
# 45/45 [==============================] - 10s 228ms/step - loss: 0.3111 - iou_score: 0.7261 - f1-score: 0.8352 - val_loss: 0.3169 - val_iou_score: 0.6909 - val_f1-score: 0.7984
# Epoch 38/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.3042 - iou_score: 0.7378 - f1-score: 0.8453 - val_loss: 0.3129 - val_iou_score: 0.6870 - val_f1-score: 0.7999
# Epoch 39/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2585 - iou_score: 0.7676 - f1-score: 0.8655 - val_loss: 0.3108 - val_iou_score: 0.6799 - val_f1-score: 0.7834
# Epoch 40/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2473 - iou_score: 0.7691 - f1-score: 0.8669 - val_loss: 0.3360 - val_iou_score: 0.6669 - val_f1-score: 0.7650
# Epoch 41/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2813 - iou_score: 0.7503 - f1-score: 0.8525 - val_loss: 0.3043 - val_iou_score: 0.6839 - val_f1-score: 0.7864
# Epoch 42/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2484 - iou_score: 0.7713 - f1-score: 0.8673 - val_loss: 0.3449 - val_iou_score: 0.6604 - val_f1-score: 0.7574
# Epoch 43/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2334 - iou_score: 0.7815 - f1-score: 0.8747 - val_loss: 0.4018 - val_iou_score: 0.6390 - val_f1-score: 0.7453
# Epoch 44/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2986 - iou_score: 0.7423 - f1-score: 0.8479 - val_loss: 0.3116 - val_iou_score: 0.6902 - val_f1-score: 0.7915
# Epoch 45/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2517 - iou_score: 0.7701 - f1-score: 0.8674 - val_loss: 0.3225 - val_iou_score: 0.7009 - val_f1-score: 0.7923
# Epoch 46/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2402 - iou_score: 0.7702 - f1-score: 0.8660 - val_loss: 0.3040 - val_iou_score: 0.6888 - val_f1-score: 0.7841
# Epoch 47/60
# 45/45 [==============================] - 10s 227ms/step - loss: 0.2394 - iou_score: 0.7749 - f1-score: 0.8706 - val_loss: 0.3131 - val_iou_score: 0.6886 - val_f1-score: 0.7981
# Epoch 48/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2554 - iou_score: 0.7681 - f1-score: 0.8661 - val_loss: 0.3548 - val_iou_score: 0.6659 - val_f1-score: 0.7650
# Epoch 49/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2308 - iou_score: 0.7760 - f1-score: 0.8706 - val_loss: 0.3017 - val_iou_score: 0.6934 - val_f1-score: 0.7981
# Epoch 50/60
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2279 - iou_score: 0.7834 - f1-score: 0.8750 - val_loss: 0.3073 - val_iou_score: 0.6960 - val_f1-score: 0.7975
# Epoch 51/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2598 - iou_score: 0.7696 - f1-score: 0.8676 - val_loss: 0.3175 - val_iou_score: 0.6797 - val_f1-score: 0.7808
# Epoch 52/60
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2410 - iou_score: 0.7742 - f1-score: 0.8690 - val_loss: 0.5005 - val_iou_score: 0.5314 - val_f1-score: 0.6376
# Epoch 53/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2643 - iou_score: 0.7642 - f1-score: 0.8618 - val_loss: 0.3238 - val_iou_score: 0.6750 - val_f1-score: 0.7707
# Epoch 54/60
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2282 - iou_score: 0.7863 - f1-score: 0.8784 - val_loss: 0.3080 - val_iou_score: 0.6899 - val_f1-score: 0.7877
# Epoch 55/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2148 - iou_score: 0.7951 - f1-score: 0.8838 - val_loss: 0.3121 - val_iou_score: 0.6944 - val_f1-score: 0.7924
# Epoch 56/60
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2244 - iou_score: 0.7913 - f1-score: 0.8812 - val_loss: 0.3090 - val_iou_score: 0.6952 - val_f1-score: 0.7881
# Epoch 57/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2304 - iou_score: 0.7757 - f1-score: 0.8708 - val_loss: 0.4127 - val_iou_score: 0.6176 - val_f1-score: 0.7395
# Epoch 58/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2178 - iou_score: 0.7868 - f1-score: 0.8783 - val_loss: 0.2917 - val_iou_score: 0.7119 - val_f1-score: 0.8137
# Epoch 59/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2136 - iou_score: 0.7962 - f1-score: 0.8838 - val_loss: 0.2816 - val_iou_score: 0.7151 - val_f1-score: 0.8117
# Epoch 60/60
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2174 - iou_score: 0.7903 - f1-score: 0.8811 - val_loss: 0.3679 - val_iou_score: 0.6667 - val_f1-score: 0.7745
# Epoch 1/80
# 45/45 [==============================] - 35s 782ms/step - loss: 1.3031 - iou_score: 0.2751 - f1-score: 0.4132 - val_loss: 1.0521 - val_iou_score: 0.3666 - val_f1-score: 0.4728
# Epoch 2/80
# 45/45 [==============================] - 10s 225ms/step - loss: 0.9544 - iou_score: 0.3765 - f1-score: 0.5204 - val_loss: 0.9025 - val_iou_score: 0.3936 - val_f1-score: 0.5019
# Epoch 3/80
# 45/45 [==============================] - 10s 225ms/step - loss: 0.7073 - iou_score: 0.5191 - f1-score: 0.6649 - val_loss: 0.7166 - val_iou_score: 0.4667 - val_f1-score: 0.5854
# Epoch 4/80
# 45/45 [==============================] - 10s 226ms/step - loss: 0.6401 - iou_score: 0.5439 - f1-score: 0.6851 - val_loss: 0.6366 - val_iou_score: 0.4856 - val_f1-score: 0.5922
# Epoch 5/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.6434 - iou_score: 0.5466 - f1-score: 0.6845 - val_loss: 0.5766 - val_iou_score: 0.5174 - val_f1-score: 0.6352
# Epoch 6/80
# 45/45 [==============================] - 10s 226ms/step - loss: 0.5694 - iou_score: 0.5842 - f1-score: 0.7173 - val_loss: 0.6078 - val_iou_score: 0.4729 - val_f1-score: 0.5781
# Epoch 7/80
# 45/45 [==============================] - 10s 227ms/step - loss: 0.5676 - iou_score: 0.5701 - f1-score: 0.7039 - val_loss: 0.6927 - val_iou_score: 0.4314 - val_f1-score: 0.5314
# Epoch 8/80
# 45/45 [==============================] - 10s 228ms/step - loss: 0.5088 - iou_score: 0.6078 - f1-score: 0.7388 - val_loss: 0.4884 - val_iou_score: 0.5494 - val_f1-score: 0.6313
# Epoch 9/80
# 45/45 [==============================] - 10s 228ms/step - loss: 0.5130 - iou_score: 0.5968 - f1-score: 0.7303 - val_loss: 0.5360 - val_iou_score: 0.5364 - val_f1-score: 0.6224
# Epoch 10/80
# 45/45 [==============================] - 10s 223ms/step - loss: 0.4644 - iou_score: 0.6353 - f1-score: 0.7567 - val_loss: 0.4433 - val_iou_score: 0.5853 - val_f1-score: 0.6962
# Epoch 11/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.4755 - iou_score: 0.6182 - f1-score: 0.7471 - val_loss: 0.5309 - val_iou_score: 0.5126 - val_f1-score: 0.5988
# Epoch 12/80
# 45/45 [==============================] - 10s 226ms/step - loss: 0.4794 - iou_score: 0.6156 - f1-score: 0.7503 - val_loss: 0.5215 - val_iou_score: 0.5328 - val_f1-score: 0.6254
# Epoch 13/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.4483 - iou_score: 0.6499 - f1-score: 0.7752 - val_loss: 0.4139 - val_iou_score: 0.5974 - val_f1-score: 0.6940
# Epoch 14/80
# 45/45 [==============================] - 10s 227ms/step - loss: 0.4657 - iou_score: 0.6262 - f1-score: 0.7585 - val_loss: 0.3966 - val_iou_score: 0.6054 - val_f1-score: 0.7015
# Epoch 15/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.4504 - iou_score: 0.6496 - f1-score: 0.7744 - val_loss: 0.4026 - val_iou_score: 0.6111 - val_f1-score: 0.7152
# Epoch 16/80
# 45/45 [==============================] - 10s 225ms/step - loss: 0.4527 - iou_score: 0.6483 - f1-score: 0.7721 - val_loss: 0.4659 - val_iou_score: 0.5786 - val_f1-score: 0.6884
# Epoch 17/80
# 45/45 [==============================] - 10s 226ms/step - loss: 0.3997 - iou_score: 0.6566 - f1-score: 0.7794 - val_loss: 0.4799 - val_iou_score: 0.5484 - val_f1-score: 0.6458
# Epoch 18/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.4122 - iou_score: 0.6644 - f1-score: 0.7863 - val_loss: 0.3473 - val_iou_score: 0.6731 - val_f1-score: 0.7707
# Epoch 19/80
# 45/45 [==============================] - 10s 222ms/step - loss: 0.3828 - iou_score: 0.6824 - f1-score: 0.8026 - val_loss: 0.3547 - val_iou_score: 0.6599 - val_f1-score: 0.7696
# Epoch 20/80
# 45/45 [==============================] - 10s 226ms/step - loss: 0.3619 - iou_score: 0.6957 - f1-score: 0.8112 - val_loss: 0.4160 - val_iou_score: 0.6297 - val_f1-score: 0.7404
# Epoch 21/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.3586 - iou_score: 0.6922 - f1-score: 0.8075 - val_loss: 0.3309 - val_iou_score: 0.6664 - val_f1-score: 0.7680
# Epoch 22/80
# 45/45 [==============================] - 10s 225ms/step - loss: 0.3494 - iou_score: 0.7005 - f1-score: 0.8126 - val_loss: 0.3543 - val_iou_score: 0.6596 - val_f1-score: 0.7626
# Epoch 23/80
# 45/45 [==============================] - 10s 227ms/step - loss: 0.3071 - iou_score: 0.7237 - f1-score: 0.8326 - val_loss: 0.3706 - val_iou_score: 0.6522 - val_f1-score: 0.7542
# Epoch 24/80
# 45/45 [==============================] - 10s 228ms/step - loss: 0.3654 - iou_score: 0.7053 - f1-score: 0.8190 - val_loss: 0.3329 - val_iou_score: 0.6670 - val_f1-score: 0.7655
# Epoch 25/80
# 45/45 [==============================] - 10s 225ms/step - loss: 0.3419 - iou_score: 0.7116 - f1-score: 0.8262 - val_loss: 0.3431 - val_iou_score: 0.6754 - val_f1-score: 0.7814
# Epoch 26/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.3358 - iou_score: 0.7067 - f1-score: 0.8213 - val_loss: 0.3379 - val_iou_score: 0.6718 - val_f1-score: 0.7774
# Epoch 27/80
# 45/45 [==============================] - 10s 225ms/step - loss: 0.3040 - iou_score: 0.7304 - f1-score: 0.8376 - val_loss: 0.4926 - val_iou_score: 0.5517 - val_f1-score: 0.6725
# Epoch 28/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.3150 - iou_score: 0.7303 - f1-score: 0.8386 - val_loss: 0.3388 - val_iou_score: 0.6676 - val_f1-score: 0.7714
# Epoch 29/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.3118 - iou_score: 0.7281 - f1-score: 0.8370 - val_loss: 0.4142 - val_iou_score: 0.6191 - val_f1-score: 0.7304
# Epoch 30/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.3047 - iou_score: 0.7354 - f1-score: 0.8423 - val_loss: 0.3804 - val_iou_score: 0.6493 - val_f1-score: 0.7637
# Epoch 31/80
# 45/45 [==============================] - 10s 223ms/step - loss: 0.3047 - iou_score: 0.7402 - f1-score: 0.8464 - val_loss: 0.4857 - val_iou_score: 0.5754 - val_f1-score: 0.6971
# Epoch 32/80
# 45/45 [==============================] - 10s 223ms/step - loss: 0.2917 - iou_score: 0.7308 - f1-score: 0.8372 - val_loss: 0.3483 - val_iou_score: 0.6812 - val_f1-score: 0.7910
# Epoch 33/80
# 45/45 [==============================] - 10s 223ms/step - loss: 0.2994 - iou_score: 0.7224 - f1-score: 0.8348 - val_loss: 0.3666 - val_iou_score: 0.6509 - val_f1-score: 0.7562
# Epoch 34/80
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2674 - iou_score: 0.7531 - f1-score: 0.8546 - val_loss: 0.3121 - val_iou_score: 0.6876 - val_f1-score: 0.7907
# Epoch 35/80
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2691 - iou_score: 0.7518 - f1-score: 0.8521 - val_loss: 0.3087 - val_iou_score: 0.6869 - val_f1-score: 0.7904
# Epoch 36/80
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2690 - iou_score: 0.7622 - f1-score: 0.8601 - val_loss: 0.3703 - val_iou_score: 0.6276 - val_f1-score: 0.7293
# Epoch 37/80
# 45/45 [==============================] - 10s 227ms/step - loss: 0.2713 - iou_score: 0.7503 - f1-score: 0.8521 - val_loss: 0.3320 - val_iou_score: 0.6793 - val_f1-score: 0.7770
# Epoch 38/80
# 45/45 [==============================] - 10s 227ms/step - loss: 0.2597 - iou_score: 0.7608 - f1-score: 0.8595 - val_loss: 0.3048 - val_iou_score: 0.7002 - val_f1-score: 0.7974
# Epoch 39/80
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2791 - iou_score: 0.7390 - f1-score: 0.8443 - val_loss: 0.2865 - val_iou_score: 0.7093 - val_f1-score: 0.8048
# Epoch 40/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2444 - iou_score: 0.7715 - f1-score: 0.8671 - val_loss: 0.2859 - val_iou_score: 0.7049 - val_f1-score: 0.8000
# Epoch 41/80
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2619 - iou_score: 0.7647 - f1-score: 0.8637 - val_loss: 0.4766 - val_iou_score: 0.5403 - val_f1-score: 0.6536
# Epoch 42/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2737 - iou_score: 0.7466 - f1-score: 0.8498 - val_loss: 0.3094 - val_iou_score: 0.7006 - val_f1-score: 0.7952
# Epoch 43/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2545 - iou_score: 0.7605 - f1-score: 0.8596 - val_loss: 0.2794 - val_iou_score: 0.7149 - val_f1-score: 0.8087
# Epoch 44/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2699 - iou_score: 0.7485 - f1-score: 0.8494 - val_loss: 0.2943 - val_iou_score: 0.6965 - val_f1-score: 0.7966
# Epoch 45/80
# 45/45 [==============================] - 10s 222ms/step - loss: 0.2482 - iou_score: 0.7723 - f1-score: 0.8685 - val_loss: 0.4875 - val_iou_score: 0.5583 - val_f1-score: 0.6750
# Epoch 46/80
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2689 - iou_score: 0.7616 - f1-score: 0.8607 - val_loss: 0.2813 - val_iou_score: 0.7194 - val_f1-score: 0.8131
# Epoch 47/80
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2623 - iou_score: 0.7615 - f1-score: 0.8610 - val_loss: 0.3162 - val_iou_score: 0.6871 - val_f1-score: 0.7832
# Epoch 48/80
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2474 - iou_score: 0.7762 - f1-score: 0.8693 - val_loss: 0.2871 - val_iou_score: 0.7108 - val_f1-score: 0.8052
# Epoch 49/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2459 - iou_score: 0.7713 - f1-score: 0.8679 - val_loss: 0.2744 - val_iou_score: 0.7220 - val_f1-score: 0.8165
# Epoch 50/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2426 - iou_score: 0.7728 - f1-score: 0.8680 - val_loss: 0.2905 - val_iou_score: 0.7042 - val_f1-score: 0.8035
# Epoch 51/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2474 - iou_score: 0.7678 - f1-score: 0.8652 - val_loss: 0.3310 - val_iou_score: 0.6546 - val_f1-score: 0.7540
# Epoch 52/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2652 - iou_score: 0.7545 - f1-score: 0.8563 - val_loss: 0.2869 - val_iou_score: 0.6998 - val_f1-score: 0.8042
# Epoch 53/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2268 - iou_score: 0.7783 - f1-score: 0.8720 - val_loss: 0.2715 - val_iou_score: 0.7166 - val_f1-score: 0.8166
# Epoch 54/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2461 - iou_score: 0.7695 - f1-score: 0.8670 - val_loss: 0.3229 - val_iou_score: 0.6729 - val_f1-score: 0.7746
# Epoch 55/80
# 45/45 [==============================] - 10s 222ms/step - loss: 0.2398 - iou_score: 0.7782 - f1-score: 0.8726 - val_loss: 0.2777 - val_iou_score: 0.7151 - val_f1-score: 0.8180
# Epoch 56/80
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2129 - iou_score: 0.7939 - f1-score: 0.8827 - val_loss: 0.3223 - val_iou_score: 0.6731 - val_f1-score: 0.7705
# Epoch 57/80
# 45/45 [==============================] - 10s 222ms/step - loss: 0.2147 - iou_score: 0.8075 - f1-score: 0.8916 - val_loss: 0.2837 - val_iou_score: 0.7200 - val_f1-score: 0.8164
# Epoch 58/80
# 45/45 [==============================] - 10s 222ms/step - loss: 0.1996 - iou_score: 0.8015 - f1-score: 0.8876 - val_loss: 0.2844 - val_iou_score: 0.7069 - val_f1-score: 0.8119
# Epoch 59/80
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2474 - iou_score: 0.7776 - f1-score: 0.8726 - val_loss: 0.3459 - val_iou_score: 0.6626 - val_f1-score: 0.7641
# Epoch 60/80
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2085 - iou_score: 0.8003 - f1-score: 0.8876 - val_loss: 0.2725 - val_iou_score: 0.7189 - val_f1-score: 0.8215
# Epoch 61/80
# 45/45 [==============================] - 10s 223ms/step - loss: 0.2248 - iou_score: 0.7958 - f1-score: 0.8843 - val_loss: 0.2923 - val_iou_score: 0.7028 - val_f1-score: 0.8034
# Epoch 62/80
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2113 - iou_score: 0.8015 - f1-score: 0.8869 - val_loss: 0.3276 - val_iou_score: 0.6859 - val_f1-score: 0.7904
# Epoch 63/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2086 - iou_score: 0.8048 - f1-score: 0.8897 - val_loss: 0.2757 - val_iou_score: 0.7194 - val_f1-score: 0.8174
# Epoch 64/80
# 45/45 [==============================] - 10s 223ms/step - loss: 0.1964 - iou_score: 0.8109 - f1-score: 0.8939 - val_loss: 0.2943 - val_iou_score: 0.7024 - val_f1-score: 0.8050
# Epoch 65/80
# 45/45 [==============================] - 10s 228ms/step - loss: 0.2298 - iou_score: 0.7866 - f1-score: 0.8765 - val_loss: 0.4443 - val_iou_score: 0.5575 - val_f1-score: 0.6678
# Epoch 66/80
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2389 - iou_score: 0.7770 - f1-score: 0.8694 - val_loss: 0.3525 - val_iou_score: 0.6718 - val_f1-score: 0.7781
# Epoch 67/80
# 45/45 [==============================] - 10s 223ms/step - loss: 0.2123 - iou_score: 0.8004 - f1-score: 0.8872 - val_loss: 0.2896 - val_iou_score: 0.7130 - val_f1-score: 0.8090
# Epoch 68/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2271 - iou_score: 0.7708 - f1-score: 0.8672 - val_loss: 0.2836 - val_iou_score: 0.7162 - val_f1-score: 0.8104
# Epoch 69/80
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2051 - iou_score: 0.8001 - f1-score: 0.8863 - val_loss: 0.2989 - val_iou_score: 0.7067 - val_f1-score: 0.8050
# Epoch 70/80
# 45/45 [==============================] - 10s 223ms/step - loss: 0.1921 - iou_score: 0.8125 - f1-score: 0.8944 - val_loss: 0.2932 - val_iou_score: 0.6993 - val_f1-score: 0.7942
# Epoch 71/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.1834 - iou_score: 0.8274 - f1-score: 0.9040 - val_loss: 0.2691 - val_iou_score: 0.7153 - val_f1-score: 0.8126
# Epoch 72/80
# 45/45 [==============================] - 10s 223ms/step - loss: 0.1882 - iou_score: 0.8138 - f1-score: 0.8953 - val_loss: 0.2759 - val_iou_score: 0.7174 - val_f1-score: 0.8145
# Epoch 73/80
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2030 - iou_score: 0.8084 - f1-score: 0.8918 - val_loss: 0.2915 - val_iou_score: 0.6953 - val_f1-score: 0.7919
# Epoch 74/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2150 - iou_score: 0.8025 - f1-score: 0.8887 - val_loss: 0.2734 - val_iou_score: 0.7154 - val_f1-score: 0.8215
# Epoch 75/80
# 45/45 [==============================] - 10s 224ms/step - loss: 0.1858 - iou_score: 0.8132 - f1-score: 0.8955 - val_loss: 0.2802 - val_iou_score: 0.7077 - val_f1-score: 0.8028
# Epoch 76/80
# 45/45 [==============================] - 10s 227ms/step - loss: 0.1971 - iou_score: 0.8033 - f1-score: 0.8890 - val_loss: 0.2576 - val_iou_score: 0.7304 - val_f1-score: 0.8264
# Epoch 77/80
# ...
# Epoch 17/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.4002 - iou_score: 0.6659 - f1-score: 0.7879 - val_loss: 0.4474 - val_iou_score: 0.5940 - val_f1-score: 0.7059
# Epoch 18/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.3973 - iou_score: 0.6697 - f1-score: 0.7899 - val_loss: 0.3945 - val_iou_score: 0.6280 - val_f1-score: 0.7303
# Epoch 19/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.3861 - iou_score: 0.6814 - f1-score: 0.8007 - val_loss: 0.3655 - val_iou_score: 0.6340 - val_f1-score: 0.7280
# Epoch 20/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.3759 - iou_score: 0.6877 - f1-score: 0.8040 - val_loss: 0.4129 - val_iou_score: 0.6311 - val_f1-score: 0.7305
# Epoch 21/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.3907 - iou_score: 0.6835 - f1-score: 0.8018 - val_loss: 0.4725 - val_iou_score: 0.5568 - val_f1-score: 0.6590
# Epoch 22/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.3639 - iou_score: 0.6939 - f1-score: 0.8121 - val_loss: 0.3387 - val_iou_score: 0.6670 - val_f1-score: 0.7778
# Epoch 23/100
# 45/45 [==============================] - 11s 233ms/step - loss: 0.3601 - iou_score: 0.7010 - f1-score: 0.8140 - val_loss: 0.3357 - val_iou_score: 0.6595 - val_f1-score: 0.7581
# Epoch 24/100
# 45/45 [==============================] - 10s 229ms/step - loss: 0.3584 - iou_score: 0.6975 - f1-score: 0.8126 - val_loss: 0.3158 - val_iou_score: 0.6873 - val_f1-score: 0.7907
# Epoch 25/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.3772 - iou_score: 0.6837 - f1-score: 0.8039 - val_loss: 0.3503 - val_iou_score: 0.6710 - val_f1-score: 0.7716
# Epoch 26/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.3333 - iou_score: 0.7063 - f1-score: 0.8201 - val_loss: 0.3211 - val_iou_score: 0.6801 - val_f1-score: 0.7867
# Epoch 27/100
# 45/45 [==============================] - 10s 230ms/step - loss: 0.3577 - iou_score: 0.7197 - f1-score: 0.8293 - val_loss: 0.3713 - val_iou_score: 0.6446 - val_f1-score: 0.7581
# Epoch 28/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.3221 - iou_score: 0.7165 - f1-score: 0.8263 - val_loss: 0.3560 - val_iou_score: 0.6608 - val_f1-score: 0.7616
# Epoch 29/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.3327 - iou_score: 0.7154 - f1-score: 0.8270 - val_loss: 0.3000 - val_iou_score: 0.6917 - val_f1-score: 0.7983
# Epoch 30/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.3014 - iou_score: 0.7282 - f1-score: 0.8366 - val_loss: 0.3067 - val_iou_score: 0.6807 - val_f1-score: 0.7862
# Epoch 31/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.3377 - iou_score: 0.7197 - f1-score: 0.8299 - val_loss: 0.3534 - val_iou_score: 0.6689 - val_f1-score: 0.7796
# Epoch 32/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.3335 - iou_score: 0.7161 - f1-score: 0.8289 - val_loss: 0.3581 - val_iou_score: 0.6447 - val_f1-score: 0.7647
# Epoch 33/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.2845 - iou_score: 0.7294 - f1-score: 0.8390 - val_loss: 0.2985 - val_iou_score: 0.6962 - val_f1-score: 0.8039
# Epoch 34/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.3451 - iou_score: 0.7028 - f1-score: 0.8158 - val_loss: 0.2935 - val_iou_score: 0.7064 - val_f1-score: 0.8122
# Epoch 35/100
# 45/45 [==============================] - 10s 229ms/step - loss: 0.3108 - iou_score: 0.7356 - f1-score: 0.8422 - val_loss: 0.3682 - val_iou_score: 0.6724 - val_f1-score: 0.7738
# Epoch 36/100
# 45/45 [==============================] - 10s 229ms/step - loss: 0.2944 - iou_score: 0.7382 - f1-score: 0.8439 - val_loss: 0.4518 - val_iou_score: 0.5846 - val_f1-score: 0.7019
# Epoch 37/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.2634 - iou_score: 0.7519 - f1-score: 0.8505 - val_loss: 0.2984 - val_iou_score: 0.7062 - val_f1-score: 0.8099
# Epoch 38/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.2745 - iou_score: 0.7407 - f1-score: 0.8462 - val_loss: 0.3040 - val_iou_score: 0.6966 - val_f1-score: 0.8038
# Epoch 39/100
# 45/45 [==============================] - 10s 229ms/step - loss: 0.2890 - iou_score: 0.7306 - f1-score: 0.8368 - val_loss: 0.2754 - val_iou_score: 0.7183 - val_f1-score: 0.8198
# Epoch 40/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2819 - iou_score: 0.7521 - f1-score: 0.8547 - val_loss: 0.4687 - val_iou_score: 0.5850 - val_f1-score: 0.7097
# Epoch 41/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2640 - iou_score: 0.7540 - f1-score: 0.8552 - val_loss: 0.4349 - val_iou_score: 0.6043 - val_f1-score: 0.7194
# Epoch 42/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.3078 - iou_score: 0.7226 - f1-score: 0.8304 - val_loss: 0.3162 - val_iou_score: 0.6832 - val_f1-score: 0.7883
# Epoch 43/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2636 - iou_score: 0.7560 - f1-score: 0.8573 - val_loss: 0.3385 - val_iou_score: 0.6539 - val_f1-score: 0.7561
# Epoch 44/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2403 - iou_score: 0.7727 - f1-score: 0.8683 - val_loss: 0.2768 - val_iou_score: 0.7195 - val_f1-score: 0.8230
# Epoch 45/100
# 45/45 [==============================] - 10s 229ms/step - loss: 0.2608 - iou_score: 0.7632 - f1-score: 0.8609 - val_loss: 0.2952 - val_iou_score: 0.7008 - val_f1-score: 0.8041
# Epoch 46/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.2673 - iou_score: 0.7637 - f1-score: 0.8603 - val_loss: 0.2752 - val_iou_score: 0.7142 - val_f1-score: 0.8179
# Epoch 47/100
# 45/45 [==============================] - 10s 223ms/step - loss: 0.2562 - iou_score: 0.7628 - f1-score: 0.8603 - val_loss: 0.3965 - val_iou_score: 0.6493 - val_f1-score: 0.7625
# Epoch 48/100
# 45/45 [==============================] - 10s 223ms/step - loss: 0.2525 - iou_score: 0.7632 - f1-score: 0.8619 - val_loss: 0.2755 - val_iou_score: 0.7216 - val_f1-score: 0.8231
# Epoch 49/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2426 - iou_score: 0.7750 - f1-score: 0.8707 - val_loss: 0.3070 - val_iou_score: 0.7073 - val_f1-score: 0.8114
# Epoch 50/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.2545 - iou_score: 0.7645 - f1-score: 0.8617 - val_loss: 0.2769 - val_iou_score: 0.7307 - val_f1-score: 0.8326
# Epoch 51/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.2461 - iou_score: 0.7731 - f1-score: 0.8685 - val_loss: 0.2761 - val_iou_score: 0.7114 - val_f1-score: 0.8170
# Epoch 52/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.2319 - iou_score: 0.7848 - f1-score: 0.8762 - val_loss: 0.2656 - val_iou_score: 0.7318 - val_f1-score: 0.8302
# Epoch 53/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.2748 - iou_score: 0.7687 - f1-score: 0.8664 - val_loss: 0.4292 - val_iou_score: 0.6258 - val_f1-score: 0.7434
# Epoch 54/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2180 - iou_score: 0.7941 - f1-score: 0.8830 - val_loss: 0.3384 - val_iou_score: 0.6732 - val_f1-score: 0.7793
# Epoch 55/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2330 - iou_score: 0.7839 - f1-score: 0.8755 - val_loss: 0.2758 - val_iou_score: 0.7302 - val_f1-score: 0.8293
# Epoch 56/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2300 - iou_score: 0.7859 - f1-score: 0.8772 - val_loss: 0.2716 - val_iou_score: 0.7225 - val_f1-score: 0.8221
# Epoch 57/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2316 - iou_score: 0.7821 - f1-score: 0.8735 - val_loss: 0.3434 - val_iou_score: 0.6664 - val_f1-score: 0.7734
# Epoch 58/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.2272 - iou_score: 0.7854 - f1-score: 0.8769 - val_loss: 0.2880 - val_iou_score: 0.7116 - val_f1-score: 0.8152
# Epoch 59/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2096 - iou_score: 0.7904 - f1-score: 0.8803 - val_loss: 0.2930 - val_iou_score: 0.7145 - val_f1-score: 0.8169
# Epoch 60/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.2594 - iou_score: 0.7834 - f1-score: 0.8762 - val_loss: 0.3452 - val_iou_score: 0.6700 - val_f1-score: 0.7680
# Epoch 61/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.2242 - iou_score: 0.7972 - f1-score: 0.8849 - val_loss: 0.2999 - val_iou_score: 0.6926 - val_f1-score: 0.7929
# Epoch 62/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.2351 - iou_score: 0.7770 - f1-score: 0.8712 - val_loss: 0.3576 - val_iou_score: 0.6342 - val_f1-score: 0.7428
# Epoch 63/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.2172 - iou_score: 0.7901 - f1-score: 0.8796 - val_loss: 0.2592 - val_iou_score: 0.7358 - val_f1-score: 0.8308
# Epoch 64/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2112 - iou_score: 0.7988 - f1-score: 0.8852 - val_loss: 0.2727 - val_iou_score: 0.7201 - val_f1-score: 0.8190
# Epoch 65/100
# 45/45 [==============================] - 10s 229ms/step - loss: 0.2308 - iou_score: 0.7894 - f1-score: 0.8803 - val_loss: 0.2953 - val_iou_score: 0.6947 - val_f1-score: 0.8004
# Epoch 66/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.2050 - iou_score: 0.8006 - f1-score: 0.8874 - val_loss: 0.2973 - val_iou_score: 0.7144 - val_f1-score: 0.8139
# Epoch 67/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.1995 - iou_score: 0.8072 - f1-score: 0.8904 - val_loss: 0.2726 - val_iou_score: 0.7289 - val_f1-score: 0.8270
# Epoch 68/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.2428 - iou_score: 0.7850 - f1-score: 0.8748 - val_loss: 0.2750 - val_iou_score: 0.7121 - val_f1-score: 0.8051
# Epoch 69/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.2164 - iou_score: 0.7971 - f1-score: 0.8849 - val_loss: 0.2667 - val_iou_score: 0.7332 - val_f1-score: 0.8332
# Epoch 70/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.2084 - iou_score: 0.8003 - f1-score: 0.8865 - val_loss: 0.2865 - val_iou_score: 0.7075 - val_f1-score: 0.8101
# Epoch 71/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.2051 - iou_score: 0.8049 - f1-score: 0.8889 - val_loss: 0.3160 - val_iou_score: 0.6825 - val_f1-score: 0.7834
# Epoch 72/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.1966 - iou_score: 0.8121 - f1-score: 0.8940 - val_loss: 0.3078 - val_iou_score: 0.7063 - val_f1-score: 0.8062
# Epoch 73/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.1931 - iou_score: 0.8117 - f1-score: 0.8936 - val_loss: 0.3407 - val_iou_score: 0.6608 - val_f1-score: 0.7633
# Epoch 74/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.1992 - iou_score: 0.8023 - f1-score: 0.8881 - val_loss: 0.3158 - val_iou_score: 0.6794 - val_f1-score: 0.7810
# Epoch 75/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.1810 - iou_score: 0.8200 - f1-score: 0.8995 - val_loss: 0.2630 - val_iou_score: 0.7287 - val_f1-score: 0.8280
# Epoch 76/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.2614 - iou_score: 0.7622 - f1-score: 0.8600 - val_loss: 0.2843 - val_iou_score: 0.7029 - val_f1-score: 0.8060
# Epoch 77/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.1912 - iou_score: 0.8129 - f1-score: 0.8952 - val_loss: 0.2894 - val_iou_score: 0.7010 - val_f1-score: 0.8052
# Epoch 78/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.1922 - iou_score: 0.8075 - f1-score: 0.8920 - val_loss: 0.2619 - val_iou_score: 0.7243 - val_f1-score: 0.8231
# Epoch 79/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.2043 - iou_score: 0.8035 - f1-score: 0.8887 - val_loss: 0.2718 - val_iou_score: 0.7274 - val_f1-score: 0.8219
# Epoch 80/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.1855 - iou_score: 0.8125 - f1-score: 0.8948 - val_loss: 0.2550 - val_iou_score: 0.7352 - val_f1-score: 0.8316
# Epoch 81/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.2059 - iou_score: 0.7958 - f1-score: 0.8815 - val_loss: 0.2576 - val_iou_score: 0.7366 - val_f1-score: 0.8333
# Epoch 82/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.1997 - iou_score: 0.8094 - f1-score: 0.8923 - val_loss: 0.2630 - val_iou_score: 0.7298 - val_f1-score: 0.8314
# Epoch 83/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.1886 - iou_score: 0.8094 - f1-score: 0.8923 - val_loss: 0.2609 - val_iou_score: 0.7306 - val_f1-score: 0.8247
# Epoch 84/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.1731 - iou_score: 0.8252 - f1-score: 0.9023 - val_loss: 0.3111 - val_iou_score: 0.7021 - val_f1-score: 0.8015
# Epoch 85/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.1910 - iou_score: 0.8134 - f1-score: 0.8949 - val_loss: 0.2879 - val_iou_score: 0.7055 - val_f1-score: 0.8062
# Epoch 86/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.1851 - iou_score: 0.8162 - f1-score: 0.8969 - val_loss: 0.2642 - val_iou_score: 0.7241 - val_f1-score: 0.8232
# Epoch 87/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.1797 - iou_score: 0.8208 - f1-score: 0.9000 - val_loss: 0.2580 - val_iou_score: 0.7388 - val_f1-score: 0.8360
# Epoch 88/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.1689 - iou_score: 0.8346 - f1-score: 0.9090 - val_loss: 0.2676 - val_iou_score: 0.7320 - val_f1-score: 0.8315
# Epoch 89/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.1886 - iou_score: 0.8211 - f1-score: 0.9006 - val_loss: 0.2703 - val_iou_score: 0.7285 - val_f1-score: 0.8288
# Epoch 90/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.1708 - iou_score: 0.8287 - f1-score: 0.9047 - val_loss: 0.2710 - val_iou_score: 0.7320 - val_f1-score: 0.8309
# Epoch 91/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.1802 - iou_score: 0.8215 - f1-score: 0.9003 - val_loss: 0.2549 - val_iou_score: 0.7428 - val_f1-score: 0.8372
# Epoch 92/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.1798 - iou_score: 0.8238 - f1-score: 0.9015 - val_loss: 0.2687 - val_iou_score: 0.7215 - val_f1-score: 0.8193
# Epoch 93/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.1702 - iou_score: 0.8297 - f1-score: 0.9054 - val_loss: 0.2613 - val_iou_score: 0.7359 - val_f1-score: 0.8349
# Epoch 94/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.1720 - iou_score: 0.8241 - f1-score: 0.9025 - val_loss: 0.2889 - val_iou_score: 0.7047 - val_f1-score: 0.8082
# Epoch 95/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.1858 - iou_score: 0.8263 - f1-score: 0.9034 - val_loss: 0.2825 - val_iou_score: 0.7157 - val_f1-score: 0.8139
# Epoch 96/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.1888 - iou_score: 0.8107 - f1-score: 0.8911 - val_loss: 0.2517 - val_iou_score: 0.7340 - val_f1-score: 0.8319
# Epoch 97/100
# 45/45 [==============================] - 10s 229ms/step - loss: 0.1853 - iou_score: 0.8163 - f1-score: 0.8964 - val_loss: 0.2623 - val_iou_score: 0.7421 - val_f1-score: 0.8397
# Epoch 98/100
# 45/45 [==============================] - 10s 228ms/step - loss: 0.1686 - iou_score: 0.8334 - f1-score: 0.9076 - val_loss: 0.3285 - val_iou_score: 0.6659 - val_f1-score: 0.7689
# Epoch 99/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.1711 - iou_score: 0.8347 - f1-score: 0.9082 - val_loss: 0.2797 - val_iou_score: 0.7212 - val_f1-score: 0.8252
# Epoch 100/100
# 45/45 [==============================] - 10s 230ms/step - loss: 0.1676 - iou_score: 0.8361 - f1-score: 0.9096 - val_loss: 0.3233 - val_iou_score: 0.6757 - val_f1-score: 0.7815
