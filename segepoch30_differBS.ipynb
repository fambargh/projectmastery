# %% [markdown]
# <a href="https://colab.research.google.com/github/fambargh/projectmastery/blob/master/segepoch30_differBS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install -U git+https://github.com/albu/albumentations --no-cache-dir
# Out:
# Collecting git+https://github.com/albu/albumentations
#   Cloning https://github.com/albu/albumentations to /tmp/pip-req-build-aw__c2te
#   Running command git clone -q https://github.com/albu/albumentations /tmp/pip-req-build-aw__c2te
# Requirement already satisfied, skipping upgrade: numpy>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (1.17.4)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (1.3.3)
# Requirement already satisfied, skipping upgrade: imgaug<0.2.7,>=0.2.5 in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (0.2.6)
# Requirement already satisfied, skipping upgrade: PyYAML in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (3.13)
# Requirement already satisfied, skipping upgrade: opencv-python>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (4.1.2.30)
# Requirement already satisfied, skipping upgrade: scikit-image>=0.11.0 in /usr/local/lib/python3.6/dist-packages (from imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (0.15.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (1.12.0)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (3.1.2)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (4.3.0)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (1.1.1)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.4)
# Requirement already satisfied, skipping upgrade: imageio>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.4.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (1.1.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.6.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.4.5)
# Requirement already satisfied, skipping upgrade: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=4.3.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (0.46)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (4.4.1)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from kiwisolver>=1.0.1->matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (42.0.2)
# Building wheels for collected packages: albumentations
#   Building wheel for albumentations (setup.py) ... done
#   Created wheel for albumentations: filename=albumentations-0.4.4-cp36-none-any.whl size=61995 sha256=fa3b381a06eda37cd84e83cd7dc763c22a15ebaa826f1c1bf71688d5eebe757f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8org8hld/wheels/45/8b/e4/2837bbcf517d00732b8e394f8646f22b8723ac00993230188b
# Successfully built albumentations
# Installing collected packages: albumentations
#   Found existing installation: albumentations 0.4.4
#     Uninstalling albumentations-0.4.4:
#       Successfully uninstalled albumentations-0.4.4
# Successfully installed albumentations-0.4.4

# %%
# Install required libs
# !pip install -U --pre segmentation-models --user
# Out:
# Collecting segmentation-models
#   Downloading https://files.pythonhosted.org/packages/70/14/090ea95a4f69c453731d9df3feff0a08e0dea0e8dff932dc4839ec4dab5c/segmentation_models-1.0.0-py3-none-any.whl
# Collecting image-classifiers==1.0.0
#   Downloading https://files.pythonhosted.org/packages/81/98/6f84720e299a4942ab80df5f76ab97b7828b24d1de5e9b2cbbe6073228b7/image_classifiers-1.0.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from segmentation-models) (1.0.8)
# Collecting efficientnet==1.0.0
#   Downloading https://files.pythonhosted.org/packages/97/82/f3ae07316f0461417dc54affab6e86ab188a5a22f33176d35271628b96e0/efficientnet-1.0.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.17.4)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (2.8.0)
# Requirement already satisfied, skipping upgrade: scikit-image in /usr/local/lib/python3.6/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.15.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.12.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.3.3)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1.2)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.4)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (4.3.0)
# Requirement already satisfied, skipping upgrade: imageio>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.4.1)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.1.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (1.1.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.4.5)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.6.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (0.10.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image->efficientnet==1.0.0->segmentation-models) (4.4.1)
# Requirement already satisfied, skipping upgrade: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=4.3.0->scikit-image->efficientnet==1.0.0->segmentation-models) (0.46)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from kiwisolver>=1.0.1->matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (42.0.2)
# Installing collected packages: image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 segmentation-models-1.0.0

# %%
from zipfile import ZipFile
filename = "image.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
from zipfile import ZipFile
filename = "annotate_cup3.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
import os
import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
x_train_dir = '/content/image_train/'
y_train_dir = '/content/annotate_cup3/annotate_cup_train/'

x_valid_dir = '/content/image_valid/'
y_valid_dir = '/content/annotate_cup3/annotate_cup_valid'

x_test_dir = '/content/image_test/'
y_test_dir = '/content/annotate_cup3/annotate_cup_test/'

# %%
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x
    

# classes for data loading and preprocessing
class Dataset:
    """ Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    CLASSES = ['bg', 'oc','nolabeled']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        self.ids = os.listdir(images_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id) for image_id in self.ids]
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)
        
        # extract certain classes from mask (e.g. oc)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # add background if mask is not binary
        if mask.shape[-1] != 1:
            background = 1 - mask.sum(axis=-1, keepdims=True)
            mask = np.concatenate((mask, background), axis=-1)
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)
    
    
class Dataloder(keras.utils.Sequence):
    """Load data from dataset and form batches
    
    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integet number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """
    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

        self.on_epoch_end()

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        # transpose list of lists
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        return batch
    
    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# Lets look at data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['bg','oc','nolabeled'])

image, mask = dataset[5] # get some sample
visualize(
    image=image, 
    bg_mask=mask[..., 0].squeeze(),
    OC_mask=mask[..., 1].squeeze(),
    no_labeled_mask=mask[..., 2].squeeze(),
    background_mask=mask[..., 3].squeeze(),
)

# %%
import albumentations as A

# %%
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# define heavy augmentations
def get_training_augmentation():
    train_transform = [

        A.HorizontalFlip(p=0.5),

        A.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, shift_limit=0.1, p=1, border_mode=0),

        A.PadIfNeeded(min_height=128, min_width=128, always_apply=True, border_mode=0),
        A.RandomCrop(height=128, width=128, always_apply=True),

        A.IAAAdditiveGaussianNoise(p=0.2),
        A.IAAPerspective(p=0.5),

        A.OneOf(
            [
                A.CLAHE(p=1),
                A.RandomBrightness(p=1),
                A.RandomGamma(p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.IAASharpen(p=1),
                A.Blur(blur_limit=3, p=1),
                A.MotionBlur(blur_limit=3, p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.RandomContrast(p=1),
                A.HueSaturationValue(p=1),
            ],
            p=0.9,
        ),
        A.Lambda(mask=round_clip_0_1)
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 128"""
    test_transform = [
        A.PadIfNeeded(128, 128)
    ]
    return A.Compose(test_transform)

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

# %%
# Lets look at augmented data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['bg', 'oc','nolabeled'], augmentation=get_training_augmentation())

image, mask = dataset[12] # get some sample
visualize(
    image=image, 
    bg_mask=mask[..., 0].squeeze(),
    OC_mask=mask[..., 1].squeeze(),
    no_labeled_mask=mask[..., 2].squeeze(),
    background_mask=mask[..., 3].squeeze(),
)
# Out:
# /usr/local/lib/python3.6/dist-packages/albumentations/augmentations/transforms.py:2910: UserWarning: Using lambda is incompatible with multiprocessing. Consider using regular functions or partial().
#   "Using lambda is incompatible with multiprocessing. "

# %%
import segmentation_models as sm
# Out:
# Segmentation Models: using `keras` framework.

# %%
BACKBONE = 'seresnet50'
BATCH_SIZE = 32
CLASSES = ['oc']
#LR = 0.01
EPOCHS = 30
preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

# %%
# study of eppoch number on metrics for segmentation problem
from keras.optimizers import SGD
from matplotlib import pyplot


# fit a model and plot learning curve
def fit_model(BATCH_SIZE):
  n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
  activation = 'sigmoid' if n_classes == 1 else 'softmax'
  # Dataset for train images
  train_dataset = Dataset(
      x_train_dir,
      y_train_dir,
      classes=CLASSES,
      augmentation=get_training_augmentation(),
      preprocessing=get_preprocessing(preprocess_input),
      )
  # Dataset for validation images
  valid_dataset = Dataset(
      x_valid_dir,
      y_valid_dir,
      classes=CLASSES,
      augmentation=get_validation_augmentation(),
      preprocessing=get_preprocessing(preprocess_input),
      )
  
  train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
  valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)
  
  # check shapes for errors
  assert train_dataloader[0][0].shape == (BATCH_SIZE, 128, 128, 3)
  assert train_dataloader[0][1].shape == (BATCH_SIZE, 128, 128, n_classes)
  
  
  # define callbacks for learning rate scheduling and best checkpoints saving
  callbacks = [
               keras.callbacks.ModelCheckpoint('./best_model.h5', save_weights_only=True, save_best_only=True, mode='min'),
               keras.callbacks.ReduceLROnPlateau(),
               ]
               # define network parameters
  n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
  activation = 'sigmoid' if n_classes == 1 else 'softmax'
  # define model
  model = sm.Unet(BACKBONE, classes=n_classes, activation=activation)
  opt = SGD()
  dice_loss = sm.losses.DiceLoss()
  focal_loss = sm.losses.BinaryFocalLoss() 
  total_loss = dice_loss + (1 * focal_loss)
  metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]
  model.compile(opt, total_loss, metrics)
  # fit model
  history = model.fit_generator(train_dataloader, 
                                steps_per_epoch=len(train_dataloader), 
                                epochs=EPOCHS, 
                                #callbacks=callbacks, 
                                validation_data=valid_dataloader, 
                                validation_steps=len(valid_dataloader),
                                )
  # plot learning curves
  pyplot.plot(history.history['f1-score'], label='train')
  pyplot.plot(history.history['val_f1-score'], label='test')
  pyplot.title('f1_score_for_epochnum30_for_BSnum_=_'+str(BATCH_SIZE), pad=-50)
  plt.ylabel('f1_score')
  plt.legend(['Train', 'Test'], loc='upper left')

# create learning curves for different epoch numbers
BATCH_SIZE = [16,32]
for i in range(len(BATCH_SIZE)):
  plt.figure(figsize=(30, 25))
  # determine the plot number
  plot_no = 420 + (i+1)
  pyplot.subplot(plot_no)
  # fit model and plot learning curves for an epoch number
  fit_model(BATCH_SIZE[i])
# show learning curves
pyplot.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/albumentations/augmentations/transforms.py:2910: UserWarning: Using lambda is incompatible with multiprocessing. Consider using regular functions or partial().
#   "Using lambda is incompatible with multiprocessing. "
# aaaaaaaaaaa
# Epoch 1/30
# 11/11 [==============================] - 26s 2s/step - loss: 2.0722 - iou_score: 0.1463 - f1-score: 0.2487 - val_loss: 1.6708 - val_iou_score: 0.1391 - val_f1-score: 0.2206
# Epoch 2/30
# 11/11 [==============================] - 6s 523ms/step - loss: 1.3352 - iou_score: 0.2700 - f1-score: 0.4200 - val_loss: 1.4143 - val_iou_score: 0.1842 - val_f1-score: 0.2745
# Epoch 3/30
# 11/11 [==============================] - 6s 520ms/step - loss: 1.1137 - iou_score: 0.3643 - f1-score: 0.5316 - val_loss: 1.3270 - val_iou_score: 0.1972 - val_f1-score: 0.2896
# Epoch 4/30
# 11/11 [==============================] - 6s 521ms/step - loss: 1.0288 - iou_score: 0.3775 - f1-score: 0.5409 - val_loss: 1.2547 - val_iou_score: 0.2106 - val_f1-score: 0.3064
# Epoch 5/30
# 11/11 [==============================] - 6s 520ms/step - loss: 0.9181 - iou_score: 0.4172 - f1-score: 0.5860 - val_loss: 1.2104 - val_iou_score: 0.2171 - val_f1-score: 0.3140
# Epoch 6/30
# 11/11 [==============================] - 6s 520ms/step - loss: 0.8186 - iou_score: 0.4743 - f1-score: 0.6376 - val_loss: 1.1203 - val_iou_score: 0.2409 - val_f1-score: 0.3398
# Epoch 7/30
# 11/11 [==============================] - 6s 522ms/step - loss: 0.7229 - iou_score: 0.5303 - f1-score: 0.6866 - val_loss: 1.0561 - val_iou_score: 0.2749 - val_f1-score: 0.3804
# Epoch 8/30
# 11/11 [==============================] - 6s 520ms/step - loss: 0.6011 - iou_score: 0.6105 - f1-score: 0.7550 - val_loss: 1.0107 - val_iou_score: 0.3029 - val_f1-score: 0.4115
# Epoch 9/30
# 11/11 [==============================] - 6s 520ms/step - loss: 0.5872 - iou_score: 0.5985 - f1-score: 0.7461 - val_loss: 0.9594 - val_iou_score: 0.3203 - val_f1-score: 0.4274
# Epoch 10/30
# 11/11 [==============================] - 6s 524ms/step - loss: 0.5326 - iou_score: 0.6345 - f1-score: 0.7750 - val_loss: 0.8760 - val_iou_score: 0.3459 - val_f1-score: 0.4434
# Epoch 11/30
# 11/11 [==============================] - 6s 519ms/step - loss: 0.5058 - iou_score: 0.6460 - f1-score: 0.7834 - val_loss: 0.9299 - val_iou_score: 0.3491 - val_f1-score: 0.4582
# Epoch 12/30
# 11/11 [==============================] - 6s 525ms/step - loss: 0.4388 - iou_score: 0.6841 - f1-score: 0.8111 - val_loss: 0.9035 - val_iou_score: 0.3621 - val_f1-score: 0.4733
# Epoch 13/30
# 11/11 [==============================] - 6s 521ms/step - loss: 0.4565 - iou_score: 0.6639 - f1-score: 0.7939 - val_loss: 0.8213 - val_iou_score: 0.3808 - val_f1-score: 0.4805
# Epoch 14/30
# 11/11 [==============================] - 6s 522ms/step - loss: 0.4470 - iou_score: 0.6604 - f1-score: 0.7937 - val_loss: 0.7643 - val_iou_score: 0.3642 - val_f1-score: 0.4286
# Epoch 15/30
# 11/11 [==============================] - 6s 518ms/step - loss: 0.4291 - iou_score: 0.6668 - f1-score: 0.7986 - val_loss: 0.7175 - val_iou_score: 0.3915 - val_f1-score: 0.4682
# Epoch 16/30
# 11/11 [==============================] - 6s 525ms/step - loss: 0.4109 - iou_score: 0.6859 - f1-score: 0.8085 - val_loss: 0.7044 - val_iou_score: 0.4205 - val_f1-score: 0.5152
# Epoch 17/30
# 11/11 [==============================] - 6s 518ms/step - loss: 0.4259 - iou_score: 0.6609 - f1-score: 0.7902 - val_loss: 0.6643 - val_iou_score: 0.4162 - val_f1-score: 0.4855
# Epoch 18/30
# 11/11 [==============================] - 6s 520ms/step - loss: 0.4174 - iou_score: 0.6830 - f1-score: 0.8083 - val_loss: 0.6668 - val_iou_score: 0.4391 - val_f1-score: 0.5354
# Epoch 19/30
# 11/11 [==============================] - 6s 523ms/step - loss: 0.3993 - iou_score: 0.6974 - f1-score: 0.8201 - val_loss: 0.6727 - val_iou_score: 0.4076 - val_f1-score: 0.4874
# Epoch 20/30
# 11/11 [==============================] - 6s 518ms/step - loss: 0.3516 - iou_score: 0.7164 - f1-score: 0.8329 - val_loss: 0.6402 - val_iou_score: 0.4259 - val_f1-score: 0.5027
# Epoch 21/30
# 11/11 [==============================] - 6s 530ms/step - loss: 0.3492 - iou_score: 0.7194 - f1-score: 0.8351 - val_loss: 0.6156 - val_iou_score: 0.4385 - val_f1-score: 0.5143
# Epoch 22/30
# 11/11 [==============================] - 6s 522ms/step - loss: 0.3677 - iou_score: 0.7050 - f1-score: 0.8250 - val_loss: 0.5960 - val_iou_score: 0.4690 - val_f1-score: 0.5638
# Epoch 23/30
# 11/11 [==============================] - 6s 526ms/step - loss: 0.3489 - iou_score: 0.7168 - f1-score: 0.8335 - val_loss: 0.5976 - val_iou_score: 0.4589 - val_f1-score: 0.5530
# Epoch 24/30
# 11/11 [==============================] - 6s 518ms/step - loss: 0.3291 - iou_score: 0.7380 - f1-score: 0.8485 - val_loss: 0.5759 - val_iou_score: 0.4982 - val_f1-score: 0.5978
# Epoch 25/30
# 11/11 [==============================] - 6s 518ms/step - loss: 0.3445 - iou_score: 0.7297 - f1-score: 0.8418 - val_loss: 0.6026 - val_iou_score: 0.4977 - val_f1-score: 0.6077
# Epoch 26/30
# 11/11 [==============================] - 6s 524ms/step - loss: 0.3428 - iou_score: 0.7184 - f1-score: 0.8339 - val_loss: 0.5604 - val_iou_score: 0.5043 - val_f1-score: 0.6049
# Epoch 27/30
# 11/11 [==============================] - 6s 516ms/step - loss: 0.3924 - iou_score: 0.7014 - f1-score: 0.8211 - val_loss: 0.5738 - val_iou_score: 0.4738 - val_f1-score: 0.5641
# Epoch 28/30
# 11/11 [==============================] - 6s 517ms/step - loss: 0.3161 - iou_score: 0.7331 - f1-score: 0.8448 - val_loss: 0.5735 - val_iou_score: 0.4660 - val_f1-score: 0.5499
# Epoch 29/30
# 11/11 [==============================] - 6s 522ms/step - loss: 0.3181 - iou_score: 0.7424 - f1-score: 0.8510 - val_loss: 0.5501 - val_iou_score: 0.5083 - val_f1-score: 0.6058
# Epoch 30/30
# 11/11 [==============================] - 6s 522ms/step - loss: 0.3163 - iou_score: 0.7317 - f1-score: 0.8418 - val_loss: 0.5391 - val_iou_score: 0.5163 - val_f1-score: 0.6098
# aaaaaaaaaaa
# Epoch 1/30
# 5/5 [==============================] - 27s 5s/step - loss: 2.5183 - iou_score: 0.1032 - f1-score: 0.1867 - val_loss: 2.0821 - val_iou_score: 0.0884 - val_f1-score: 0.1475
# Epoch 2/30
# 5/5 [==============================] - 4s 860ms/step - loss: 1.7522 - iou_score: 0.1909 - f1-score: 0.3203 - val_loss: 1.7222 - val_iou_score: 0.1428 - val_f1-score: 0.2272
# Epoch 3/30
# 5/5 [==============================] - 4s 863ms/step - loss: 1.4572 - iou_score: 0.2566 - f1-score: 0.4062 - val_loss: 1.5387 - val_iou_score: 0.1843 - val_f1-score: 0.2840
# Epoch 4/30
# 5/5 [==============================] - 4s 864ms/step - loss: 1.2917 - iou_score: 0.2998 - f1-score: 0.4601 - val_loss: 1.4539 - val_iou_score: 0.2048 - val_f1-score: 0.3103
# Epoch 5/30
# 5/5 [==============================] - 4s 866ms/step - loss: 1.2051 - iou_score: 0.3124 - f1-score: 0.4744 - val_loss: 1.4074 - val_iou_score: 0.2173 - val_f1-score: 0.3262
# Epoch 6/30
# 5/5 [==============================] - 4s 859ms/step - loss: 1.1142 - iou_score: 0.3589 - f1-score: 0.5260 - val_loss: 1.3626 - val_iou_score: 0.2296 - val_f1-score: 0.3424
# Epoch 7/30
# 5/5 [==============================] - 4s 855ms/step - loss: 1.0561 - iou_score: 0.3685 - f1-score: 0.5377 - val_loss: 1.3467 - val_iou_score: 0.2412 - val_f1-score: 0.3582
# Epoch 8/30
# 5/5 [==============================] - 4s 860ms/step - loss: 1.0043 - iou_score: 0.3865 - f1-score: 0.5549 - val_loss: 1.3346 - val_iou_score: 0.2465 - val_f1-score: 0.3648
# Epoch 9/30
# 5/5 [==============================] - 4s 851ms/step - loss: 0.9459 - iou_score: 0.4193 - f1-score: 0.5876 - val_loss: 1.3260 - val_iou_score: 0.2527 - val_f1-score: 0.3710
# Epoch 10/30
# 5/5 [==============================] - 4s 866ms/step - loss: 0.8938 - iou_score: 0.4513 - f1-score: 0.6205 - val_loss: 1.3144 - val_iou_score: 0.2658 - val_f1-score: 0.3867
# Epoch 11/30
# 5/5 [==============================] - 4s 858ms/step - loss: 0.8307 - iou_score: 0.4789 - f1-score: 0.6467 - val_loss: 1.2507 - val_iou_score: 0.2803 - val_f1-score: 0.4028
# Epoch 12/30
# 5/5 [==============================] - 4s 859ms/step - loss: 0.7571 - iou_score: 0.5299 - f1-score: 0.6921 - val_loss: 1.2624 - val_iou_score: 0.2809 - val_f1-score: 0.4030
# Epoch 13/30
# 5/5 [==============================] - 4s 857ms/step - loss: 0.6875 - iou_score: 0.5776 - f1-score: 0.7319 - val_loss: 1.1832 - val_iou_score: 0.3014 - val_f1-score: 0.4238
# Epoch 14/30
# 5/5 [==============================] - 4s 859ms/step - loss: 0.6216 - iou_score: 0.6115 - f1-score: 0.7579 - val_loss: 1.2137 - val_iou_score: 0.3063 - val_f1-score: 0.4317
# Epoch 15/30
# 5/5 [==============================] - 4s 865ms/step - loss: 0.6067 - iou_score: 0.6133 - f1-score: 0.7598 - val_loss: 1.1787 - val_iou_score: 0.3203 - val_f1-score: 0.4436
# Epoch 16/30
# 5/5 [==============================] - 4s 859ms/step - loss: 0.5697 - iou_score: 0.6292 - f1-score: 0.7722 - val_loss: 1.0996 - val_iou_score: 0.3451 - val_f1-score: 0.4687
# Epoch 17/30
# 5/5 [==============================] - 4s 865ms/step - loss: 0.5286 - iou_score: 0.6565 - f1-score: 0.7923 - val_loss: 1.1190 - val_iou_score: 0.3432 - val_f1-score: 0.4695
# Epoch 18/30
# 5/5 [==============================] - 4s 867ms/step - loss: 0.5463 - iou_score: 0.6368 - f1-score: 0.7762 - val_loss: 1.0819 - val_iou_score: 0.3516 - val_f1-score: 0.4764
# Epoch 19/30
# 5/5 [==============================] - 4s 869ms/step - loss: 0.4695 - iou_score: 0.6856 - f1-score: 0.8129 - val_loss: 1.0466 - val_iou_score: 0.3609 - val_f1-score: 0.4837
# Epoch 20/30
# 5/5 [==============================] - 4s 857ms/step - loss: 0.4955 - iou_score: 0.6509 - f1-score: 0.7882 - val_loss: 0.9948 - val_iou_score: 0.3821 - val_f1-score: 0.5056
# Epoch 21/30
# 5/5 [==============================] - 4s 863ms/step - loss: 0.4676 - iou_score: 0.6661 - f1-score: 0.7995 - val_loss: 0.9222 - val_iou_score: 0.3966 - val_f1-score: 0.5169
# Epoch 22/30
# 5/5 [==============================] - 4s 862ms/step - loss: 0.4422 - iou_score: 0.6935 - f1-score: 0.8178 - val_loss: 0.9999 - val_iou_score: 0.3872 - val_f1-score: 0.5148
# Epoch 23/30
# 5/5 [==============================] - 4s 860ms/step - loss: 0.4542 - iou_score: 0.6690 - f1-score: 0.8006 - val_loss: 0.9293 - val_iou_score: 0.4018 - val_f1-score: 0.5254
# Epoch 24/30
# 5/5 [==============================] - 4s 861ms/step - loss: 0.4429 - iou_score: 0.6880 - f1-score: 0.8148 - val_loss: 0.8891 - val_iou_score: 0.4172 - val_f1-score: 0.5371
# Epoch 25/30
# 5/5 [==============================] - 4s 857ms/step - loss: 0.4001 - iou_score: 0.7124 - f1-score: 0.8318 - val_loss: 0.8625 - val_iou_score: 0.4237 - val_f1-score: 0.5392
# Epoch 26/30
# 5/5 [==============================] - 4s 857ms/step - loss: 0.4066 - iou_score: 0.6979 - f1-score: 0.8216 - val_loss: 0.8226 - val_iou_score: 0.4338 - val_f1-score: 0.5452
# Epoch 27/30
# 5/5 [==============================] - 4s 858ms/step - loss: 0.3777 - iou_score: 0.7218 - f1-score: 0.8381 - val_loss: 0.8185 - val_iou_score: 0.4334 - val_f1-score: 0.5468
# Epoch 28/30
# 5/5 [==============================] - 4s 859ms/step - loss: 0.4166 - iou_score: 0.6830 - f1-score: 0.8114 - val_loss: 0.8004 - val_iou_score: 0.4429 - val_f1-score: 0.5511
# Epoch 29/30
# 5/5 [==============================] - 4s 860ms/step - loss: 0.3821 - iou_score: 0.7085 - f1-score: 0.8283 - val_loss: 0.7273 - val_iou_score: 0.4487 - val_f1-score: 0.5515
# Epoch 30/30
# 5/5 [==============================] - 4s 861ms/step - loss: 0.3474 - iou_score: 0.7379 - f1-score: 0.8491 - val_loss: 0.7662 - val_iou_score: 0.4689 - val_f1-score: 0.5794
