# %% [markdown]
# <a href="https://colab.research.google.com/github/fambargh/projectmastery/blob/master/seg_cup_correct_rmsprop_drishti_aug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install -U git+https://github.com/albu/albumentations --no-cache-dir
# Out:
# Collecting git+https://github.com/albu/albumentations
#   Cloning https://github.com/albu/albumentations to /tmp/pip-req-build-5ha83iu0
#   Running command git clone -q https://github.com/albu/albumentations /tmp/pip-req-build-5ha83iu0
# Requirement already satisfied, skipping upgrade: numpy>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (1.17.4)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (1.3.3)
# Requirement already satisfied, skipping upgrade: imgaug<0.2.7,>=0.2.5 in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (0.2.6)
# Requirement already satisfied, skipping upgrade: PyYAML in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (3.13)
# Requirement already satisfied, skipping upgrade: opencv-python>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (4.1.2.30)
# Requirement already satisfied, skipping upgrade: scikit-image>=0.11.0 in /usr/local/lib/python3.6/dist-packages (from imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (0.15.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (1.12.0)
# Requirement already satisfied, skipping upgrade: imageio>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.4.1)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (3.1.2)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (1.1.1)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.4)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (4.3.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.6.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (0.10.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.4.5)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (1.1.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (4.4.1)
# Requirement already satisfied, skipping upgrade: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=4.3.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (0.46)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from kiwisolver>=1.0.1->matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (42.0.2)
# Building wheels for collected packages: albumentations
#   Building wheel for albumentations (setup.py) ... done
#   Created wheel for albumentations: filename=albumentations-0.4.4-cp36-none-any.whl size=61955 sha256=08ecd341d954b21bc405fdaaa138fd0c94b2842c2d816a2866884b2eee06a69b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hulr7ygg/wheels/45/8b/e4/2837bbcf517d00732b8e394f8646f22b8723ac00993230188b
# Successfully built albumentations
# Installing collected packages: albumentations
#   Found existing installation: albumentations 0.4.4
#     Uninstalling albumentations-0.4.4:
#       Successfully uninstalled albumentations-0.4.4
# Successfully installed albumentations-0.4.4

# %%
# Install required libs

# !pip install -U --pre segmentation-models --user
# Out:
# Collecting segmentation-models
#   Downloading https://files.pythonhosted.org/packages/70/14/090ea95a4f69c453731d9df3feff0a08e0dea0e8dff932dc4839ec4dab5c/segmentation_models-1.0.0-py3-none-any.whl
# Collecting efficientnet==1.0.0
#   Downloading https://files.pythonhosted.org/packages/97/82/f3ae07316f0461417dc54affab6e86ab188a5a22f33176d35271628b96e0/efficientnet-1.0.0-py3-none-any.whl
# Collecting image-classifiers==1.0.0
#   Downloading https://files.pythonhosted.org/packages/81/98/6f84720e299a4942ab80df5f76ab97b7828b24d1de5e9b2cbbe6073228b7/image_classifiers-1.0.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from segmentation-models) (1.0.8)
# Requirement already satisfied, skipping upgrade: scikit-image in /usr/local/lib/python3.6/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.15.0)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (2.8.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.17.4)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.3.3)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (4.3.0)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1.2)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.4)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.1.1)
# Requirement already satisfied, skipping upgrade: imageio>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.4.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.12.0)
# Requirement already satisfied, skipping upgrade: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=4.3.0->scikit-image->efficientnet==1.0.0->segmentation-models) (0.46)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (1.1.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.4.5)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.6.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (0.10.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image->efficientnet==1.0.0->segmentation-models) (4.4.1)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from kiwisolver>=1.0.1->matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (42.0.2)
# Installing collected packages: efficientnet, image-classifiers, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 segmentation-models-1.0.0

# %%
from zipfile import ZipFile
filename = "total.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
from zipfile import ZipFile
filename = "test.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
import os
import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
x_train_dir = '/content/image_train/'
y_train_dir = '/content/annotation_cup_train/'

x_valid_dir = '/content/image_valid/'
y_valid_dir = '/content/annotation_cup_valid'

x_test_dir = '/content/id/'
y_test_dir = '/content/cd/'

# %%
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x
    

# classes for data loading and preprocessing
class Dataset:
    """ Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    CLASSES = ['bg', 'oc','nolabeled']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        self.ids = os.listdir(images_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id) for image_id in self.ids]
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)
        
        # extract certain classes from mask (e.g. oc)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # add background if mask is not binary
        if mask.shape[-1] != 1:
            background = 1 - mask.sum(axis=-1, keepdims=True)
            mask = np.concatenate((mask, background), axis=-1)
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)
    
    
class Dataloder(keras.utils.Sequence):
    """Load data from dataset and form batches
    
    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integet number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """
    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

        self.on_epoch_end()

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        # transpose list of lists
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        return batch
    
    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# Lets look at data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['oc','bg','nolabeled'])

image, mask = dataset[12] # get some sample
visualize(
    image=image, 
    OC_mask=mask[..., 0].squeeze(),
    bg_mask=mask[..., 1].squeeze(),
    nolabeled_mask=mask[..., 2].squeeze(),
    background_mask=mask[..., 3].squeeze(),
)

# %%
import albumentations as A

# %%
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# define heavy augmentations
def get_training_augmentation():
    train_transform = [

        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.5),

        A.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, shift_limit=0.1, p=1, border_mode=0),

        A.IAAAdditiveGaussianNoise(p=0.2),
        A.IAAPerspective(p=0.5),

        A.OneOf(
            [
                A.CLAHE(p=1),
                A.RandomBrightness(p=1),
                A.RandomGamma(p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.IAASharpen(p=1),
                A.Blur(blur_limit=40, p=1),
                A.MotionBlur(blur_limit=20, p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.RandomContrast(p=1),
                A.HueSaturationValue(p=1),
            ],
            p=0.9,
        ),
        A.Lambda(mask=round_clip_0_1)
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        
    ]
    return A.Compose(test_transform)

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

# %%
# Lets look at augmented data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['oc', 'bg','nolabeled'], augmentation=get_training_augmentation())

image, mask = dataset[12] # get some sample
visualize(
    image=image, 
    OC_mask=mask[..., 0].squeeze(),
    bg_mask=mask[..., 1].squeeze(),
    nolabeled_mask=mask[..., 2].squeeze(),
    background_mask=mask[..., 3].squeeze(),
)
# Out:
# /usr/local/lib/python3.6/dist-packages/albumentations/augmentations/transforms.py:2910: UserWarning: Using lambda is incompatible with multiprocessing. Consider using regular functions or partial().
#   "Using lambda is incompatible with multiprocessing. "

# %%
import segmentation_models as sm
# Out:
# Segmentation Models: using `keras` framework.

# %%
BACKBONE = 'seresnet50'
BATCH_SIZE = 2
CLASSES = ['oc']
#LR = 0.0001
EPOCHS = 150

preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# define network parameters
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

#create model
model = sm.Unet(BACKBONE, classes=n_classes, activation=activation)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.

# %%
# define optomizer
optim = keras.optimizers.RMSprop(lr=0.0001)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
dice_loss = sm.losses.DiceLoss()
focal_loss = sm.losses.BinaryFocalLoss() if n_classes == 1 else sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 

metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5), sm.metrics.Precision(), sm.metrics.Recall()]

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, total_loss, metrics)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
assert train_dataloader[0][0].shape == (BATCH_SIZE, 128, 128, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 128, 128, n_classes)

# define callbacks for learning rate scheduling and best checkpoints saving
callbacks = [
    keras.callbacks.ModelCheckpoint('./best_model.h5', save_weights_only=True, save_best_only=True, mode='min'),
    keras.callbacks.ReduceLROnPlateau(),
]
# Out:
# /usr/local/lib/python3.6/dist-packages/albumentations/augmentations/transforms.py:2910: UserWarning: Using lambda is incompatible with multiprocessing. Consider using regular functions or partial().
#   "Using lambda is incompatible with multiprocessing. "

# %%
history = model.fit_generator(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=EPOCHS, 
    callbacks=callbacks, 
    validation_data=valid_dataloader, 
    validation_steps=len(valid_dataloader),
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/150
# 91/91 [==============================] - 30s 325ms/step - loss: 1.3724 - iou_score: 0.2844 - f1-score: 0.4100 - precision: 0.1609 - recall: 0.6430 - val_loss: 1.1050 - val_iou_score: 0.2246 - val_f1-score: 0.2873 - val_precision: 0.1865 - val_recall: 0.2921
# Epoch 2/150
# 91/91 [==============================] - 9s 103ms/step - loss: 1.0582 - iou_score: 0.4457 - f1-score: 0.5774 - precision: 0.2443 - recall: 0.7343 - val_loss: 0.8417 - val_iou_score: 0.5287 - val_f1-score: 0.6310 - val_precision: 0.2675 - val_recall: 0.7272
# Epoch 3/150
# 91/91 [==============================] - 9s 103ms/step - loss: 0.9240 - iou_score: 0.4847 - f1-score: 0.6180 - precision: 0.3078 - recall: 0.7607 - val_loss: 0.8959 - val_iou_score: 0.4877 - val_f1-score: 0.6243 - val_precision: 0.2710 - val_recall: 0.8841
# Epoch 4/150
# 91/91 [==============================] - 9s 102ms/step - loss: 0.8323 - iou_score: 0.4863 - f1-score: 0.6233 - precision: 0.3092 - recall: 0.7822 - val_loss: 0.7371 - val_iou_score: 0.5153 - val_f1-score: 0.6392 - val_precision: 0.3449 - val_recall: 0.9393
# Epoch 5/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.8189 - iou_score: 0.4964 - f1-score: 0.6392 - precision: 0.4033 - recall: 0.7456 - val_loss: 0.5998 - val_iou_score: 0.6216 - val_f1-score: 0.7304 - val_precision: 0.4238 - val_recall: 0.7489
# Epoch 6/150
# 91/91 [==============================] - 9s 101ms/step - loss: 0.7065 - iou_score: 0.5550 - f1-score: 0.6924 - precision: 0.4314 - recall: 0.7911 - val_loss: 0.5731 - val_iou_score: 0.6308 - val_f1-score: 0.7317 - val_precision: 0.4663 - val_recall: 0.7144
# Epoch 7/150
# 91/91 [==============================] - 9s 101ms/step - loss: 0.6586 - iou_score: 0.5409 - f1-score: 0.6735 - precision: 0.4707 - recall: 0.7782 - val_loss: 0.5660 - val_iou_score: 0.5769 - val_f1-score: 0.7047 - val_precision: 0.4419 - val_recall: 0.9241
# Epoch 8/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.5788 - iou_score: 0.5811 - f1-score: 0.7140 - precision: 0.5197 - recall: 0.7935 - val_loss: 0.6222 - val_iou_score: 0.4485 - val_f1-score: 0.5338 - val_precision: 0.4673 - val_recall: 0.4923
# Epoch 9/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.5657 - iou_score: 0.5784 - f1-score: 0.7130 - precision: 0.5573 - recall: 0.7778 - val_loss: 0.4382 - val_iou_score: 0.6614 - val_f1-score: 0.7730 - val_precision: 0.5673 - val_recall: 0.7789
# Epoch 10/150
# 91/91 [==============================] - 9s 101ms/step - loss: 0.5596 - iou_score: 0.5930 - f1-score: 0.7298 - precision: 0.5779 - recall: 0.7712 - val_loss: 0.3895 - val_iou_score: 0.6847 - val_f1-score: 0.7947 - val_precision: 0.6069 - val_recall: 0.8562
# Epoch 11/150
# 91/91 [==============================] - 9s 102ms/step - loss: 0.5083 - iou_score: 0.6054 - f1-score: 0.7351 - precision: 0.5957 - recall: 0.7944 - val_loss: 0.4764 - val_iou_score: 0.5819 - val_f1-score: 0.7001 - val_precision: 0.6691 - val_recall: 0.6075
# Epoch 12/150
# 91/91 [==============================] - 9s 101ms/step - loss: 0.5167 - iou_score: 0.5872 - f1-score: 0.7183 - precision: 0.6072 - recall: 0.7780 - val_loss: 0.3775 - val_iou_score: 0.6671 - val_f1-score: 0.7733 - val_precision: 0.6574 - val_recall: 0.7999
# Epoch 13/150
# 91/91 [==============================] - 9s 101ms/step - loss: 0.4779 - iou_score: 0.6244 - f1-score: 0.7479 - precision: 0.6498 - recall: 0.7805 - val_loss: 0.3700 - val_iou_score: 0.6779 - val_f1-score: 0.7866 - val_precision: 0.6580 - val_recall: 0.8217
# Epoch 14/150
# 91/91 [==============================] - 9s 102ms/step - loss: 0.5139 - iou_score: 0.5990 - f1-score: 0.7281 - precision: 0.6462 - recall: 0.7573 - val_loss: 0.3705 - val_iou_score: 0.6587 - val_f1-score: 0.7721 - val_precision: 0.6408 - val_recall: 0.8655
# Epoch 15/150
# 91/91 [==============================] - 9s 101ms/step - loss: 0.4792 - iou_score: 0.6078 - f1-score: 0.7377 - precision: 0.6457 - recall: 0.7795 - val_loss: 0.3558 - val_iou_score: 0.6726 - val_f1-score: 0.7912 - val_precision: 0.6943 - val_recall: 0.7886
# Epoch 16/150
# 91/91 [==============================] - 9s 101ms/step - loss: 0.4464 - iou_score: 0.6338 - f1-score: 0.7632 - precision: 0.6834 - recall: 0.7837 - val_loss: 0.3251 - val_iou_score: 0.6872 - val_f1-score: 0.7990 - val_precision: 0.7058 - val_recall: 0.8536
# Epoch 17/150
# 91/91 [==============================] - 9s 101ms/step - loss: 0.4709 - iou_score: 0.6057 - f1-score: 0.7396 - precision: 0.6684 - recall: 0.7707 - val_loss: 0.4010 - val_iou_score: 0.6312 - val_f1-score: 0.7492 - val_precision: 0.8248 - val_recall: 0.6527
# Epoch 18/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.4533 - iou_score: 0.6266 - f1-score: 0.7563 - precision: 0.6874 - recall: 0.7717 - val_loss: 0.3154 - val_iou_score: 0.7001 - val_f1-score: 0.7988 - val_precision: 0.7828 - val_recall: 0.7426
# Epoch 19/150
# 91/91 [==============================] - 9s 101ms/step - loss: 0.4129 - iou_score: 0.6474 - f1-score: 0.7700 - precision: 0.7065 - recall: 0.7886 - val_loss: 0.2985 - val_iou_score: 0.7127 - val_f1-score: 0.8110 - val_precision: 0.7196 - val_recall: 0.8368
# Epoch 20/150
# 91/91 [==============================] - 9s 101ms/step - loss: 0.4159 - iou_score: 0.6529 - f1-score: 0.7785 - precision: 0.7252 - recall: 0.7937 - val_loss: 0.2799 - val_iou_score: 0.7277 - val_f1-score: 0.8219 - val_precision: 0.7840 - val_recall: 0.7994
# Epoch 21/150
# 91/91 [==============================] - 9s 102ms/step - loss: 0.4254 - iou_score: 0.6216 - f1-score: 0.7515 - precision: 0.6993 - recall: 0.7815 - val_loss: 0.3173 - val_iou_score: 0.7057 - val_f1-score: 0.8101 - val_precision: 0.6850 - val_recall: 0.8685
# Epoch 22/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.4043 - iou_score: 0.6395 - f1-score: 0.7643 - precision: 0.7198 - recall: 0.7864 - val_loss: 0.3274 - val_iou_score: 0.6699 - val_f1-score: 0.7755 - val_precision: 0.8102 - val_recall: 0.7037
# Epoch 23/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.4106 - iou_score: 0.6379 - f1-score: 0.7625 - precision: 0.7145 - recall: 0.7881 - val_loss: 0.3067 - val_iou_score: 0.6920 - val_f1-score: 0.7898 - val_precision: 0.7529 - val_recall: 0.7914
# Epoch 24/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.4214 - iou_score: 0.6399 - f1-score: 0.7662 - precision: 0.7147 - recall: 0.7879 - val_loss: 0.2989 - val_iou_score: 0.6922 - val_f1-score: 0.7865 - val_precision: 0.8177 - val_recall: 0.7496
# Epoch 25/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3996 - iou_score: 0.6495 - f1-score: 0.7728 - precision: 0.7271 - recall: 0.7886 - val_loss: 0.4500 - val_iou_score: 0.6212 - val_f1-score: 0.7498 - val_precision: 0.5939 - val_recall: 0.9545
# Epoch 26/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3978 - iou_score: 0.6562 - f1-score: 0.7777 - precision: 0.7328 - recall: 0.8019 - val_loss: 0.2982 - val_iou_score: 0.7171 - val_f1-score: 0.8153 - val_precision: 0.7994 - val_recall: 0.7749
# Epoch 27/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3951 - iou_score: 0.6738 - f1-score: 0.7936 - precision: 0.7537 - recall: 0.7947 - val_loss: 0.2752 - val_iou_score: 0.7228 - val_f1-score: 0.8196 - val_precision: 0.8072 - val_recall: 0.7867
# Epoch 28/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3603 - iou_score: 0.6701 - f1-score: 0.7884 - precision: 0.7471 - recall: 0.8168 - val_loss: 0.3039 - val_iou_score: 0.6910 - val_f1-score: 0.7905 - val_precision: 0.7825 - val_recall: 0.7595
# Epoch 29/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3795 - iou_score: 0.6597 - f1-score: 0.7799 - precision: 0.7475 - recall: 0.7917 - val_loss: 0.2919 - val_iou_score: 0.7014 - val_f1-score: 0.8031 - val_precision: 0.7704 - val_recall: 0.7974
# Epoch 30/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.4000 - iou_score: 0.6432 - f1-score: 0.7647 - precision: 0.7337 - recall: 0.7912 - val_loss: 0.2930 - val_iou_score: 0.7023 - val_f1-score: 0.8030 - val_precision: 0.7942 - val_recall: 0.7807
# Epoch 31/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3544 - iou_score: 0.6683 - f1-score: 0.7886 - precision: 0.7462 - recall: 0.8080 - val_loss: 0.3266 - val_iou_score: 0.6866 - val_f1-score: 0.7945 - val_precision: 0.8291 - val_recall: 0.7380
# Epoch 32/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.4105 - iou_score: 0.6483 - f1-score: 0.7724 - precision: 0.7559 - recall: 0.7851 - val_loss: 0.2686 - val_iou_score: 0.7303 - val_f1-score: 0.8286 - val_precision: 0.7640 - val_recall: 0.8474
# Epoch 33/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3485 - iou_score: 0.6805 - f1-score: 0.8001 - precision: 0.7645 - recall: 0.8081 - val_loss: 0.3266 - val_iou_score: 0.6668 - val_f1-score: 0.7753 - val_precision: 0.7594 - val_recall: 0.7675
# Epoch 34/150
# 91/91 [==============================] - 9s 98ms/step - loss: 0.3754 - iou_score: 0.6522 - f1-score: 0.7738 - precision: 0.7411 - recall: 0.7948 - val_loss: 0.3444 - val_iou_score: 0.6630 - val_f1-score: 0.7710 - val_precision: 0.8299 - val_recall: 0.7000
# Epoch 35/150
# 91/91 [==============================] - 9s 101ms/step - loss: 0.3791 - iou_score: 0.6686 - f1-score: 0.7885 - precision: 0.7568 - recall: 0.8069 - val_loss: 0.3443 - val_iou_score: 0.6615 - val_f1-score: 0.7775 - val_precision: 0.7521 - val_recall: 0.8090
# Epoch 36/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3622 - iou_score: 0.6662 - f1-score: 0.7833 - precision: 0.7404 - recall: 0.7986 - val_loss: 0.3255 - val_iou_score: 0.6934 - val_f1-score: 0.7982 - val_precision: 0.8228 - val_recall: 0.7394
# Epoch 37/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3661 - iou_score: 0.6789 - f1-score: 0.7946 - precision: 0.7687 - recall: 0.8000 - val_loss: 0.3673 - val_iou_score: 0.6452 - val_f1-score: 0.7530 - val_precision: 0.7484 - val_recall: 0.7729
# Epoch 38/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3631 - iou_score: 0.6640 - f1-score: 0.7891 - precision: 0.7556 - recall: 0.8006 - val_loss: 0.3714 - val_iou_score: 0.6475 - val_f1-score: 0.7675 - val_precision: 0.7491 - val_recall: 0.7566
# Epoch 39/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3610 - iou_score: 0.6685 - f1-score: 0.7896 - precision: 0.7563 - recall: 0.8093 - val_loss: 0.2929 - val_iou_score: 0.7015 - val_f1-score: 0.8054 - val_precision: 0.7806 - val_recall: 0.8056
# Epoch 40/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.4225 - iou_score: 0.6593 - f1-score: 0.7774 - precision: 0.7511 - recall: 0.8061 - val_loss: 0.2995 - val_iou_score: 0.7183 - val_f1-score: 0.8203 - val_precision: 0.7720 - val_recall: 0.8199
# Epoch 41/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3525 - iou_score: 0.6787 - f1-score: 0.7971 - precision: 0.7686 - recall: 0.8126 - val_loss: 0.2834 - val_iou_score: 0.7182 - val_f1-score: 0.8204 - val_precision: 0.7681 - val_recall: 0.8462
# Epoch 42/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3572 - iou_score: 0.6760 - f1-score: 0.7950 - precision: 0.7611 - recall: 0.8053 - val_loss: 0.2967 - val_iou_score: 0.7071 - val_f1-score: 0.8142 - val_precision: 0.7303 - val_recall: 0.8946
# Epoch 43/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3657 - iou_score: 0.6787 - f1-score: 0.7944 - precision: 0.7497 - recall: 0.8278 - val_loss: 0.2793 - val_iou_score: 0.7128 - val_f1-score: 0.8137 - val_precision: 0.8282 - val_recall: 0.7751
# Epoch 44/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3124 - iou_score: 0.7009 - f1-score: 0.8159 - precision: 0.7917 - recall: 0.8061 - val_loss: 0.2807 - val_iou_score: 0.7117 - val_f1-score: 0.8118 - val_precision: 0.8264 - val_recall: 0.7734
# Epoch 45/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3020 - iou_score: 0.7058 - f1-score: 0.8172 - precision: 0.7854 - recall: 0.8257 - val_loss: 0.2891 - val_iou_score: 0.6975 - val_f1-score: 0.7996 - val_precision: 0.8275 - val_recall: 0.7620
# Epoch 46/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3174 - iou_score: 0.6930 - f1-score: 0.8103 - precision: 0.7893 - recall: 0.8131 - val_loss: 0.2901 - val_iou_score: 0.7048 - val_f1-score: 0.8057 - val_precision: 0.8289 - val_recall: 0.7633
# Epoch 47/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2929 - iou_score: 0.7211 - f1-score: 0.8263 - precision: 0.7951 - recall: 0.8288 - val_loss: 0.2922 - val_iou_score: 0.7006 - val_f1-score: 0.8038 - val_precision: 0.8212 - val_recall: 0.7710
# Epoch 48/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3123 - iou_score: 0.6973 - f1-score: 0.8108 - precision: 0.7757 - recall: 0.8250 - val_loss: 0.2934 - val_iou_score: 0.6989 - val_f1-score: 0.8016 - val_precision: 0.8363 - val_recall: 0.7566
# Epoch 49/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2851 - iou_score: 0.7252 - f1-score: 0.8322 - precision: 0.7981 - recall: 0.8387 - val_loss: 0.2990 - val_iou_score: 0.6977 - val_f1-score: 0.7998 - val_precision: 0.8366 - val_recall: 0.7522
# Epoch 50/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3113 - iou_score: 0.7160 - f1-score: 0.8234 - precision: 0.8091 - recall: 0.8169 - val_loss: 0.2821 - val_iou_score: 0.7120 - val_f1-score: 0.8105 - val_precision: 0.8118 - val_recall: 0.7908
# Epoch 51/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2987 - iou_score: 0.7013 - f1-score: 0.8103 - precision: 0.7861 - recall: 0.8096 - val_loss: 0.2885 - val_iou_score: 0.7090 - val_f1-score: 0.8096 - val_precision: 0.8117 - val_recall: 0.7889
# Epoch 52/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3034 - iou_score: 0.7038 - f1-score: 0.8162 - precision: 0.7886 - recall: 0.8184 - val_loss: 0.2880 - val_iou_score: 0.7076 - val_f1-score: 0.8082 - val_precision: 0.8207 - val_recall: 0.7794
# Epoch 53/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3003 - iou_score: 0.7010 - f1-score: 0.8144 - precision: 0.7722 - recall: 0.8351 - val_loss: 0.2888 - val_iou_score: 0.7095 - val_f1-score: 0.8097 - val_precision: 0.8222 - val_recall: 0.7786
# Epoch 54/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2622 - iou_score: 0.7372 - f1-score: 0.8409 - precision: 0.8080 - recall: 0.8416 - val_loss: 0.2888 - val_iou_score: 0.7088 - val_f1-score: 0.8093 - val_precision: 0.8210 - val_recall: 0.7788
# Epoch 55/150
# 91/91 [==============================] - 9s 101ms/step - loss: 0.2899 - iou_score: 0.7130 - f1-score: 0.8220 - precision: 0.7900 - recall: 0.8305 - val_loss: 0.2867 - val_iou_score: 0.7092 - val_f1-score: 0.8097 - val_precision: 0.8217 - val_recall: 0.7811
# Epoch 56/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3115 - iou_score: 0.7155 - f1-score: 0.8249 - precision: 0.7890 - recall: 0.8381 - val_loss: 0.2812 - val_iou_score: 0.7139 - val_f1-score: 0.8134 - val_precision: 0.8247 - val_recall: 0.7861
# Epoch 57/150
# 91/91 [==============================] - 9s 98ms/step - loss: 0.3125 - iou_score: 0.7216 - f1-score: 0.8270 - precision: 0.7964 - recall: 0.8230 - val_loss: 0.2797 - val_iou_score: 0.7129 - val_f1-score: 0.8120 - val_precision: 0.8254 - val_recall: 0.7834
# Epoch 58/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3470 - iou_score: 0.7044 - f1-score: 0.8143 - precision: 0.7993 - recall: 0.8059 - val_loss: 0.2791 - val_iou_score: 0.7153 - val_f1-score: 0.8142 - val_precision: 0.8249 - val_recall: 0.7874
# Epoch 59/150
# 91/91 [==============================] - 9s 101ms/step - loss: 0.3004 - iou_score: 0.7014 - f1-score: 0.8142 - precision: 0.7942 - recall: 0.8154 - val_loss: 0.2772 - val_iou_score: 0.7169 - val_f1-score: 0.8152 - val_precision: 0.8224 - val_recall: 0.7913
# Epoch 60/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3066 - iou_score: 0.7053 - f1-score: 0.8152 - precision: 0.7786 - recall: 0.8292 - val_loss: 0.2795 - val_iou_score: 0.7146 - val_f1-score: 0.8133 - val_precision: 0.8233 - val_recall: 0.7880
# Epoch 61/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2814 - iou_score: 0.7361 - f1-score: 0.8387 - precision: 0.8152 - recall: 0.8272 - val_loss: 0.2815 - val_iou_score: 0.7137 - val_f1-score: 0.8129 - val_precision: 0.8210 - val_recall: 0.7863
# Epoch 62/150
# 91/91 [==============================] - 9s 98ms/step - loss: 0.3000 - iou_score: 0.7184 - f1-score: 0.8253 - precision: 0.7885 - recall: 0.8435 - val_loss: 0.2823 - val_iou_score: 0.7121 - val_f1-score: 0.8118 - val_precision: 0.8231 - val_recall: 0.7844
# Epoch 63/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2809 - iou_score: 0.7172 - f1-score: 0.8264 - precision: 0.8013 - recall: 0.8271 - val_loss: 0.2845 - val_iou_score: 0.7095 - val_f1-score: 0.8096 - val_precision: 0.8265 - val_recall: 0.7793
# Epoch 64/150
# 91/91 [==============================] - 9s 98ms/step - loss: 0.3118 - iou_score: 0.6958 - f1-score: 0.8075 - precision: 0.7923 - recall: 0.8052 - val_loss: 0.2868 - val_iou_score: 0.7075 - val_f1-score: 0.8083 - val_precision: 0.8240 - val_recall: 0.7783
# Epoch 65/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2695 - iou_score: 0.7306 - f1-score: 0.8356 - precision: 0.8128 - recall: 0.8334 - val_loss: 0.2867 - val_iou_score: 0.7078 - val_f1-score: 0.8084 - val_precision: 0.8244 - val_recall: 0.7765
# Epoch 66/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2684 - iou_score: 0.7322 - f1-score: 0.8392 - precision: 0.8075 - recall: 0.8372 - val_loss: 0.2832 - val_iou_score: 0.7096 - val_f1-score: 0.8096 - val_precision: 0.8244 - val_recall: 0.7807
# Epoch 67/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2941 - iou_score: 0.7146 - f1-score: 0.8239 - precision: 0.7880 - recall: 0.8357 - val_loss: 0.2822 - val_iou_score: 0.7118 - val_f1-score: 0.8111 - val_precision: 0.8262 - val_recall: 0.7820
# Epoch 68/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2686 - iou_score: 0.7385 - f1-score: 0.8419 - precision: 0.8029 - recall: 0.8515 - val_loss: 0.2807 - val_iou_score: 0.7132 - val_f1-score: 0.8122 - val_precision: 0.8265 - val_recall: 0.7826
# Epoch 69/150
# 91/91 [==============================] - 9s 102ms/step - loss: 0.2802 - iou_score: 0.7353 - f1-score: 0.8398 - precision: 0.8121 - recall: 0.8326 - val_loss: 0.2817 - val_iou_score: 0.7107 - val_f1-score: 0.8106 - val_precision: 0.8261 - val_recall: 0.7802
# Epoch 70/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2960 - iou_score: 0.7165 - f1-score: 0.8250 - precision: 0.8033 - recall: 0.8235 - val_loss: 0.2837 - val_iou_score: 0.7092 - val_f1-score: 0.8098 - val_precision: 0.8233 - val_recall: 0.7812
# Epoch 71/150
# 91/91 [==============================] - 9s 98ms/step - loss: 0.2662 - iou_score: 0.7390 - f1-score: 0.8424 - precision: 0.8188 - recall: 0.8345 - val_loss: 0.2843 - val_iou_score: 0.7084 - val_f1-score: 0.8086 - val_precision: 0.8260 - val_recall: 0.7770
# Epoch 72/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2969 - iou_score: 0.7181 - f1-score: 0.8231 - precision: 0.7929 - recall: 0.8371 - val_loss: 0.2833 - val_iou_score: 0.7100 - val_f1-score: 0.8099 - val_precision: 0.8264 - val_recall: 0.7783
# Epoch 73/150
# 91/91 [==============================] - 9s 101ms/step - loss: 0.2959 - iou_score: 0.7127 - f1-score: 0.8216 - precision: 0.7910 - recall: 0.8315 - val_loss: 0.2846 - val_iou_score: 0.7097 - val_f1-score: 0.8101 - val_precision: 0.8249 - val_recall: 0.7771
# Epoch 74/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2773 - iou_score: 0.7260 - f1-score: 0.8335 - precision: 0.8118 - recall: 0.8231 - val_loss: 0.2851 - val_iou_score: 0.7087 - val_f1-score: 0.8092 - val_precision: 0.8274 - val_recall: 0.7746
# Epoch 75/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2741 - iou_score: 0.7251 - f1-score: 0.8292 - precision: 0.8009 - recall: 0.8311 - val_loss: 0.2828 - val_iou_score: 0.7112 - val_f1-score: 0.8112 - val_precision: 0.8256 - val_recall: 0.7792
# Epoch 76/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2917 - iou_score: 0.7219 - f1-score: 0.8287 - precision: 0.8089 - recall: 0.8244 - val_loss: 0.2824 - val_iou_score: 0.7115 - val_f1-score: 0.8114 - val_precision: 0.8244 - val_recall: 0.7808
# Epoch 77/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3035 - iou_score: 0.7142 - f1-score: 0.8178 - precision: 0.7914 - recall: 0.8201 - val_loss: 0.2797 - val_iou_score: 0.7134 - val_f1-score: 0.8128 - val_precision: 0.8248 - val_recall: 0.7833
# Epoch 78/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2843 - iou_score: 0.7264 - f1-score: 0.8342 - precision: 0.8129 - recall: 0.8245 - val_loss: 0.2832 - val_iou_score: 0.7105 - val_f1-score: 0.8105 - val_precision: 0.8242 - val_recall: 0.7794
# Epoch 79/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2822 - iou_score: 0.7211 - f1-score: 0.8274 - precision: 0.8089 - recall: 0.8128 - val_loss: 0.2793 - val_iou_score: 0.7133 - val_f1-score: 0.8125 - val_precision: 0.8259 - val_recall: 0.7848
# Epoch 80/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3114 - iou_score: 0.7002 - f1-score: 0.8090 - precision: 0.7796 - recall: 0.8237 - val_loss: 0.2817 - val_iou_score: 0.7129 - val_f1-score: 0.8124 - val_precision: 0.8238 - val_recall: 0.7835
# Epoch 81/150
# 91/91 [==============================] - 9s 98ms/step - loss: 0.2943 - iou_score: 0.7062 - f1-score: 0.8176 - precision: 0.7988 - recall: 0.8165 - val_loss: 0.2845 - val_iou_score: 0.7086 - val_f1-score: 0.8090 - val_precision: 0.8260 - val_recall: 0.7792
# Epoch 82/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2831 - iou_score: 0.7185 - f1-score: 0.8278 - precision: 0.7940 - recall: 0.8346 - val_loss: 0.2808 - val_iou_score: 0.7126 - val_f1-score: 0.8118 - val_precision: 0.8283 - val_recall: 0.7825
# Epoch 83/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2786 - iou_score: 0.7290 - f1-score: 0.8322 - precision: 0.8027 - recall: 0.8286 - val_loss: 0.2857 - val_iou_score: 0.7070 - val_f1-score: 0.8077 - val_precision: 0.8275 - val_recall: 0.7759
# Epoch 84/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3115 - iou_score: 0.7103 - f1-score: 0.8182 - precision: 0.7944 - recall: 0.8217 - val_loss: 0.2842 - val_iou_score: 0.7098 - val_f1-score: 0.8103 - val_precision: 0.8238 - val_recall: 0.7798
# Epoch 85/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3079 - iou_score: 0.7054 - f1-score: 0.8110 - precision: 0.7968 - recall: 0.8079 - val_loss: 0.2829 - val_iou_score: 0.7117 - val_f1-score: 0.8114 - val_precision: 0.8248 - val_recall: 0.7819
# Epoch 86/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3009 - iou_score: 0.7137 - f1-score: 0.8234 - precision: 0.7982 - recall: 0.8238 - val_loss: 0.2801 - val_iou_score: 0.7148 - val_f1-score: 0.8138 - val_precision: 0.8251 - val_recall: 0.7866
# Epoch 87/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3107 - iou_score: 0.7014 - f1-score: 0.8096 - precision: 0.7958 - recall: 0.8227 - val_loss: 0.2801 - val_iou_score: 0.7151 - val_f1-score: 0.8136 - val_precision: 0.8259 - val_recall: 0.7856
# Epoch 88/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2978 - iou_score: 0.7038 - f1-score: 0.8156 - precision: 0.7918 - recall: 0.8166 - val_loss: 0.2821 - val_iou_score: 0.7098 - val_f1-score: 0.8094 - val_precision: 0.8280 - val_recall: 0.7798
# Epoch 89/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2757 - iou_score: 0.7327 - f1-score: 0.8379 - precision: 0.8127 - recall: 0.8283 - val_loss: 0.2835 - val_iou_score: 0.7104 - val_f1-score: 0.8104 - val_precision: 0.8284 - val_recall: 0.7788
# Epoch 90/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2793 - iou_score: 0.7281 - f1-score: 0.8344 - precision: 0.8135 - recall: 0.8264 - val_loss: 0.2814 - val_iou_score: 0.7141 - val_f1-score: 0.8133 - val_precision: 0.8267 - val_recall: 0.7832
# Epoch 91/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3105 - iou_score: 0.7081 - f1-score: 0.8173 - precision: 0.7900 - recall: 0.8260 - val_loss: 0.2826 - val_iou_score: 0.7110 - val_f1-score: 0.8110 - val_precision: 0.8261 - val_recall: 0.7817
# Epoch 92/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3131 - iou_score: 0.6985 - f1-score: 0.8088 - precision: 0.7945 - recall: 0.8048 - val_loss: 0.2808 - val_iou_score: 0.7137 - val_f1-score: 0.8133 - val_precision: 0.8228 - val_recall: 0.7873
# Epoch 93/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3085 - iou_score: 0.6982 - f1-score: 0.8092 - precision: 0.7838 - recall: 0.8173 - val_loss: 0.2813 - val_iou_score: 0.7134 - val_f1-score: 0.8130 - val_precision: 0.8249 - val_recall: 0.7862
# Epoch 94/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2736 - iou_score: 0.7341 - f1-score: 0.8385 - precision: 0.8171 - recall: 0.8267 - val_loss: 0.2832 - val_iou_score: 0.7118 - val_f1-score: 0.8115 - val_precision: 0.8243 - val_recall: 0.7815
# Epoch 95/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3055 - iou_score: 0.7081 - f1-score: 0.8175 - precision: 0.7895 - recall: 0.8270 - val_loss: 0.2839 - val_iou_score: 0.7113 - val_f1-score: 0.8115 - val_precision: 0.8214 - val_recall: 0.7831
# Epoch 96/150
# 91/91 [==============================] - 9s 98ms/step - loss: 0.2599 - iou_score: 0.7350 - f1-score: 0.8371 - precision: 0.8150 - recall: 0.8312 - val_loss: 0.2858 - val_iou_score: 0.7081 - val_f1-score: 0.8087 - val_precision: 0.8253 - val_recall: 0.7791
# Epoch 97/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2961 - iou_score: 0.7144 - f1-score: 0.8247 - precision: 0.7889 - recall: 0.8375 - val_loss: 0.2816 - val_iou_score: 0.7140 - val_f1-score: 0.8129 - val_precision: 0.8254 - val_recall: 0.7849
# Epoch 98/150
# 91/91 [==============================] - 9s 98ms/step - loss: 0.2902 - iou_score: 0.7101 - f1-score: 0.8209 - precision: 0.7962 - recall: 0.8229 - val_loss: 0.2854 - val_iou_score: 0.7102 - val_f1-score: 0.8105 - val_precision: 0.8244 - val_recall: 0.7814
# Epoch 99/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2924 - iou_score: 0.7135 - f1-score: 0.8228 - precision: 0.8054 - recall: 0.8134 - val_loss: 0.2805 - val_iou_score: 0.7143 - val_f1-score: 0.8136 - val_precision: 0.8230 - val_recall: 0.7867
# Epoch 100/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3006 - iou_score: 0.7197 - f1-score: 0.8278 - precision: 0.8058 - recall: 0.8234 - val_loss: 0.2851 - val_iou_score: 0.7106 - val_f1-score: 0.8110 - val_precision: 0.8229 - val_recall: 0.7802
# Epoch 101/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2842 - iou_score: 0.7142 - f1-score: 0.8222 - precision: 0.8098 - recall: 0.8021 - val_loss: 0.2888 - val_iou_score: 0.7074 - val_f1-score: 0.8083 - val_precision: 0.8261 - val_recall: 0.7730
# Epoch 102/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2889 - iou_score: 0.7086 - f1-score: 0.8167 - precision: 0.8006 - recall: 0.8125 - val_loss: 0.2855 - val_iou_score: 0.7089 - val_f1-score: 0.8093 - val_precision: 0.8226 - val_recall: 0.7799
# Epoch 103/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2895 - iou_score: 0.7109 - f1-score: 0.8179 - precision: 0.7936 - recall: 0.8267 - val_loss: 0.2868 - val_iou_score: 0.7065 - val_f1-score: 0.8070 - val_precision: 0.8280 - val_recall: 0.7740
# Epoch 104/150
# 91/91 [==============================] - 9s 101ms/step - loss: 0.2848 - iou_score: 0.7292 - f1-score: 0.8332 - precision: 0.8011 - recall: 0.8307 - val_loss: 0.2863 - val_iou_score: 0.7071 - val_f1-score: 0.8076 - val_precision: 0.8280 - val_recall: 0.7741
# Epoch 105/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2969 - iou_score: 0.7022 - f1-score: 0.8128 - precision: 0.7952 - recall: 0.8020 - val_loss: 0.2840 - val_iou_score: 0.7109 - val_f1-score: 0.8107 - val_precision: 0.8238 - val_recall: 0.7810
# Epoch 106/150
# 91/91 [==============================] - 9s 98ms/step - loss: 0.2924 - iou_score: 0.7172 - f1-score: 0.8223 - precision: 0.7943 - recall: 0.8188 - val_loss: 0.2826 - val_iou_score: 0.7120 - val_f1-score: 0.8117 - val_precision: 0.8245 - val_recall: 0.7837
# Epoch 107/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2911 - iou_score: 0.7147 - f1-score: 0.8245 - precision: 0.8026 - recall: 0.8205 - val_loss: 0.2814 - val_iou_score: 0.7120 - val_f1-score: 0.8118 - val_precision: 0.8261 - val_recall: 0.7833
# Epoch 108/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2955 - iou_score: 0.7154 - f1-score: 0.8205 - precision: 0.7887 - recall: 0.8280 - val_loss: 0.2823 - val_iou_score: 0.7110 - val_f1-score: 0.8113 - val_precision: 0.8233 - val_recall: 0.7838
# Epoch 109/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2829 - iou_score: 0.7220 - f1-score: 0.8307 - precision: 0.8058 - recall: 0.8359 - val_loss: 0.2837 - val_iou_score: 0.7102 - val_f1-score: 0.8104 - val_precision: 0.8251 - val_recall: 0.7805
# Epoch 110/150
# 91/91 [==============================] - 9s 98ms/step - loss: 0.2865 - iou_score: 0.7155 - f1-score: 0.8226 - precision: 0.7950 - recall: 0.8300 - val_loss: 0.2856 - val_iou_score: 0.7069 - val_f1-score: 0.8071 - val_precision: 0.8291 - val_recall: 0.7758
# Epoch 111/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3021 - iou_score: 0.7076 - f1-score: 0.8148 - precision: 0.7808 - recall: 0.8234 - val_loss: 0.2826 - val_iou_score: 0.7115 - val_f1-score: 0.8110 - val_precision: 0.8266 - val_recall: 0.7812
# Epoch 112/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2803 - iou_score: 0.7230 - f1-score: 0.8320 - precision: 0.8110 - recall: 0.8250 - val_loss: 0.2836 - val_iou_score: 0.7113 - val_f1-score: 0.8111 - val_precision: 0.8245 - val_recall: 0.7824
# Epoch 113/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3091 - iou_score: 0.7035 - f1-score: 0.8134 - precision: 0.7884 - recall: 0.8171 - val_loss: 0.2806 - val_iou_score: 0.7122 - val_f1-score: 0.8119 - val_precision: 0.8240 - val_recall: 0.7862
# Epoch 114/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2980 - iou_score: 0.7104 - f1-score: 0.8181 - precision: 0.8007 - recall: 0.8091 - val_loss: 0.2832 - val_iou_score: 0.7113 - val_f1-score: 0.8113 - val_precision: 0.8247 - val_recall: 0.7833
# Epoch 115/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2815 - iou_score: 0.7241 - f1-score: 0.8314 - precision: 0.8040 - recall: 0.8299 - val_loss: 0.2834 - val_iou_score: 0.7103 - val_f1-score: 0.8103 - val_precision: 0.8248 - val_recall: 0.7814
# Epoch 116/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2838 - iou_score: 0.7238 - f1-score: 0.8316 - precision: 0.8140 - recall: 0.8249 - val_loss: 0.2841 - val_iou_score: 0.7095 - val_f1-score: 0.8096 - val_precision: 0.8268 - val_recall: 0.7790
# Epoch 117/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3039 - iou_score: 0.7118 - f1-score: 0.8200 - precision: 0.7907 - recall: 0.8251 - val_loss: 0.2829 - val_iou_score: 0.7112 - val_f1-score: 0.8111 - val_precision: 0.8235 - val_recall: 0.7806
# Epoch 118/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2697 - iou_score: 0.7309 - f1-score: 0.8358 - precision: 0.8182 - recall: 0.8215 - val_loss: 0.2821 - val_iou_score: 0.7134 - val_f1-score: 0.8128 - val_precision: 0.8235 - val_recall: 0.7842
# Epoch 119/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3036 - iou_score: 0.7094 - f1-score: 0.8206 - precision: 0.7992 - recall: 0.8154 - val_loss: 0.2782 - val_iou_score: 0.7168 - val_f1-score: 0.8151 - val_precision: 0.8219 - val_recall: 0.7905
# Epoch 120/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3019 - iou_score: 0.7086 - f1-score: 0.8162 - precision: 0.7998 - recall: 0.8144 - val_loss: 0.2792 - val_iou_score: 0.7149 - val_f1-score: 0.8136 - val_precision: 0.8245 - val_recall: 0.7870
# Epoch 121/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2709 - iou_score: 0.7327 - f1-score: 0.8383 - precision: 0.8157 - recall: 0.8264 - val_loss: 0.2806 - val_iou_score: 0.7143 - val_f1-score: 0.8133 - val_precision: 0.8238 - val_recall: 0.7854
# Epoch 122/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2890 - iou_score: 0.7145 - f1-score: 0.8235 - precision: 0.7912 - recall: 0.8219 - val_loss: 0.2802 - val_iou_score: 0.7148 - val_f1-score: 0.8140 - val_precision: 0.8221 - val_recall: 0.7870
# Epoch 123/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2898 - iou_score: 0.7253 - f1-score: 0.8324 - precision: 0.8120 - recall: 0.8288 - val_loss: 0.2823 - val_iou_score: 0.7107 - val_f1-score: 0.8105 - val_precision: 0.8244 - val_recall: 0.7828
# Epoch 124/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2971 - iou_score: 0.7215 - f1-score: 0.8295 - precision: 0.8175 - recall: 0.8168 - val_loss: 0.2814 - val_iou_score: 0.7106 - val_f1-score: 0.8104 - val_precision: 0.8266 - val_recall: 0.7813
# Epoch 125/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3179 - iou_score: 0.7024 - f1-score: 0.8145 - precision: 0.7813 - recall: 0.8281 - val_loss: 0.2814 - val_iou_score: 0.7123 - val_f1-score: 0.8115 - val_precision: 0.8258 - val_recall: 0.7836
# Epoch 126/150
# 91/91 [==============================] - 9s 101ms/step - loss: 0.3000 - iou_score: 0.7131 - f1-score: 0.8234 - precision: 0.8062 - recall: 0.8172 - val_loss: 0.2807 - val_iou_score: 0.7140 - val_f1-score: 0.8135 - val_precision: 0.8222 - val_recall: 0.7890
# Epoch 127/150
# 91/91 [==============================] - 9s 101ms/step - loss: 0.2819 - iou_score: 0.7232 - f1-score: 0.8287 - precision: 0.7979 - recall: 0.8299 - val_loss: 0.2817 - val_iou_score: 0.7134 - val_f1-score: 0.8128 - val_precision: 0.8225 - val_recall: 0.7860
# Epoch 128/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2864 - iou_score: 0.7189 - f1-score: 0.8251 - precision: 0.7988 - recall: 0.8325 - val_loss: 0.2845 - val_iou_score: 0.7099 - val_f1-score: 0.8102 - val_precision: 0.8212 - val_recall: 0.7827
# Epoch 129/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2730 - iou_score: 0.7278 - f1-score: 0.8338 - precision: 0.7981 - recall: 0.8416 - val_loss: 0.2859 - val_iou_score: 0.7087 - val_f1-score: 0.8095 - val_precision: 0.8236 - val_recall: 0.7804
# Epoch 130/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3255 - iou_score: 0.7005 - f1-score: 0.8126 - precision: 0.8080 - recall: 0.7959 - val_loss: 0.2873 - val_iou_score: 0.7078 - val_f1-score: 0.8086 - val_precision: 0.8254 - val_recall: 0.7781
# Epoch 131/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2781 - iou_score: 0.7317 - f1-score: 0.8385 - precision: 0.8100 - recall: 0.8376 - val_loss: 0.2841 - val_iou_score: 0.7102 - val_f1-score: 0.8104 - val_precision: 0.8263 - val_recall: 0.7804
# Epoch 132/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2880 - iou_score: 0.7180 - f1-score: 0.8280 - precision: 0.7993 - recall: 0.8288 - val_loss: 0.2886 - val_iou_score: 0.7066 - val_f1-score: 0.8071 - val_precision: 0.8271 - val_recall: 0.7712
# Epoch 133/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3070 - iou_score: 0.7109 - f1-score: 0.8206 - precision: 0.8089 - recall: 0.8052 - val_loss: 0.2868 - val_iou_score: 0.7084 - val_f1-score: 0.8087 - val_precision: 0.8293 - val_recall: 0.7725
# Epoch 134/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3074 - iou_score: 0.6984 - f1-score: 0.8086 - precision: 0.8026 - recall: 0.8019 - val_loss: 0.2850 - val_iou_score: 0.7090 - val_f1-score: 0.8092 - val_precision: 0.8278 - val_recall: 0.7774
# Epoch 135/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2756 - iou_score: 0.7224 - f1-score: 0.8289 - precision: 0.8009 - recall: 0.8306 - val_loss: 0.2874 - val_iou_score: 0.7081 - val_f1-score: 0.8085 - val_precision: 0.8277 - val_recall: 0.7745
# Epoch 136/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3065 - iou_score: 0.7001 - f1-score: 0.8051 - precision: 0.7844 - recall: 0.8077 - val_loss: 0.2858 - val_iou_score: 0.7075 - val_f1-score: 0.8082 - val_precision: 0.8251 - val_recall: 0.7781
# Epoch 137/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2869 - iou_score: 0.7158 - f1-score: 0.8247 - precision: 0.7900 - recall: 0.8310 - val_loss: 0.2791 - val_iou_score: 0.7161 - val_f1-score: 0.8148 - val_precision: 0.8219 - val_recall: 0.7891
# Epoch 138/150
# 91/91 [==============================] - 9s 102ms/step - loss: 0.2875 - iou_score: 0.7268 - f1-score: 0.8340 - precision: 0.8176 - recall: 0.8233 - val_loss: 0.2794 - val_iou_score: 0.7140 - val_f1-score: 0.8128 - val_precision: 0.8249 - val_recall: 0.7855
# Epoch 139/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2902 - iou_score: 0.7163 - f1-score: 0.8284 - precision: 0.8096 - recall: 0.8196 - val_loss: 0.2825 - val_iou_score: 0.7123 - val_f1-score: 0.8122 - val_precision: 0.8242 - val_recall: 0.7850
# Epoch 140/150
# 91/91 [==============================] - 9s 98ms/step - loss: 0.2896 - iou_score: 0.7193 - f1-score: 0.8259 - precision: 0.8037 - recall: 0.8276 - val_loss: 0.2812 - val_iou_score: 0.7135 - val_f1-score: 0.8131 - val_precision: 0.8245 - val_recall: 0.7852
# Epoch 141/150
# 91/91 [==============================] - 9s 98ms/step - loss: 0.2818 - iou_score: 0.7167 - f1-score: 0.8268 - precision: 0.8006 - recall: 0.8235 - val_loss: 0.2842 - val_iou_score: 0.7112 - val_f1-score: 0.8111 - val_precision: 0.8262 - val_recall: 0.7826
# Epoch 142/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.3115 - iou_score: 0.7116 - f1-score: 0.8182 - precision: 0.7904 - recall: 0.8217 - val_loss: 0.2836 - val_iou_score: 0.7104 - val_f1-score: 0.8104 - val_precision: 0.8230 - val_recall: 0.7804
# Epoch 143/150
# 91/91 [==============================] - 9s 98ms/step - loss: 0.2979 - iou_score: 0.7152 - f1-score: 0.8199 - precision: 0.7987 - recall: 0.8201 - val_loss: 0.2832 - val_iou_score: 0.7121 - val_f1-score: 0.8118 - val_precision: 0.8268 - val_recall: 0.7807
# Epoch 144/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2614 - iou_score: 0.7397 - f1-score: 0.8418 - precision: 0.8158 - recall: 0.8401 - val_loss: 0.2867 - val_iou_score: 0.7073 - val_f1-score: 0.8077 - val_precision: 0.8279 - val_recall: 0.7731
# Epoch 145/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3008 - iou_score: 0.7075 - f1-score: 0.8204 - precision: 0.7917 - recall: 0.8317 - val_loss: 0.2824 - val_iou_score: 0.7114 - val_f1-score: 0.8108 - val_precision: 0.8261 - val_recall: 0.7831
# Epoch 146/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3211 - iou_score: 0.6953 - f1-score: 0.8022 - precision: 0.7846 - recall: 0.8025 - val_loss: 0.2794 - val_iou_score: 0.7160 - val_f1-score: 0.8144 - val_precision: 0.8229 - val_recall: 0.7882
# Epoch 147/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2845 - iou_score: 0.7247 - f1-score: 0.8325 - precision: 0.8143 - recall: 0.8242 - val_loss: 0.2853 - val_iou_score: 0.7091 - val_f1-score: 0.8093 - val_precision: 0.8245 - val_recall: 0.7797
# Epoch 148/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.2997 - iou_score: 0.7116 - f1-score: 0.8202 - precision: 0.7969 - recall: 0.8192 - val_loss: 0.2832 - val_iou_score: 0.7107 - val_f1-score: 0.8105 - val_precision: 0.8237 - val_recall: 0.7830
# Epoch 149/150
# 91/91 [==============================] - 9s 100ms/step - loss: 0.3103 - iou_score: 0.6991 - f1-score: 0.8112 - precision: 0.7915 - recall: 0.8161 - val_loss: 0.2839 - val_iou_score: 0.7102 - val_f1-score: 0.8103 - val_precision: 0.8241 - val_recall: 0.7818
# Epoch 150/150
# 91/91 [==============================] - 9s 99ms/step - loss: 0.2841 - iou_score: 0.7215 - f1-score: 0.8270 - precision: 0.8092 - recall: 0.8186 - val_loss: 0.2808 - val_iou_score: 0.7144 - val_f1-score: 0.8135 - val_precision: 0.8237 - val_recall: 0.7867

# %%
# Plot training & validation iou_score values
plt.figure(figsize=(30, 5))
plt.subplot(221)
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(222)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.figure(figsize=(30, 5))
plt.subplot(223)
plt.plot(history.history['f1-score'])
plt.plot(history.history['val_f1-score'])
plt.title('Model f1-score')
plt.ylabel('f1-score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
test_dataset = Dataset(
    x_test_dir, 
    y_test_dir, 
    classes=CLASSES, 
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

test_dataloader = Dataloder(test_dataset, batch_size=1, shuffle=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/albumentations/augmentations/transforms.py:2910: UserWarning: Using lambda is incompatible with multiprocessing. Consider using regular functions or partial().
#   "Using lambda is incompatible with multiprocessing. "

# %%
# load best weights
model.load_weights('best_model.h5')

# %%
##executing time=1.382s
scores = model.evaluate_generator(test_dataloader)

print("Loss: {:.5}".format(scores[0]))
for metric, value in zip(metrics, scores[1:]):
    print("mean {}: {:.5}".format(metric.__name__, value))
# Out:
# Loss: 0.28153
# mean iou_score: 0.80522
# mean f1-score: 0.88608
# mean precision: 0.83283
# mean recall: 0.92062

# %%
import numpy
for idx, img_name in enumerate(sorted(os.listdir(x_test_dir))):
  image, gt_mask = test_dataset[idx]
  print(img_name)
  image = np.expand_dims(image, axis=0)
  pr_mask = model.predict(image).round()
  out_arr = numpy.squeeze(pr_mask)  
  cv2.imwrite('/content/resault/{}'.format(img_name),out_arr)
  print(out_arr.shape)
  visualize(
      image=denormalize(image.squeeze()),
      gt_mask=gt_mask[..., 0].squeeze(),
      pr_mask=pr_mask[..., 0].squeeze(),
      )
# Out:
# drishtiGS_001.png
# (128, 128)
# drishtiGS_002.png
# (128, 128)
# drishtiGS_003.png
# (128, 128)
# drishtiGS_004.png
# (128, 128)
# drishtiGS_005.png
# (128, 128)
# drishtiGS_006.png
# (128, 128)
# drishtiGS_007.png
# (128, 128)
# drishtiGS_008.png
# (128, 128)
# drishtiGS_009.png
# (128, 128)
# drishtiGS_010.png
# (128, 128)
# drishtiGS_011.png
# (128, 128)
# drishtiGS_012.png
# (128, 128)
# drishtiGS_013.png
# (128, 128)
# drishtiGS_014.png
# (128, 128)
# drishtiGS_017.png
# (128, 128)

# %%
# !zip -r /content/resualt_cup_drishti.zip /content/resault
# Out:
#   adding: content/resault/ (stored 0%)
#   adding: content/resault/drishtiGS_009.png (deflated 11%)
#   adding: content/resault/drishtiGS_014.png (deflated 19%)
#   adding: content/resault/drishtiGS_017.png (deflated 20%)
#   adding: content/resault/drishtiGS_004.png (deflated 16%)
#   adding: content/resault/drishtiGS_011.png (deflated 22%)
#   adding: content/resault/drishtiGS_006.png (deflated 19%)
#   adding: content/resault/drishtiGS_005.png (deflated 12%)
#   adding: content/resault/drishtiGS_001.png (deflated 32%)
#   adding: content/resault/drishtiGS_010.png (deflated 11%)
#   adding: content/resault/drishtiGS_007.png (deflated 16%)
#   adding: content/resault/drishtiGS_008.png (deflated 18%)
#   adding: content/resault/drishtiGS_003.png (deflated 26%)
#   adding: content/resault/drishtiGS_012.png (deflated 12%)
#   adding: content/resault/drishtiGS_013.png (deflated 12%)
#   adding: content/resault/drishtiGS_002.png (deflated 14%)

# %%
###when we do not use preprocessing for dataset loader
from PIL import Image
import numpy as np
for i in range(39):
  image, gt_mask = test_dataset[i]
  print(image.size)
  img = Image.fromarray(image)
  img.save('/content/resault/{}.png'.format(i))
  img.show()

# %%
for idx, img_name in enumerate(sorted(os.listdir(x_test_dir))):
  print(img_name)
