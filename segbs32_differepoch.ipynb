# %% [markdown]
# <a href="https://colab.research.google.com/github/fambargh/projectmastery/blob/master/segbs32_differepoch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install -U git+https://github.com/albu/albumentations --no-cache-dir
# Out:
# Collecting git+https://github.com/albu/albumentations
#   Cloning https://github.com/albu/albumentations to /tmp/pip-req-build-c8fc0eci
#   Running command git clone -q https://github.com/albu/albumentations /tmp/pip-req-build-c8fc0eci
# Requirement already satisfied, skipping upgrade: numpy>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (1.17.4)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (1.3.3)
# Requirement already satisfied, skipping upgrade: imgaug<0.2.7,>=0.2.5 in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (0.2.6)
# Requirement already satisfied, skipping upgrade: PyYAML in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (3.13)
# Requirement already satisfied, skipping upgrade: opencv-python>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (4.1.2.30)
# Requirement already satisfied, skipping upgrade: scikit-image>=0.11.0 in /usr/local/lib/python3.6/dist-packages (from imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (0.15.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (1.12.0)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (1.1.1)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.4)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (4.3.0)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (3.1.2)
# Requirement already satisfied, skipping upgrade: imageio>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.4.1)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (4.4.1)
# Requirement already satisfied, skipping upgrade: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=4.3.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (0.46)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.6.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.4.5)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (1.1.0)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from kiwisolver>=1.0.1->matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (42.0.2)
# Building wheels for collected packages: albumentations
#   Building wheel for albumentations (setup.py) ... done
#   Created wheel for albumentations: filename=albumentations-0.4.4-cp36-none-any.whl size=61995 sha256=caf7a787f6cf7f8e145568b77fdc1701a3ce58c2602161379034e5d52d05be94
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ytzgs6ch/wheels/45/8b/e4/2837bbcf517d00732b8e394f8646f22b8723ac00993230188b
# Successfully built albumentations
# Installing collected packages: albumentations
#   Found existing installation: albumentations 0.4.4
#     Uninstalling albumentations-0.4.4:
#       Successfully uninstalled albumentations-0.4.4
# Successfully installed albumentations-0.4.4

# %%
# Install required libs
# !pip install -U --pre segmentation-models --user
# Out:
# Collecting segmentation-models
#   Downloading https://files.pythonhosted.org/packages/70/14/090ea95a4f69c453731d9df3feff0a08e0dea0e8dff932dc4839ec4dab5c/segmentation_models-1.0.0-py3-none-any.whl
# Collecting image-classifiers==1.0.0
#   Downloading https://files.pythonhosted.org/packages/81/98/6f84720e299a4942ab80df5f76ab97b7828b24d1de5e9b2cbbe6073228b7/image_classifiers-1.0.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from segmentation-models) (1.0.8)
# Collecting efficientnet==1.0.0
#   Downloading https://files.pythonhosted.org/packages/97/82/f3ae07316f0461417dc54affab6e86ab188a5a22f33176d35271628b96e0/efficientnet-1.0.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.17.4)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (2.8.0)
# Requirement already satisfied, skipping upgrade: scikit-image in /usr/local/lib/python3.6/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.15.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.12.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.3.3)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1.2)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.4)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (4.3.0)
# Requirement already satisfied, skipping upgrade: imageio>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.4.1)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.1.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (1.1.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.4.5)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.6.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (0.10.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image->efficientnet==1.0.0->segmentation-models) (4.4.1)
# Requirement already satisfied, skipping upgrade: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=4.3.0->scikit-image->efficientnet==1.0.0->segmentation-models) (0.46)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from kiwisolver>=1.0.1->matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (42.0.2)
# Installing collected packages: image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 segmentation-models-1.0.0

# %%
from zipfile import ZipFile
filename = "image.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
from zipfile import ZipFile
filename = "annotate_cup3.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
import os
import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
x_train_dir = '/content/image_train/'
y_train_dir = '/content/annotate_cup3/annotate_cup_train/'

x_valid_dir = '/content/image_valid/'
y_valid_dir = '/content/annotate_cup3/annotate_cup_valid'

x_test_dir = '/content/image_test/'
y_test_dir = '/content/annotate_cup3/annotate_cup_test/'

# %%
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x
    

# classes for data loading and preprocessing
class Dataset:
    """ Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    CLASSES = ['bg', 'oc','nolabeled']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        self.ids = os.listdir(images_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id) for image_id in self.ids]
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)
        
        # extract certain classes from mask (e.g. oc)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # add background if mask is not binary
        if mask.shape[-1] != 1:
            background = 1 - mask.sum(axis=-1, keepdims=True)
            mask = np.concatenate((mask, background), axis=-1)
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)
    
    
class Dataloder(keras.utils.Sequence):
    """Load data from dataset and form batches
    
    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integet number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """
    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

        self.on_epoch_end()

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        # transpose list of lists
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        return batch
    
    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# Lets look at data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['bg','oc','nolabeled'])

image, mask = dataset[5] # get some sample
visualize(
    image=image, 
    bg_mask=mask[..., 0].squeeze(),
    OC_mask=mask[..., 1].squeeze(),
    no_labeled_mask=mask[..., 2].squeeze(),
    background_mask=mask[..., 3].squeeze(),
)

# %%
import albumentations as A

# %%
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# define heavy augmentations
def get_training_augmentation():
    train_transform = [

        A.HorizontalFlip(p=0.5),

        A.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, shift_limit=0.1, p=1, border_mode=0),

        A.PadIfNeeded(min_height=128, min_width=128, always_apply=True, border_mode=0),
        A.RandomCrop(height=128, width=128, always_apply=True),

        A.IAAAdditiveGaussianNoise(p=0.2),
        A.IAAPerspective(p=0.5),

        A.OneOf(
            [
                A.CLAHE(p=1),
                A.RandomBrightness(p=1),
                A.RandomGamma(p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.IAASharpen(p=1),
                A.Blur(blur_limit=3, p=1),
                A.MotionBlur(blur_limit=3, p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.RandomContrast(p=1),
                A.HueSaturationValue(p=1),
            ],
            p=0.9,
        ),
        A.Lambda(mask=round_clip_0_1)
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 128"""
    test_transform = [
        A.PadIfNeeded(128, 128)
    ]
    return A.Compose(test_transform)

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

# %%
# Lets look at augmented data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['bg', 'oc','nolabeled'], augmentation=get_training_augmentation())

image, mask = dataset[12] # get some sample
visualize(
    image=image, 
    bg_mask=mask[..., 0].squeeze(),
    OC_mask=mask[..., 1].squeeze(),
    no_labeled_mask=mask[..., 2].squeeze(),
    background_mask=mask[..., 3].squeeze(),
)
# Out:
# /usr/local/lib/python3.6/dist-packages/albumentations/augmentations/transforms.py:2910: UserWarning: Using lambda is incompatible with multiprocessing. Consider using regular functions or partial().
#   "Using lambda is incompatible with multiprocessing. "

# %%
import segmentation_models as sm
# Out:
# Segmentation Models: using `keras` framework.

# %%
BACKBONE = 'seresnet50'
BATCH_SIZE = 32
CLASSES = ['oc']
#LR = 0.01
#EPOCHS = 2
preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
assert train_dataloader[0][0].shape == (BATCH_SIZE, 128, 128, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 128, 128, n_classes)

# define callbacks for learning rate scheduling and best checkpoints saving
callbacks = [
    keras.callbacks.ModelCheckpoint('./best_model.h5', save_weights_only=True, save_best_only=True, mode='min'),
    keras.callbacks.ReduceLROnPlateau(),
]
# Out:
# /usr/local/lib/python3.6/dist-packages/albumentations/augmentations/transforms.py:2910: UserWarning: Using lambda is incompatible with multiprocessing. Consider using regular functions or partial().
#   "Using lambda is incompatible with multiprocessing. "

# %%
# study of eppoch number on metrics for segmentation problem
from keras.optimizers import SGD
from matplotlib import pyplot


# fit a model and plot learning curve
def fit_model(train_data, validimage,EPOCHS):
  # define network parameters
  n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
  activation = 'sigmoid' if n_classes == 1 else 'softmax'
  # define model
  model = sm.Unet(BACKBONE, classes=n_classes, activation=activation)
  opt = SGD()
  dice_loss = sm.losses.DiceLoss()
  focal_loss = sm.losses.BinaryFocalLoss() 
  total_loss = dice_loss + (1 * focal_loss)
  metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]
  model.compile(opt, total_loss, metrics)
  # fit model
  history = model.fit_generator(train_dataloader, 
                                steps_per_epoch=len(train_data), 
                                epochs=EPOCHS, 
                                #callbacks=callbacks, 
                                validation_data=validimage, 
                                validation_steps=len(validimage),
                                )
  # plot learning curves
  pyplot.plot(history.history['f1-score'], label='train')
  pyplot.plot(history.history['val_f1-score'], label='test')
  pyplot.title('f1_score_for_BS32_for_epochnum.='+str(EPOCHS), pad=-50)
  plt.ylabel('f1_score')
  plt.legend(['Train', 'Test'], loc='upper left')

# create learning curves for different epoch numbers
EPOCHS = [10,20,30,40,60,80,100]
for i in range(len(EPOCHS)):
  plt.figure(figsize=(30, 25))
  # determine the plot number
  plot_no = 420 + (i+1)
  pyplot.subplot(plot_no)
  # fit model and plot learning curves for an epoch number
  fit_model(train_dataloader, valid_dataloader, EPOCHS[i])
# show learning curves
pyplot.show()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/seresnet50_imagenet_1000_no_top.h5
# 104939520/104934688 [==============================] - 5s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/10
# 5/5 [==============================] - 26s 5s/step - loss: 1.7030 - iou_score: 0.1740 - f1-score: 0.2914 - val_loss: 1.5980 - val_iou_score: 0.1716 - val_f1-score: 0.2681
# Epoch 2/10
# 5/5 [==============================] - 4s 847ms/step - loss: 1.3925 - iou_score: 0.2558 - f1-score: 0.4050 - val_loss: 1.4588 - val_iou_score: 0.2145 - val_f1-score: 0.3208
# Epoch 3/10
# 5/5 [==============================] - 4s 842ms/step - loss: 1.2290 - iou_score: 0.3130 - f1-score: 0.4759 - val_loss: 1.4051 - val_iou_score: 0.2271 - val_f1-score: 0.3345
# Epoch 4/10
# 5/5 [==============================] - 4s 856ms/step - loss: 1.1783 - iou_score: 0.3031 - f1-score: 0.4646 - val_loss: 1.3905 - val_iou_score: 0.2278 - val_f1-score: 0.3354
# Epoch 5/10
# 5/5 [==============================] - 4s 846ms/step - loss: 1.0843 - iou_score: 0.3442 - f1-score: 0.5099 - val_loss: 1.3972 - val_iou_score: 0.2290 - val_f1-score: 0.3383
# Epoch 6/10
# 5/5 [==============================] - 4s 847ms/step - loss: 1.0335 - iou_score: 0.3619 - f1-score: 0.5303 - val_loss: 1.3703 - val_iou_score: 0.2356 - val_f1-score: 0.3467
# Epoch 7/10
# 5/5 [==============================] - 4s 849ms/step - loss: 0.9759 - iou_score: 0.3980 - f1-score: 0.5686 - val_loss: 1.3299 - val_iou_score: 0.2419 - val_f1-score: 0.3515
# Epoch 8/10
# 5/5 [==============================] - 4s 849ms/step - loss: 0.9324 - iou_score: 0.4071 - f1-score: 0.5761 - val_loss: 1.2751 - val_iou_score: 0.2512 - val_f1-score: 0.3610
# Epoch 9/10
# 5/5 [==============================] - 4s 846ms/step - loss: 0.9258 - iou_score: 0.3877 - f1-score: 0.5573 - val_loss: 1.2188 - val_iou_score: 0.2608 - val_f1-score: 0.3714
# Epoch 10/10
# 5/5 [==============================] - 4s 848ms/step - loss: 0.9022 - iou_score: 0.4029 - f1-score: 0.5730 - val_loss: 1.2023 - val_iou_score: 0.2732 - val_f1-score: 0.3880
# Epoch 1/20
# 5/5 [==============================] - 20s 4s/step - loss: 1.8347 - iou_score: 0.1328 - f1-score: 0.2311 - val_loss: 1.7489 - val_iou_score: 0.1040 - val_f1-score: 0.1722
# Epoch 2/20
# 5/5 [==============================] - 4s 856ms/step - loss: 1.4424 - iou_score: 0.2537 - f1-score: 0.4040 - val_loss: 1.5474 - val_iou_score: 0.1572 - val_f1-score: 0.2475
# Epoch 3/20
# 5/5 [==============================] - 4s 858ms/step - loss: 1.2727 - iou_score: 0.2944 - f1-score: 0.4525 - val_loss: 1.4562 - val_iou_score: 0.1948 - val_f1-score: 0.2936
# Epoch 4/20
# 5/5 [==============================] - 4s 856ms/step - loss: 1.1612 - iou_score: 0.3282 - f1-score: 0.4930 - val_loss: 1.3793 - val_iou_score: 0.2178 - val_f1-score: 0.3178
# Epoch 5/20
# 5/5 [==============================] - 4s 855ms/step - loss: 1.0902 - iou_score: 0.3552 - f1-score: 0.5226 - val_loss: 1.3131 - val_iou_score: 0.2320 - val_f1-score: 0.3306
# Epoch 6/20
# 5/5 [==============================] - 4s 861ms/step - loss: 1.0642 - iou_score: 0.3437 - f1-score: 0.5096 - val_loss: 1.2640 - val_iou_score: 0.2415 - val_f1-score: 0.3399
# Epoch 7/20
# 5/5 [==============================] - 4s 857ms/step - loss: 0.9560 - iou_score: 0.4314 - f1-score: 0.6027 - val_loss: 1.2461 - val_iou_score: 0.2496 - val_f1-score: 0.3519
# Epoch 8/20
# 5/5 [==============================] - 4s 868ms/step - loss: 0.9203 - iou_score: 0.4348 - f1-score: 0.6039 - val_loss: 1.1790 - val_iou_score: 0.2648 - val_f1-score: 0.3670
# Epoch 9/20
# 5/5 [==============================] - 4s 859ms/step - loss: 0.8914 - iou_score: 0.4367 - f1-score: 0.6065 - val_loss: 1.1616 - val_iou_score: 0.2702 - val_f1-score: 0.3756
# Epoch 10/20
# 5/5 [==============================] - 4s 853ms/step - loss: 0.8365 - iou_score: 0.4724 - f1-score: 0.6401 - val_loss: 1.1176 - val_iou_score: 0.2882 - val_f1-score: 0.3975
# Epoch 11/20
# 5/5 [==============================] - 4s 851ms/step - loss: 0.7770 - iou_score: 0.5105 - f1-score: 0.6746 - val_loss: 1.0861 - val_iou_score: 0.3018 - val_f1-score: 0.4140
# Epoch 12/20
# 5/5 [==============================] - 4s 853ms/step - loss: 0.7045 - iou_score: 0.5619 - f1-score: 0.7188 - val_loss: 1.0911 - val_iou_score: 0.3024 - val_f1-score: 0.4150
# Epoch 13/20
# 5/5 [==============================] - 4s 842ms/step - loss: 0.7044 - iou_score: 0.5445 - f1-score: 0.7033 - val_loss: 1.0451 - val_iou_score: 0.3263 - val_f1-score: 0.4413
# Epoch 14/20
# 5/5 [==============================] - 4s 858ms/step - loss: 0.6448 - iou_score: 0.5867 - f1-score: 0.7394 - val_loss: 1.0319 - val_iou_score: 0.3457 - val_f1-score: 0.4602
# Epoch 15/20
# 5/5 [==============================] - 4s 855ms/step - loss: 0.5880 - iou_score: 0.6270 - f1-score: 0.7693 - val_loss: 1.0256 - val_iou_score: 0.3517 - val_f1-score: 0.4675
# Epoch 16/20
# 5/5 [==============================] - 4s 854ms/step - loss: 0.5450 - iou_score: 0.6422 - f1-score: 0.7807 - val_loss: 1.0539 - val_iou_score: 0.3511 - val_f1-score: 0.4663
# Epoch 17/20
# 5/5 [==============================] - 4s 846ms/step - loss: 0.5023 - iou_score: 0.6690 - f1-score: 0.8010 - val_loss: 1.0609 - val_iou_score: 0.3524 - val_f1-score: 0.4694
# Epoch 18/20
# 5/5 [==============================] - 4s 847ms/step - loss: 0.5402 - iou_score: 0.6285 - f1-score: 0.7712 - val_loss: 0.9695 - val_iou_score: 0.3763 - val_f1-score: 0.4908
# Epoch 19/20
# 5/5 [==============================] - 4s 855ms/step - loss: 0.5072 - iou_score: 0.6468 - f1-score: 0.7853 - val_loss: 0.9591 - val_iou_score: 0.3706 - val_f1-score: 0.4886
# Epoch 20/20
# 5/5 [==============================] - 4s 858ms/step - loss: 0.4866 - iou_score: 0.6522 - f1-score: 0.7883 - val_loss: 0.9323 - val_iou_score: 0.3843 - val_f1-score: 0.5009
# Epoch 1/30
# 5/5 [==============================] - 23s 5s/step - loss: 2.2887 - iou_score: 0.0843 - f1-score: 0.1539 - val_loss: 1.8848 - val_iou_score: 0.1006 - val_f1-score: 0.1652
# Epoch 2/30
# 5/5 [==============================] - 4s 853ms/step - loss: 1.6778 - iou_score: 0.1914 - f1-score: 0.3188 - val_loss: 1.6162 - val_iou_score: 0.1486 - val_f1-score: 0.2338
# Epoch 3/30
# 5/5 [==============================] - 4s 856ms/step - loss: 1.4446 - iou_score: 0.2570 - f1-score: 0.4082 - val_loss: 1.4728 - val_iou_score: 0.1846 - val_f1-score: 0.2801
# Epoch 4/30
# 5/5 [==============================] - 4s 851ms/step - loss: 1.3028 - iou_score: 0.2848 - f1-score: 0.4427 - val_loss: 1.3912 - val_iou_score: 0.2105 - val_f1-score: 0.3106
# Epoch 5/30
# 5/5 [==============================] - 4s 856ms/step - loss: 1.2377 - iou_score: 0.2601 - f1-score: 0.4087 - val_loss: 1.3369 - val_iou_score: 0.2283 - val_f1-score: 0.3317
# Epoch 6/30
# 5/5 [==============================] - 4s 857ms/step - loss: 1.1354 - iou_score: 0.3202 - f1-score: 0.4829 - val_loss: 1.2992 - val_iou_score: 0.2434 - val_f1-score: 0.3504
# Epoch 7/30
# 5/5 [==============================] - 4s 857ms/step - loss: 1.0384 - iou_score: 0.3930 - f1-score: 0.5633 - val_loss: 1.2632 - val_iou_score: 0.2529 - val_f1-score: 0.3627
# Epoch 8/30
# 5/5 [==============================] - 4s 850ms/step - loss: 0.9760 - iou_score: 0.4209 - f1-score: 0.5887 - val_loss: 1.2371 - val_iou_score: 0.2563 - val_f1-score: 0.3676
# Epoch 9/30
# 5/5 [==============================] - 4s 850ms/step - loss: 0.9119 - iou_score: 0.4523 - f1-score: 0.6208 - val_loss: 1.1956 - val_iou_score: 0.2688 - val_f1-score: 0.3825
# Epoch 10/30
# 5/5 [==============================] - 4s 849ms/step - loss: 0.8883 - iou_score: 0.4572 - f1-score: 0.6245 - val_loss: 1.1289 - val_iou_score: 0.2903 - val_f1-score: 0.4039
# Epoch 11/30
# 5/5 [==============================] - 4s 855ms/step - loss: 0.7916 - iou_score: 0.5410 - f1-score: 0.6992 - val_loss: 1.1331 - val_iou_score: 0.2965 - val_f1-score: 0.4146
# Epoch 12/30
# 5/5 [==============================] - 4s 855ms/step - loss: 0.7418 - iou_score: 0.5550 - f1-score: 0.7112 - val_loss: 1.0569 - val_iou_score: 0.3307 - val_f1-score: 0.4494
# Epoch 13/30
# 5/5 [==============================] - 4s 861ms/step - loss: 0.6869 - iou_score: 0.5805 - f1-score: 0.7338 - val_loss: 1.0134 - val_iou_score: 0.3517 - val_f1-score: 0.4711
# Epoch 14/30
# 5/5 [==============================] - 4s 851ms/step - loss: 0.6209 - iou_score: 0.6225 - f1-score: 0.7653 - val_loss: 1.0299 - val_iou_score: 0.3460 - val_f1-score: 0.4704
# Epoch 15/30
# 5/5 [==============================] - 4s 853ms/step - loss: 0.5910 - iou_score: 0.6260 - f1-score: 0.7692 - val_loss: 1.0890 - val_iou_score: 0.3327 - val_f1-score: 0.4560
# Epoch 16/30
# 5/5 [==============================] - 4s 859ms/step - loss: 0.5515 - iou_score: 0.6516 - f1-score: 0.7873 - val_loss: 1.0523 - val_iou_score: 0.3602 - val_f1-score: 0.4855
# Epoch 17/30
# 5/5 [==============================] - 4s 862ms/step - loss: 0.5101 - iou_score: 0.6737 - f1-score: 0.8048 - val_loss: 0.9574 - val_iou_score: 0.3849 - val_f1-score: 0.5048
# Epoch 18/30
# 5/5 [==============================] - 4s 857ms/step - loss: 0.4927 - iou_score: 0.6772 - f1-score: 0.8073 - val_loss: 0.9493 - val_iou_score: 0.3983 - val_f1-score: 0.5220
# Epoch 19/30
# 5/5 [==============================] - 4s 855ms/step - loss: 0.4824 - iou_score: 0.6760 - f1-score: 0.8059 - val_loss: 1.0047 - val_iou_score: 0.3931 - val_f1-score: 0.5251
# Epoch 20/30
# 5/5 [==============================] - 4s 853ms/step - loss: 0.5093 - iou_score: 0.6435 - f1-score: 0.7809 - val_loss: 0.9466 - val_iou_score: 0.4143 - val_f1-score: 0.5457
# Epoch 21/30
# 5/5 [==============================] - 4s 853ms/step - loss: 0.4554 - iou_score: 0.6805 - f1-score: 0.8097 - val_loss: 0.8331 - val_iou_score: 0.4216 - val_f1-score: 0.5441
# Epoch 22/30
# 5/5 [==============================] - 4s 857ms/step - loss: 0.4154 - iou_score: 0.7126 - f1-score: 0.8321 - val_loss: 0.9401 - val_iou_score: 0.4196 - val_f1-score: 0.5553
# Epoch 23/30
# 5/5 [==============================] - 4s 851ms/step - loss: 0.4400 - iou_score: 0.6816 - f1-score: 0.8100 - val_loss: 0.7768 - val_iou_score: 0.4254 - val_f1-score: 0.5315
# Epoch 24/30
# 5/5 [==============================] - 4s 858ms/step - loss: 0.4368 - iou_score: 0.6966 - f1-score: 0.8207 - val_loss: 0.8301 - val_iou_score: 0.4459 - val_f1-score: 0.5759
# Epoch 25/30
# 5/5 [==============================] - 4s 855ms/step - loss: 0.4083 - iou_score: 0.7024 - f1-score: 0.8248 - val_loss: 0.7799 - val_iou_score: 0.4647 - val_f1-score: 0.5990
# Epoch 26/30
# 5/5 [==============================] - 4s 860ms/step - loss: 0.4043 - iou_score: 0.7009 - f1-score: 0.8237 - val_loss: 0.7971 - val_iou_score: 0.4768 - val_f1-score: 0.6129
# Epoch 27/30
# 5/5 [==============================] - 4s 858ms/step - loss: 0.4061 - iou_score: 0.6914 - f1-score: 0.8172 - val_loss: 0.7290 - val_iou_score: 0.4857 - val_f1-score: 0.6181
# Epoch 28/30
# 5/5 [==============================] - 4s 854ms/step - loss: 0.3832 - iou_score: 0.7128 - f1-score: 0.8320 - val_loss: 0.7265 - val_iou_score: 0.4602 - val_f1-score: 0.5799
# Epoch 29/30
# 5/5 [==============================] - 4s 853ms/step - loss: 0.3683 - iou_score: 0.7228 - f1-score: 0.8390 - val_loss: 0.6915 - val_iou_score: 0.5060 - val_f1-score: 0.6377
# Epoch 30/30
# 5/5 [==============================] - 4s 854ms/step - loss: 0.3730 - iou_score: 0.7129 - f1-score: 0.8321 - val_loss: 0.6554 - val_iou_score: 0.5059 - val_f1-score: 0.6288
# Epoch 1/40
# 5/5 [==============================] - 25s 5s/step - loss: 1.5052 - iou_score: 0.1461 - f1-score: 0.2528 - val_loss: 1.5510 - val_iou_score: 0.1332 - val_f1-score: 0.2169
# Epoch 2/40
# 5/5 [==============================] - 4s 859ms/step - loss: 1.3258 - iou_score: 0.2017 - f1-score: 0.3350 - val_loss: 1.4539 - val_iou_score: 0.1673 - val_f1-score: 0.2637
# Epoch 3/40
# 5/5 [==============================] - 4s 862ms/step - loss: 1.2031 - iou_score: 0.2748 - f1-score: 0.4310 - val_loss: 1.3865 - val_iou_score: 0.1959 - val_f1-score: 0.2987
# Epoch 4/40
# 5/5 [==============================] - 4s 858ms/step - loss: 1.1519 - iou_score: 0.2863 - f1-score: 0.4444 - val_loss: 1.3526 - val_iou_score: 0.2099 - val_f1-score: 0.3158
# Epoch 5/40
# 5/5 [==============================] - 4s 861ms/step - loss: 1.0775 - iou_score: 0.3409 - f1-score: 0.5079 - val_loss: 1.3112 - val_iou_score: 0.2262 - val_f1-score: 0.3352
# Epoch 6/40
# 5/5 [==============================] - 4s 854ms/step - loss: 1.0341 - iou_score: 0.3705 - f1-score: 0.5391 - val_loss: 1.2757 - val_iou_score: 0.2339 - val_f1-score: 0.3444
# Epoch 7/40
# 5/5 [==============================] - 4s 865ms/step - loss: 0.9863 - iou_score: 0.3824 - f1-score: 0.5523 - val_loss: 1.2494 - val_iou_score: 0.2427 - val_f1-score: 0.3549
# Epoch 8/40
# 5/5 [==============================] - 4s 873ms/step - loss: 0.9512 - iou_score: 0.3844 - f1-score: 0.5549 - val_loss: 1.2106 - val_iou_score: 0.2545 - val_f1-score: 0.3685
# Epoch 9/40
# 5/5 [==============================] - 4s 865ms/step - loss: 0.8988 - iou_score: 0.4258 - f1-score: 0.5961 - val_loss: 1.1763 - val_iou_score: 0.2607 - val_f1-score: 0.3754
# Epoch 10/40
# 5/5 [==============================] - 4s 859ms/step - loss: 0.8713 - iou_score: 0.4553 - f1-score: 0.6231 - val_loss: 1.1203 - val_iou_score: 0.2751 - val_f1-score: 0.3918
# Epoch 11/40
# 5/5 [==============================] - 4s 856ms/step - loss: 0.8603 - iou_score: 0.4522 - f1-score: 0.6216 - val_loss: 1.0904 - val_iou_score: 0.2828 - val_f1-score: 0.4010
# Epoch 12/40
# 5/5 [==============================] - 4s 865ms/step - loss: 0.7705 - iou_score: 0.5254 - f1-score: 0.6878 - val_loss: 1.0775 - val_iou_score: 0.2918 - val_f1-score: 0.4113
# Epoch 13/40
# 5/5 [==============================] - 4s 866ms/step - loss: 0.7004 - iou_score: 0.5747 - f1-score: 0.7288 - val_loss: 1.0147 - val_iou_score: 0.3203 - val_f1-score: 0.4425
# Epoch 14/40
# 5/5 [==============================] - 4s 868ms/step - loss: 0.6604 - iou_score: 0.5825 - f1-score: 0.7360 - val_loss: 0.9925 - val_iou_score: 0.3402 - val_f1-score: 0.4625
# Epoch 15/40
# 5/5 [==============================] - 4s 865ms/step - loss: 0.6024 - iou_score: 0.6355 - f1-score: 0.7760 - val_loss: 0.9392 - val_iou_score: 0.3558 - val_f1-score: 0.4779
# Epoch 16/40
# 5/5 [==============================] - 4s 859ms/step - loss: 0.5974 - iou_score: 0.6162 - f1-score: 0.7620 - val_loss: 0.9723 - val_iou_score: 0.3596 - val_f1-score: 0.4849
# Epoch 17/40
# 5/5 [==============================] - 4s 860ms/step - loss: 0.5857 - iou_score: 0.6155 - f1-score: 0.7617 - val_loss: 0.8928 - val_iou_score: 0.3898 - val_f1-score: 0.5117
# Epoch 18/40
# 5/5 [==============================] - 4s 861ms/step - loss: 0.5215 - iou_score: 0.6557 - f1-score: 0.7917 - val_loss: 0.8873 - val_iou_score: 0.4010 - val_f1-score: 0.5238
# Epoch 19/40
# 5/5 [==============================] - 4s 856ms/step - loss: 0.5097 - iou_score: 0.6552 - f1-score: 0.7916 - val_loss: 0.8405 - val_iou_score: 0.4120 - val_f1-score: 0.5323
# Epoch 20/40
# 5/5 [==============================] - 4s 862ms/step - loss: 0.4833 - iou_score: 0.6704 - f1-score: 0.8026 - val_loss: 0.8872 - val_iou_score: 0.4056 - val_f1-score: 0.5298
# Epoch 21/40
# 5/5 [==============================] - 4s 865ms/step - loss: 0.4467 - iou_score: 0.6976 - f1-score: 0.8214 - val_loss: 0.8397 - val_iou_score: 0.4207 - val_f1-score: 0.5403
# Epoch 22/40
# 5/5 [==============================] - 4s 866ms/step - loss: 0.4376 - iou_score: 0.6955 - f1-score: 0.8201 - val_loss: 0.7943 - val_iou_score: 0.4310 - val_f1-score: 0.5444
# Epoch 23/40
# 5/5 [==============================] - 4s 868ms/step - loss: 0.4202 - iou_score: 0.7059 - f1-score: 0.8274 - val_loss: 0.8398 - val_iou_score: 0.4259 - val_f1-score: 0.5506
# Epoch 24/40
# 5/5 [==============================] - 4s 862ms/step - loss: 0.4210 - iou_score: 0.7039 - f1-score: 0.8257 - val_loss: 0.8322 - val_iou_score: 0.4202 - val_f1-score: 0.5470
# Epoch 25/40
# 5/5 [==============================] - 4s 866ms/step - loss: 0.3975 - iou_score: 0.7164 - f1-score: 0.8346 - val_loss: 0.8287 - val_iou_score: 0.4262 - val_f1-score: 0.5509
# Epoch 26/40
# 5/5 [==============================] - 4s 862ms/step - loss: 0.4084 - iou_score: 0.6972 - f1-score: 0.8214 - val_loss: 0.7932 - val_iou_score: 0.4335 - val_f1-score: 0.5568
# Epoch 27/40
# 5/5 [==============================] - 4s 864ms/step - loss: 0.4285 - iou_score: 0.6955 - f1-score: 0.8198 - val_loss: 0.7359 - val_iou_score: 0.4494 - val_f1-score: 0.5658
# Epoch 28/40
# 5/5 [==============================] - 4s 867ms/step - loss: 0.3636 - iou_score: 0.7327 - f1-score: 0.8455 - val_loss: 0.7020 - val_iou_score: 0.4556 - val_f1-score: 0.5698
# Epoch 29/40
# 5/5 [==============================] - 4s 870ms/step - loss: 0.4079 - iou_score: 0.6957 - f1-score: 0.8202 - val_loss: 0.7129 - val_iou_score: 0.4641 - val_f1-score: 0.5866
# Epoch 30/40
# 5/5 [==============================] - 4s 864ms/step - loss: 0.3849 - iou_score: 0.7059 - f1-score: 0.8270 - val_loss: 0.7191 - val_iou_score: 0.4587 - val_f1-score: 0.5821
# Epoch 31/40
# 5/5 [==============================] - 4s 856ms/step - loss: 0.3675 - iou_score: 0.7287 - f1-score: 0.8428 - val_loss: 0.6850 - val_iou_score: 0.4649 - val_f1-score: 0.5784
# Epoch 32/40
# 5/5 [==============================] - 4s 862ms/step - loss: 0.3760 - iou_score: 0.7199 - f1-score: 0.8369 - val_loss: 0.6770 - val_iou_score: 0.4617 - val_f1-score: 0.5627
# Epoch 33/40
# 5/5 [==============================] - 4s 866ms/step - loss: 0.3624 - iou_score: 0.7193 - f1-score: 0.8367 - val_loss: 0.6433 - val_iou_score: 0.4751 - val_f1-score: 0.5820
# Epoch 34/40
# 5/5 [==============================] - 4s 861ms/step - loss: 0.3773 - iou_score: 0.7038 - f1-score: 0.8255 - val_loss: 0.6772 - val_iou_score: 0.4657 - val_f1-score: 0.5778
# Epoch 35/40
# 5/5 [==============================] - 4s 863ms/step - loss: 0.3538 - iou_score: 0.7271 - f1-score: 0.8413 - val_loss: 0.6811 - val_iou_score: 0.4670 - val_f1-score: 0.5840
# Epoch 36/40
# 5/5 [==============================] - 4s 861ms/step - loss: 0.3704 - iou_score: 0.7228 - f1-score: 0.8389 - val_loss: 0.6910 - val_iou_score: 0.4634 - val_f1-score: 0.5828
# Epoch 37/40
# 5/5 [==============================] - 4s 870ms/step - loss: 0.3345 - iou_score: 0.7321 - f1-score: 0.8449 - val_loss: 0.6714 - val_iou_score: 0.4607 - val_f1-score: 0.5739
# Epoch 38/40
# 5/5 [==============================] - 4s 864ms/step - loss: 0.3384 - iou_score: 0.7314 - f1-score: 0.8445 - val_loss: 0.7043 - val_iou_score: 0.4654 - val_f1-score: 0.5947
# Epoch 39/40
# 5/5 [==============================] - 4s 859ms/step - loss: 0.3086 - iou_score: 0.7514 - f1-score: 0.8579 - val_loss: 0.6576 - val_iou_score: 0.4739 - val_f1-score: 0.5901
# Epoch 40/40
# 5/5 [==============================] - 4s 861ms/step - loss: 0.3864 - iou_score: 0.6974 - f1-score: 0.8184 - val_loss: 0.6445 - val_iou_score: 0.4685 - val_f1-score: 0.5670
# Epoch 1/60
# 5/5 [==============================] - 28s 6s/step - loss: 1.4861 - iou_score: 0.0634 - f1-score: 0.1184 - val_loss: 1.4599 - val_iou_score: 0.1143 - val_f1-score: 0.1881
# Epoch 2/60
# 5/5 [==============================] - 4s 872ms/step - loss: 1.2954 - iou_score: 0.1468 - f1-score: 0.2554 - val_loss: 1.3709 - val_iou_score: 0.1812 - val_f1-score: 0.2693
# Epoch 3/60
# 5/5 [==============================] - 4s 872ms/step - loss: 1.1801 - iou_score: 0.2654 - f1-score: 0.4173 - val_loss: 1.3122 - val_iou_score: 0.2125 - val_f1-score: 0.3045
# Epoch 4/60
# 5/5 [==============================] - 4s 863ms/step - loss: 1.0926 - iou_score: 0.3217 - f1-score: 0.4846 - val_loss: 1.2652 - val_iou_score: 0.2240 - val_f1-score: 0.3166
# Epoch 5/60
# 5/5 [==============================] - 4s 868ms/step - loss: 1.0278 - iou_score: 0.3835 - f1-score: 0.5536 - val_loss: 1.2321 - val_iou_score: 0.2336 - val_f1-score: 0.3275
# Epoch 6/60
# 5/5 [==============================] - 4s 865ms/step - loss: 0.9609 - iou_score: 0.4096 - f1-score: 0.5804 - val_loss: 1.2080 - val_iou_score: 0.2406 - val_f1-score: 0.3368
# Epoch 7/60
# 5/5 [==============================] - 4s 869ms/step - loss: 0.9585 - iou_score: 0.3973 - f1-score: 0.5659 - val_loss: 1.1873 - val_iou_score: 0.2420 - val_f1-score: 0.3406
# Epoch 8/60
# 5/5 [==============================] - 4s 874ms/step - loss: 0.9062 - iou_score: 0.4211 - f1-score: 0.5922 - val_loss: 1.1274 - val_iou_score: 0.2565 - val_f1-score: 0.3570
# Epoch 9/60
# 5/5 [==============================] - 4s 865ms/step - loss: 0.8114 - iou_score: 0.4929 - f1-score: 0.6600 - val_loss: 1.1151 - val_iou_score: 0.2632 - val_f1-score: 0.3679
# Epoch 10/60
# 5/5 [==============================] - 4s 867ms/step - loss: 0.7530 - iou_score: 0.5363 - f1-score: 0.6979 - val_loss: 1.0364 - val_iou_score: 0.2901 - val_f1-score: 0.3941
# Epoch 11/60
# 5/5 [==============================] - 4s 866ms/step - loss: 0.6933 - iou_score: 0.5650 - f1-score: 0.7203 - val_loss: 1.0530 - val_iou_score: 0.3017 - val_f1-score: 0.4092
# Epoch 12/60
# 5/5 [==============================] - 4s 872ms/step - loss: 0.6267 - iou_score: 0.6096 - f1-score: 0.7570 - val_loss: 0.9632 - val_iou_score: 0.3220 - val_f1-score: 0.4260
# Epoch 13/60
# 5/5 [==============================] - 4s 866ms/step - loss: 0.6038 - iou_score: 0.6242 - f1-score: 0.7680 - val_loss: 1.1143 - val_iou_score: 0.3131 - val_f1-score: 0.4286
# Epoch 14/60
# 5/5 [==============================] - 4s 868ms/step - loss: 0.5813 - iou_score: 0.6230 - f1-score: 0.7676 - val_loss: 1.0369 - val_iou_score: 0.3230 - val_f1-score: 0.4319
# Epoch 15/60
# 5/5 [==============================] - 4s 879ms/step - loss: 0.5448 - iou_score: 0.6395 - f1-score: 0.7794 - val_loss: 0.9206 - val_iou_score: 0.3261 - val_f1-score: 0.4195
# Epoch 16/60
# 5/5 [==============================] - 4s 873ms/step - loss: 0.4888 - iou_score: 0.6747 - f1-score: 0.8052 - val_loss: 0.9330 - val_iou_score: 0.3346 - val_f1-score: 0.4334
# Epoch 17/60
# 5/5 [==============================] - 4s 864ms/step - loss: 0.4954 - iou_score: 0.6635 - f1-score: 0.7976 - val_loss: 0.9383 - val_iou_score: 0.3465 - val_f1-score: 0.4521
# Epoch 18/60
# 5/5 [==============================] - 4s 863ms/step - loss: 0.4885 - iou_score: 0.6583 - f1-score: 0.7932 - val_loss: 0.8923 - val_iou_score: 0.3625 - val_f1-score: 0.4696
# Epoch 19/60
# 5/5 [==============================] - 4s 872ms/step - loss: 0.4574 - iou_score: 0.6809 - f1-score: 0.8095 - val_loss: 0.9243 - val_iou_score: 0.3623 - val_f1-score: 0.4713
# Epoch 20/60
# 5/5 [==============================] - 4s 866ms/step - loss: 0.4578 - iou_score: 0.6814 - f1-score: 0.8101 - val_loss: 0.8957 - val_iou_score: 0.3630 - val_f1-score: 0.4693
# Epoch 21/60
# 5/5 [==============================] - 4s 869ms/step - loss: 0.4260 - iou_score: 0.6973 - f1-score: 0.8215 - val_loss: 0.9400 - val_iou_score: 0.3779 - val_f1-score: 0.4945
# Epoch 22/60
# 5/5 [==============================] - 4s 871ms/step - loss: 0.4224 - iou_score: 0.6913 - f1-score: 0.8162 - val_loss: 0.9617 - val_iou_score: 0.3718 - val_f1-score: 0.4872
# Epoch 23/60
# 5/5 [==============================] - 4s 873ms/step - loss: 0.3885 - iou_score: 0.7147 - f1-score: 0.8328 - val_loss: 0.9382 - val_iou_score: 0.3716 - val_f1-score: 0.4869
# Epoch 24/60
# 5/5 [==============================] - 4s 863ms/step - loss: 0.4239 - iou_score: 0.6905 - f1-score: 0.8166 - val_loss: 0.8533 - val_iou_score: 0.3712 - val_f1-score: 0.4708
# Epoch 25/60
# 5/5 [==============================] - 4s 863ms/step - loss: 0.3857 - iou_score: 0.7136 - f1-score: 0.8323 - val_loss: 0.8366 - val_iou_score: 0.3803 - val_f1-score: 0.4825
# Epoch 26/60
# 5/5 [==============================] - 4s 873ms/step - loss: 0.3500 - iou_score: 0.7387 - f1-score: 0.8497 - val_loss: 0.7624 - val_iou_score: 0.4048 - val_f1-score: 0.5055
# Epoch 27/60
# 5/5 [==============================] - 4s 867ms/step - loss: 0.3973 - iou_score: 0.6894 - f1-score: 0.8134 - val_loss: 0.7442 - val_iou_score: 0.4161 - val_f1-score: 0.5174
# Epoch 28/60
# 5/5 [==============================] - 4s 870ms/step - loss: 0.4144 - iou_score: 0.6762 - f1-score: 0.8060 - val_loss: 0.7457 - val_iou_score: 0.4205 - val_f1-score: 0.5224
# Epoch 29/60
# 5/5 [==============================] - 4s 870ms/step - loss: 0.3791 - iou_score: 0.6992 - f1-score: 0.8228 - val_loss: 0.7224 - val_iou_score: 0.4269 - val_f1-score: 0.5279
# Epoch 30/60
# 5/5 [==============================] - 4s 866ms/step - loss: 0.3961 - iou_score: 0.7061 - f1-score: 0.8274 - val_loss: 0.7011 - val_iou_score: 0.4407 - val_f1-score: 0.5400
# Epoch 31/60
# 5/5 [==============================] - 4s 861ms/step - loss: 0.3544 - iou_score: 0.7249 - f1-score: 0.8398 - val_loss: 0.7146 - val_iou_score: 0.4327 - val_f1-score: 0.5312
# Epoch 32/60
# 5/5 [==============================] - 4s 869ms/step - loss: 0.3446 - iou_score: 0.7313 - f1-score: 0.8446 - val_loss: 0.7299 - val_iou_score: 0.4356 - val_f1-score: 0.5434
# Epoch 33/60
# 5/5 [==============================] - 4s 873ms/step - loss: 0.3221 - iou_score: 0.7516 - f1-score: 0.8581 - val_loss: 0.6883 - val_iou_score: 0.4394 - val_f1-score: 0.5373
# Epoch 34/60
# 5/5 [==============================] - 4s 866ms/step - loss: 0.3642 - iou_score: 0.7064 - f1-score: 0.8275 - val_loss: 0.7269 - val_iou_score: 0.4374 - val_f1-score: 0.5411
# Epoch 35/60
# 5/5 [==============================] - 4s 862ms/step - loss: 0.3363 - iou_score: 0.7317 - f1-score: 0.8450 - val_loss: 0.6803 - val_iou_score: 0.4595 - val_f1-score: 0.5624
# Epoch 36/60
# 5/5 [==============================] - 4s 863ms/step - loss: 0.3393 - iou_score: 0.7299 - f1-score: 0.8436 - val_loss: 0.6650 - val_iou_score: 0.4550 - val_f1-score: 0.5522
# Epoch 37/60
# 5/5 [==============================] - 4s 876ms/step - loss: 0.2948 - iou_score: 0.7688 - f1-score: 0.8692 - val_loss: 0.6956 - val_iou_score: 0.4530 - val_f1-score: 0.5540
# Epoch 38/60
# 5/5 [==============================] - 4s 864ms/step - loss: 0.3264 - iou_score: 0.7332 - f1-score: 0.8456 - val_loss: 0.6480 - val_iou_score: 0.4700 - val_f1-score: 0.5676
# Epoch 39/60
# 5/5 [==============================] - 4s 871ms/step - loss: 0.3363 - iou_score: 0.7363 - f1-score: 0.8481 - val_loss: 0.6431 - val_iou_score: 0.4584 - val_f1-score: 0.5555
# Epoch 40/60
# 5/5 [==============================] - 4s 866ms/step - loss: 0.3140 - iou_score: 0.7438 - f1-score: 0.8528 - val_loss: 0.6324 - val_iou_score: 0.4638 - val_f1-score: 0.5584
# Epoch 41/60
# 5/5 [==============================] - 4s 870ms/step - loss: 0.3109 - iou_score: 0.7450 - f1-score: 0.8530 - val_loss: 0.6377 - val_iou_score: 0.4676 - val_f1-score: 0.5620
# Epoch 42/60
# 5/5 [==============================] - 4s 865ms/step - loss: 0.3166 - iou_score: 0.7399 - f1-score: 0.8501 - val_loss: 0.6099 - val_iou_score: 0.4741 - val_f1-score: 0.5648
# Epoch 43/60
# 5/5 [==============================] - 4s 864ms/step - loss: 0.3008 - iou_score: 0.7564 - f1-score: 0.8611 - val_loss: 0.6319 - val_iou_score: 0.4652 - val_f1-score: 0.5581
# Epoch 44/60
# 5/5 [==============================] - 4s 864ms/step - loss: 0.2851 - iou_score: 0.7600 - f1-score: 0.8631 - val_loss: 0.6428 - val_iou_score: 0.4674 - val_f1-score: 0.5609
# Epoch 45/60
# 5/5 [==============================] - 4s 869ms/step - loss: 0.2967 - iou_score: 0.7637 - f1-score: 0.8659 - val_loss: 0.6640 - val_iou_score: 0.4578 - val_f1-score: 0.5543
# Epoch 46/60
# 5/5 [==============================] - 4s 865ms/step - loss: 0.3008 - iou_score: 0.7624 - f1-score: 0.8650 - val_loss: 0.6947 - val_iou_score: 0.4503 - val_f1-score: 0.5534
# Epoch 47/60
# 5/5 [==============================] - 4s 864ms/step - loss: 0.3043 - iou_score: 0.7590 - f1-score: 0.8629 - val_loss: 0.6700 - val_iou_score: 0.4528 - val_f1-score: 0.5528
# Epoch 48/60
# 5/5 [==============================] - 4s 870ms/step - loss: 0.2837 - iou_score: 0.7673 - f1-score: 0.8683 - val_loss: 0.6309 - val_iou_score: 0.4653 - val_f1-score: 0.5622
# Epoch 49/60
# 5/5 [==============================] - 4s 865ms/step - loss: 0.3122 - iou_score: 0.7524 - f1-score: 0.8585 - val_loss: 0.6196 - val_iou_score: 0.4723 - val_f1-score: 0.5655
# Epoch 50/60
# 5/5 [==============================] - 4s 876ms/step - loss: 0.2900 - iou_score: 0.7603 - f1-score: 0.8637 - val_loss: 0.6046 - val_iou_score: 0.4866 - val_f1-score: 0.5783
# Epoch 51/60
# 5/5 [==============================] - 4s 867ms/step - loss: 0.2833 - iou_score: 0.7612 - f1-score: 0.8635 - val_loss: 0.5870 - val_iou_score: 0.4851 - val_f1-score: 0.5756
# Epoch 52/60
# 5/5 [==============================] - 4s 865ms/step - loss: 0.2891 - iou_score: 0.7601 - f1-score: 0.8632 - val_loss: 0.5843 - val_iou_score: 0.4918 - val_f1-score: 0.5817
# Epoch 53/60
# 5/5 [==============================] - 4s 873ms/step - loss: 0.2741 - iou_score: 0.7754 - f1-score: 0.8734 - val_loss: 0.5856 - val_iou_score: 0.4970 - val_f1-score: 0.5856
# Epoch 54/60
# 5/5 [==============================] - 4s 867ms/step - loss: 0.3072 - iou_score: 0.7472 - f1-score: 0.8547 - val_loss: 0.5825 - val_iou_score: 0.4919 - val_f1-score: 0.5715
# Epoch 55/60
# 5/5 [==============================] - 4s 871ms/step - loss: 0.2873 - iou_score: 0.7616 - f1-score: 0.8645 - val_loss: 0.5546 - val_iou_score: 0.5172 - val_f1-score: 0.5964
# Epoch 56/60
# 5/5 [==============================] - 4s 867ms/step - loss: 0.2714 - iou_score: 0.7771 - f1-score: 0.8744 - val_loss: 0.5606 - val_iou_score: 0.5119 - val_f1-score: 0.6000
# Epoch 57/60
# 5/5 [==============================] - 4s 864ms/step - loss: 0.2853 - iou_score: 0.7582 - f1-score: 0.8624 - val_loss: 0.5610 - val_iou_score: 0.5064 - val_f1-score: 0.5938
# Epoch 58/60
# 5/5 [==============================] - 4s 866ms/step - loss: 0.2973 - iou_score: 0.7517 - f1-score: 0.8580 - val_loss: 0.5438 - val_iou_score: 0.5125 - val_f1-score: 0.6012
# Epoch 59/60
# 5/5 [==============================] - 4s 866ms/step - loss: 0.2766 - iou_score: 0.7728 - f1-score: 0.8717 - val_loss: 0.5585 - val_iou_score: 0.5040 - val_f1-score: 0.5962
# Epoch 60/60
# 5/5 [==============================] - 4s 875ms/step - loss: 0.2723 - iou_score: 0.7698 - f1-score: 0.8696 - val_loss: 0.5572 - val_iou_score: 0.5031 - val_f1-score: 0.5857
# Epoch 1/80
# 5/5 [==============================] - 30s 6s/step - loss: 1.6191 - iou_score: 0.2338 - f1-score: 0.3783 - val_loss: 1.4909 - val_iou_score: 0.2070 - val_f1-score: 0.3075
# Epoch 2/80
# 5/5 [==============================] - 4s 874ms/step - loss: 1.3302 - iou_score: 0.3256 - f1-score: 0.4905 - val_loss: 1.3728 - val_iou_score: 0.2380 - val_f1-score: 0.3434
# Epoch 3/80
# 5/5 [==============================] - 4s 881ms/step - loss: 1.1743 - iou_score: 0.3786 - f1-score: 0.5472 - val_loss: 1.2829 - val_iou_score: 0.2549 - val_f1-score: 0.3603
# Epoch 4/80
# 5/5 [==============================] - 4s 880ms/step - loss: 1.1343 - iou_score: 0.3300 - f1-score: 0.4920 - val_loss: 1.2073 - val_iou_score: 0.2682 - val_f1-score: 0.3729
# Epoch 5/80
# 5/5 [==============================] - 4s 874ms/step - loss: 1.0037 - iou_score: 0.4114 - f1-score: 0.5827 - val_loss: 1.1896 - val_iou_score: 0.2715 - val_f1-score: 0.3792
# Epoch 6/80
# 5/5 [==============================] - 4s 875ms/step - loss: 0.9400 - iou_score: 0.4368 - f1-score: 0.6033 - val_loss: 1.1528 - val_iou_score: 0.2803 - val_f1-score: 0.3893
# Epoch 7/80
# 5/5 [==============================] - 4s 868ms/step - loss: 0.9117 - iou_score: 0.4401 - f1-score: 0.6086 - val_loss: 1.1146 - val_iou_score: 0.2917 - val_f1-score: 0.4040
# Epoch 8/80
# 5/5 [==============================] - 4s 870ms/step - loss: 0.8294 - iou_score: 0.4850 - f1-score: 0.6513 - val_loss: 1.0925 - val_iou_score: 0.3126 - val_f1-score: 0.4334
# Epoch 9/80
# 5/5 [==============================] - 4s 874ms/step - loss: 0.7872 - iou_score: 0.4886 - f1-score: 0.6559 - val_loss: 1.1074 - val_iou_score: 0.3195 - val_f1-score: 0.4450
# Epoch 10/80
# 5/5 [==============================] - 4s 872ms/step - loss: 0.7163 - iou_score: 0.5440 - f1-score: 0.7046 - val_loss: 1.0746 - val_iou_score: 0.3389 - val_f1-score: 0.4671
# Epoch 11/80
# 5/5 [==============================] - 4s 874ms/step - loss: 0.6447 - iou_score: 0.5924 - f1-score: 0.7435 - val_loss: 1.1183 - val_iou_score: 0.3390 - val_f1-score: 0.4704
# Epoch 12/80
# 5/5 [==============================] - 4s 878ms/step - loss: 0.6173 - iou_score: 0.5970 - f1-score: 0.7476 - val_loss: 1.0752 - val_iou_score: 0.3516 - val_f1-score: 0.4818
# Epoch 13/80
# 5/5 [==============================] - 4s 882ms/step - loss: 0.5719 - iou_score: 0.6146 - f1-score: 0.7609 - val_loss: 1.0980 - val_iou_score: 0.3503 - val_f1-score: 0.4816
# Epoch 14/80
# 5/5 [==============================] - 4s 870ms/step - loss: 0.5650 - iou_score: 0.6062 - f1-score: 0.7532 - val_loss: 1.0253 - val_iou_score: 0.3706 - val_f1-score: 0.5031
# Epoch 15/80
# 5/5 [==============================] - 4s 872ms/step - loss: 0.4791 - iou_score: 0.6814 - f1-score: 0.8103 - val_loss: 1.0981 - val_iou_score: 0.3668 - val_f1-score: 0.5052
# Epoch 16/80
# 5/5 [==============================] - 4s 872ms/step - loss: 0.4903 - iou_score: 0.6639 - f1-score: 0.7978 - val_loss: 1.0635 - val_iou_score: 0.3798 - val_f1-score: 0.5164
# Epoch 17/80
# 5/5 [==============================] - 4s 871ms/step - loss: 0.4756 - iou_score: 0.6651 - f1-score: 0.7987 - val_loss: 1.0576 - val_iou_score: 0.3870 - val_f1-score: 0.5284
# Epoch 18/80
# 5/5 [==============================] - 4s 875ms/step - loss: 0.5008 - iou_score: 0.6379 - f1-score: 0.7782 - val_loss: 0.9788 - val_iou_score: 0.3991 - val_f1-score: 0.5336
# Epoch 19/80
# 5/5 [==============================] - 4s 870ms/step - loss: 0.4578 - iou_score: 0.6623 - f1-score: 0.7966 - val_loss: 0.9769 - val_iou_score: 0.4135 - val_f1-score: 0.5538
# Epoch 20/80
# 5/5 [==============================] - 4s 871ms/step - loss: 0.4013 - iou_score: 0.7107 - f1-score: 0.8303 - val_loss: 0.9713 - val_iou_score: 0.4148 - val_f1-score: 0.5537
# Epoch 21/80
# 5/5 [==============================] - 4s 869ms/step - loss: 0.4196 - iou_score: 0.7015 - f1-score: 0.8241 - val_loss: 0.9566 - val_iou_score: 0.4241 - val_f1-score: 0.5649
# Epoch 22/80
# 5/5 [==============================] - 4s 874ms/step - loss: 0.4223 - iou_score: 0.6873 - f1-score: 0.8144 - val_loss: 0.9071 - val_iou_score: 0.4376 - val_f1-score: 0.5746
# Epoch 23/80
# 5/5 [==============================] - 4s 870ms/step - loss: 0.4337 - iou_score: 0.6882 - f1-score: 0.8147 - val_loss: 0.9076 - val_iou_score: 0.4333 - val_f1-score: 0.5761
# Epoch 24/80
# 5/5 [==============================] - 4s 878ms/step - loss: 0.3915 - iou_score: 0.7069 - f1-score: 0.8279 - val_loss: 0.8656 - val_iou_score: 0.4415 - val_f1-score: 0.5865
# Epoch 25/80
# 5/5 [==============================] - 4s 877ms/step - loss: 0.3748 - iou_score: 0.7111 - f1-score: 0.8307 - val_loss: 0.8340 - val_iou_score: 0.4533 - val_f1-score: 0.5926
# Epoch 26/80
# 5/5 [==============================] - 4s 875ms/step - loss: 0.4073 - iou_score: 0.6940 - f1-score: 0.8192 - val_loss: 0.7292 - val_iou_score: 0.4772 - val_f1-score: 0.5998
# Epoch 27/80
# 5/5 [==============================] - 4s 889ms/step - loss: 0.3756 - iou_score: 0.7055 - f1-score: 0.8269 - val_loss: 0.7046 - val_iou_score: 0.4965 - val_f1-score: 0.6250
# Epoch 28/80
# 5/5 [==============================] - 4s 875ms/step - loss: 0.3910 - iou_score: 0.7025 - f1-score: 0.8248 - val_loss: 0.7602 - val_iou_score: 0.4766 - val_f1-score: 0.6084
# Epoch 29/80
# 5/5 [==============================] - 4s 876ms/step - loss: 0.3417 - iou_score: 0.7349 - f1-score: 0.8471 - val_loss: 0.6709 - val_iou_score: 0.4973 - val_f1-score: 0.6069
# Epoch 30/80
# 5/5 [==============================] - 4s 882ms/step - loss: 0.3510 - iou_score: 0.7251 - f1-score: 0.8401 - val_loss: 0.6543 - val_iou_score: 0.5077 - val_f1-score: 0.6312
# Epoch 31/80
# 5/5 [==============================] - 4s 872ms/step - loss: 0.3319 - iou_score: 0.7464 - f1-score: 0.8545 - val_loss: 0.6554 - val_iou_score: 0.5148 - val_f1-score: 0.6415
# Epoch 32/80
# 5/5 [==============================] - 4s 870ms/step - loss: 0.3556 - iou_score: 0.7191 - f1-score: 0.8360 - val_loss: 0.6536 - val_iou_score: 0.5119 - val_f1-score: 0.6367
# Epoch 33/80
# 5/5 [==============================] - 4s 874ms/step - loss: 0.3368 - iou_score: 0.7303 - f1-score: 0.8440 - val_loss: 0.6109 - val_iou_score: 0.5259 - val_f1-score: 0.6380
# Epoch 34/80
# 5/5 [==============================] - 4s 880ms/step - loss: 0.3737 - iou_score: 0.7040 - f1-score: 0.8250 - val_loss: 0.6056 - val_iou_score: 0.5457 - val_f1-score: 0.6478
# Epoch 35/80
# 5/5 [==============================] - 4s 873ms/step - loss: 0.3167 - iou_score: 0.7415 - f1-score: 0.8511 - val_loss: 0.6329 - val_iou_score: 0.5202 - val_f1-score: 0.6391
# Epoch 36/80
# 5/5 [==============================] - 4s 871ms/step - loss: 0.3350 - iou_score: 0.7374 - f1-score: 0.8486 - val_loss: 0.6176 - val_iou_score: 0.5207 - val_f1-score: 0.6407
# Epoch 37/80
# 5/5 [==============================] - 4s 873ms/step - loss: 0.3419 - iou_score: 0.7334 - f1-score: 0.8458 - val_loss: 0.6095 - val_iou_score: 0.5311 - val_f1-score: 0.6378
# Epoch 38/80
# 5/5 [==============================] - 4s 876ms/step - loss: 0.3583 - iou_score: 0.7240 - f1-score: 0.8391 - val_loss: 0.6025 - val_iou_score: 0.5251 - val_f1-score: 0.6419
# Epoch 39/80
# 5/5 [==============================] - 4s 869ms/step - loss: 0.3164 - iou_score: 0.7390 - f1-score: 0.8496 - val_loss: 0.5713 - val_iou_score: 0.5446 - val_f1-score: 0.6538
# Epoch 40/80
# 5/5 [==============================] - 4s 872ms/step - loss: 0.3241 - iou_score: 0.7409 - f1-score: 0.8507 - val_loss: 0.5853 - val_iou_score: 0.5486 - val_f1-score: 0.6581
# Epoch 41/80
# 5/5 [==============================] - 4s 870ms/step - loss: 0.2997 - iou_score: 0.7501 - f1-score: 0.8571 - val_loss: 0.5667 - val_iou_score: 0.5344 - val_f1-score: 0.6371
# Epoch 42/80
# 5/5 [==============================] - 4s 868ms/step - loss: 0.3169 - iou_score: 0.7507 - f1-score: 0.8569 - val_loss: 0.5623 - val_iou_score: 0.5408 - val_f1-score: 0.6436
# Epoch 43/80
# 5/5 [==============================] - 4s 870ms/step - loss: 0.2941 - iou_score: 0.7567 - f1-score: 0.8609 - val_loss: 0.5673 - val_iou_score: 0.5244 - val_f1-score: 0.6224
# Epoch 44/80
# 5/5 [==============================] - 4s 878ms/step - loss: 0.3146 - iou_score: 0.7558 - f1-score: 0.8603 - val_loss: 0.5729 - val_iou_score: 0.5311 - val_f1-score: 0.6305
# Epoch 45/80
# 5/5 [==============================] - 4s 877ms/step - loss: 0.3400 - iou_score: 0.7286 - f1-score: 0.8425 - val_loss: 0.5469 - val_iou_score: 0.5513 - val_f1-score: 0.6513
# Epoch 46/80
# 5/5 [==============================] - 4s 888ms/step - loss: 0.3027 - iou_score: 0.7583 - f1-score: 0.8624 - val_loss: 0.5363 - val_iou_score: 0.5628 - val_f1-score: 0.6629
# Epoch 47/80
# 5/5 [==============================] - 4s 884ms/step - loss: 0.2857 - iou_score: 0.7707 - f1-score: 0.8704 - val_loss: 0.5338 - val_iou_score: 0.5612 - val_f1-score: 0.6616
# Epoch 48/80
# 5/5 [==============================] - 4s 876ms/step - loss: 0.2837 - iou_score: 0.7625 - f1-score: 0.8647 - val_loss: 0.5587 - val_iou_score: 0.5497 - val_f1-score: 0.6607
# Epoch 49/80
# 5/5 [==============================] - 4s 876ms/step - loss: 0.2752 - iou_score: 0.7741 - f1-score: 0.8722 - val_loss: 0.5326 - val_iou_score: 0.5651 - val_f1-score: 0.6753
# Epoch 50/80
# 5/5 [==============================] - 4s 871ms/step - loss: 0.2749 - iou_score: 0.7728 - f1-score: 0.8717 - val_loss: 0.5376 - val_iou_score: 0.5654 - val_f1-score: 0.6752
# Epoch 51/80
# 5/5 [==============================] - 4s 877ms/step - loss: 0.2924 - iou_score: 0.7486 - f1-score: 0.8557 - val_loss: 0.5333 - val_iou_score: 0.5360 - val_f1-score: 0.6269
# Epoch 52/80
# 5/5 [==============================] - 4s 874ms/step - loss: 0.2567 - iou_score: 0.7872 - f1-score: 0.8809 - val_loss: 0.5356 - val_iou_score: 0.5603 - val_f1-score: 0.6641
# Epoch 53/80
# 5/5 [==============================] - 4s 875ms/step - loss: 0.2665 - iou_score: 0.7767 - f1-score: 0.8740 - val_loss: 0.5366 - val_iou_score: 0.5560 - val_f1-score: 0.6554
# Epoch 54/80
# 5/5 [==============================] - 4s 884ms/step - loss: 0.2643 - iou_score: 0.7821 - f1-score: 0.8775 - val_loss: 0.5318 - val_iou_score: 0.5256 - val_f1-score: 0.6104
# Epoch 55/80
# 5/5 [==============================] - 4s 875ms/step - loss: 0.2805 - iou_score: 0.7770 - f1-score: 0.8741 - val_loss: 0.5388 - val_iou_score: 0.5516 - val_f1-score: 0.6518
# Epoch 56/80
# 5/5 [==============================] - 4s 877ms/step - loss: 0.3024 - iou_score: 0.7458 - f1-score: 0.8543 - val_loss: 0.5211 - val_iou_score: 0.5668 - val_f1-score: 0.6643
# Epoch 57/80
# 5/5 [==============================] - 4s 882ms/step - loss: 0.2972 - iou_score: 0.7581 - f1-score: 0.8622 - val_loss: 0.5101 - val_iou_score: 0.5669 - val_f1-score: 0.6643
# Epoch 58/80
# 5/5 [==============================] - 4s 871ms/step - loss: 0.2508 - iou_score: 0.7871 - f1-score: 0.8807 - val_loss: 0.5088 - val_iou_score: 0.5730 - val_f1-score: 0.6786
# Epoch 59/80
# 5/5 [==============================] - 4s 876ms/step - loss: 0.2436 - iou_score: 0.7867 - f1-score: 0.8803 - val_loss: 0.4996 - val_iou_score: 0.5809 - val_f1-score: 0.6798
# Epoch 60/80
# 5/5 [==============================] - 4s 879ms/step - loss: 0.2553 - iou_score: 0.7901 - f1-score: 0.8823 - val_loss: 0.4995 - val_iou_score: 0.5852 - val_f1-score: 0.6821
# Epoch 61/80
# 5/5 [==============================] - 4s 874ms/step - loss: 0.2665 - iou_score: 0.7640 - f1-score: 0.8661 - val_loss: 0.4979 - val_iou_score: 0.5832 - val_f1-score: 0.6771
# Epoch 62/80
# 5/5 [==============================] - 4s 868ms/step - loss: 0.2676 - iou_score: 0.7773 - f1-score: 0.8747 - val_loss: 0.5001 - val_iou_score: 0.5571 - val_f1-score: 0.6495
# Epoch 63/80
# 5/5 [==============================] - 4s 870ms/step - loss: 0.2796 - iou_score: 0.7693 - f1-score: 0.8696 - val_loss: 0.5022 - val_iou_score: 0.5674 - val_f1-score: 0.6631
# Epoch 64/80
# 5/5 [==============================] - 4s 869ms/step - loss: 0.2658 - iou_score: 0.7820 - f1-score: 0.8776 - val_loss: 0.5098 - val_iou_score: 0.5673 - val_f1-score: 0.6677
# Epoch 65/80
# 5/5 [==============================] - 4s 878ms/step - loss: 0.2622 - iou_score: 0.7839 - f1-score: 0.8787 - val_loss: 0.4937 - val_iou_score: 0.5755 - val_f1-score: 0.6715
# Epoch 66/80
# 5/5 [==============================] - 4s 876ms/step - loss: 0.2693 - iou_score: 0.7698 - f1-score: 0.8695 - val_loss: 0.5029 - val_iou_score: 0.5562 - val_f1-score: 0.6483
# Epoch 67/80
# 5/5 [==============================] - 4s 872ms/step - loss: 0.2728 - iou_score: 0.7699 - f1-score: 0.8699 - val_loss: 0.5015 - val_iou_score: 0.5521 - val_f1-score: 0.6423
# Epoch 68/80
# 5/5 [==============================] - 4s 880ms/step - loss: 0.2929 - iou_score: 0.7434 - f1-score: 0.8504 - val_loss: 0.5190 - val_iou_score: 0.5259 - val_f1-score: 0.6113
# Epoch 69/80
# 5/5 [==============================] - 4s 877ms/step - loss: 0.2515 - iou_score: 0.7882 - f1-score: 0.8815 - val_loss: 0.5113 - val_iou_score: 0.5514 - val_f1-score: 0.6404
# Epoch 70/80
# 5/5 [==============================] - 4s 875ms/step - loss: 0.2573 - iou_score: 0.7820 - f1-score: 0.8773 - val_loss: 0.4861 - val_iou_score: 0.5824 - val_f1-score: 0.6748
# Epoch 71/80
# 5/5 [==============================] - 4s 887ms/step - loss: 0.2775 - iou_score: 0.7493 - f1-score: 0.8557 - val_loss: 0.5177 - val_iou_score: 0.5179 - val_f1-score: 0.6036
# Epoch 72/80
# 5/5 [==============================] - 4s 876ms/step - loss: 0.2614 - iou_score: 0.7813 - f1-score: 0.8769 - val_loss: 0.5216 - val_iou_score: 0.5097 - val_f1-score: 0.5926
# Epoch 73/80
# 5/5 [==============================] - 4s 879ms/step - loss: 0.2292 - iou_score: 0.8047 - f1-score: 0.8917 - val_loss: 0.4819 - val_iou_score: 0.5785 - val_f1-score: 0.6694
# Epoch 74/80
# 5/5 [==============================] - 4s 873ms/step - loss: 0.2718 - iou_score: 0.7770 - f1-score: 0.8743 - val_loss: 0.4863 - val_iou_score: 0.5580 - val_f1-score: 0.6475
# Epoch 75/80
# 5/5 [==============================] - 4s 878ms/step - loss: 0.3078 - iou_score: 0.7427 - f1-score: 0.8522 - val_loss: 0.5055 - val_iou_score: 0.5271 - val_f1-score: 0.6156
# Epoch 76/80
# 5/5 [==============================] - 4s 874ms/step - loss: 0.2354 - iou_score: 0.7905 - f1-score: 0.8830 - val_loss: 0.4953 - val_iou_score: 0.5395 - val_f1-score: 0.6229
# Epoch 77/80
# 5/5 [==============================] - 4s 870ms/step - loss: 0.2488 - iou_score: 0.7857 - f1-score: 0.8797 - val_loss: 0.4839 - val_iou_score: 0.5559 - val_f1-score: 0.6440
# Epoch 78/80
# 5/5 [==============================] - 4s 872ms/step - loss: 0.2932 - iou_score: 0.7564 - f1-score: 0.8609 - val_loss: 0.4591 - val_iou_score: 0.5979 - val_f1-score: 0.6854
# Epoch 79/80
# 5/5 [==============================] - 4s 881ms/step - loss: 0.2439 - iou_score: 0.7921 - f1-score: 0.8839 - val_loss: 0.4650 - val_iou_score: 0.5877 - val_f1-score: 0.6753
# Epoch 80/80
# ...
# Epoch 15/100
# 5/5 [==============================] - 4s 875ms/step - loss: 0.5677 - iou_score: 0.6494 - f1-score: 0.7874 - val_loss: 1.0031 - val_iou_score: 0.3524 - val_f1-score: 0.4700
# Epoch 16/100
# 5/5 [==============================] - 4s 886ms/step - loss: 0.5398 - iou_score: 0.6600 - f1-score: 0.7940 - val_loss: 0.9778 - val_iou_score: 0.3524 - val_f1-score: 0.4678
# Epoch 17/100
# 5/5 [==============================] - 4s 874ms/step - loss: 0.5165 - iou_score: 0.6644 - f1-score: 0.7983 - val_loss: 0.9663 - val_iou_score: 0.3414 - val_f1-score: 0.4474
# Epoch 18/100
# 5/5 [==============================] - 4s 882ms/step - loss: 0.5248 - iou_score: 0.6445 - f1-score: 0.7831 - val_loss: 0.9954 - val_iou_score: 0.3455 - val_f1-score: 0.4590
# Epoch 19/100
# 5/5 [==============================] - 4s 876ms/step - loss: 0.4807 - iou_score: 0.6773 - f1-score: 0.8073 - val_loss: 1.0004 - val_iou_score: 0.3393 - val_f1-score: 0.4497
# Epoch 20/100
# 5/5 [==============================] - 4s 883ms/step - loss: 0.4484 - iou_score: 0.6943 - f1-score: 0.8191 - val_loss: 0.9869 - val_iou_score: 0.3532 - val_f1-score: 0.4665
# Epoch 21/100
# 5/5 [==============================] - 4s 879ms/step - loss: 0.4668 - iou_score: 0.6624 - f1-score: 0.7944 - val_loss: 0.9875 - val_iou_score: 0.3698 - val_f1-score: 0.4883
# Epoch 22/100
# 5/5 [==============================] - 4s 875ms/step - loss: 0.4247 - iou_score: 0.7037 - f1-score: 0.8259 - val_loss: 0.9061 - val_iou_score: 0.3802 - val_f1-score: 0.4927
# Epoch 23/100
# 5/5 [==============================] - 4s 879ms/step - loss: 0.4361 - iou_score: 0.6982 - f1-score: 0.8212 - val_loss: 0.8640 - val_iou_score: 0.3888 - val_f1-score: 0.5001
# Epoch 24/100
# 5/5 [==============================] - 4s 872ms/step - loss: 0.4169 - iou_score: 0.6990 - f1-score: 0.8211 - val_loss: 0.8398 - val_iou_score: 0.3802 - val_f1-score: 0.4837
# Epoch 25/100
# 5/5 [==============================] - 4s 895ms/step - loss: 0.4186 - iou_score: 0.6893 - f1-score: 0.8158 - val_loss: 0.8221 - val_iou_score: 0.3940 - val_f1-score: 0.4983
# Epoch 26/100
# 5/5 [==============================] - 4s 884ms/step - loss: 0.3901 - iou_score: 0.7090 - f1-score: 0.8293 - val_loss: 0.8667 - val_iou_score: 0.3974 - val_f1-score: 0.5152
# Epoch 27/100
# 5/5 [==============================] - 4s 880ms/step - loss: 0.3728 - iou_score: 0.7267 - f1-score: 0.8415 - val_loss: 0.8607 - val_iou_score: 0.4040 - val_f1-score: 0.5221
# Epoch 28/100
# 5/5 [==============================] - 4s 879ms/step - loss: 0.4065 - iou_score: 0.6852 - f1-score: 0.8121 - val_loss: 0.7906 - val_iou_score: 0.4167 - val_f1-score: 0.5275
# Epoch 29/100
# 5/5 [==============================] - 4s 881ms/step - loss: 0.3877 - iou_score: 0.7028 - f1-score: 0.8252 - val_loss: 0.7655 - val_iou_score: 0.4235 - val_f1-score: 0.5360
# Epoch 30/100
# 5/5 [==============================] - 4s 882ms/step - loss: 0.3505 - iou_score: 0.7315 - f1-score: 0.8443 - val_loss: 0.7505 - val_iou_score: 0.4270 - val_f1-score: 0.5374
# Epoch 31/100
# 5/5 [==============================] - 4s 881ms/step - loss: 0.3930 - iou_score: 0.6963 - f1-score: 0.8199 - val_loss: 0.7458 - val_iou_score: 0.4300 - val_f1-score: 0.5366
# Epoch 32/100
# 5/5 [==============================] - 4s 875ms/step - loss: 0.3696 - iou_score: 0.7058 - f1-score: 0.8266 - val_loss: 0.7024 - val_iou_score: 0.4241 - val_f1-score: 0.5119
# Epoch 33/100
# 5/5 [==============================] - 4s 880ms/step - loss: 0.3335 - iou_score: 0.7470 - f1-score: 0.8548 - val_loss: 0.7370 - val_iou_score: 0.4278 - val_f1-score: 0.5398
# Epoch 34/100
# 5/5 [==============================] - 4s 884ms/step - loss: 0.3512 - iou_score: 0.7247 - f1-score: 0.8402 - val_loss: 0.7262 - val_iou_score: 0.4257 - val_f1-score: 0.5333
# Epoch 35/100
# 5/5 [==============================] - 4s 879ms/step - loss: 0.3393 - iou_score: 0.7384 - f1-score: 0.8491 - val_loss: 0.7282 - val_iou_score: 0.4382 - val_f1-score: 0.5554
# Epoch 36/100
# 5/5 [==============================] - 4s 878ms/step - loss: 0.3404 - iou_score: 0.7307 - f1-score: 0.8439 - val_loss: 0.6877 - val_iou_score: 0.4396 - val_f1-score: 0.5412
# Epoch 37/100
# 5/5 [==============================] - 4s 881ms/step - loss: 0.3325 - iou_score: 0.7374 - f1-score: 0.8484 - val_loss: 0.6684 - val_iou_score: 0.4394 - val_f1-score: 0.5378
# Epoch 38/100
# 5/5 [==============================] - 4s 881ms/step - loss: 0.3202 - iou_score: 0.7473 - f1-score: 0.8552 - val_loss: 0.6425 - val_iou_score: 0.4558 - val_f1-score: 0.5563
# Epoch 39/100
# 5/5 [==============================] - 4s 877ms/step - loss: 0.3562 - iou_score: 0.7284 - f1-score: 0.8421 - val_loss: 0.6544 - val_iou_score: 0.4539 - val_f1-score: 0.5648
# Epoch 40/100
# 5/5 [==============================] - 4s 881ms/step - loss: 0.3436 - iou_score: 0.7316 - f1-score: 0.8445 - val_loss: 0.6604 - val_iou_score: 0.4529 - val_f1-score: 0.5552
# Epoch 41/100
# 5/5 [==============================] - 4s 874ms/step - loss: 0.3276 - iou_score: 0.7459 - f1-score: 0.8534 - val_loss: 0.6730 - val_iou_score: 0.4509 - val_f1-score: 0.5594
# Epoch 42/100
# 5/5 [==============================] - 4s 881ms/step - loss: 0.3246 - iou_score: 0.7340 - f1-score: 0.8459 - val_loss: 0.6444 - val_iou_score: 0.4423 - val_f1-score: 0.5196
# Epoch 43/100
# 5/5 [==============================] - 4s 875ms/step - loss: 0.3054 - iou_score: 0.7492 - f1-score: 0.8562 - val_loss: 0.6402 - val_iou_score: 0.4562 - val_f1-score: 0.5417
# Epoch 44/100
# 5/5 [==============================] - 4s 885ms/step - loss: 0.3846 - iou_score: 0.7120 - f1-score: 0.8301 - val_loss: 0.5974 - val_iou_score: 0.4746 - val_f1-score: 0.5604
# Epoch 45/100
# 5/5 [==============================] - 4s 874ms/step - loss: 0.3269 - iou_score: 0.7400 - f1-score: 0.8491 - val_loss: 0.5953 - val_iou_score: 0.4736 - val_f1-score: 0.5662
# Epoch 46/100
# 5/5 [==============================] - 4s 879ms/step - loss: 0.2865 - iou_score: 0.7679 - f1-score: 0.8684 - val_loss: 0.6031 - val_iou_score: 0.4668 - val_f1-score: 0.5555
# Epoch 47/100
# 5/5 [==============================] - 4s 879ms/step - loss: 0.2977 - iou_score: 0.7583 - f1-score: 0.8624 - val_loss: 0.5949 - val_iou_score: 0.4630 - val_f1-score: 0.5481
# Epoch 48/100
# 5/5 [==============================] - 4s 881ms/step - loss: 0.3315 - iou_score: 0.7256 - f1-score: 0.8402 - val_loss: 0.5923 - val_iou_score: 0.4589 - val_f1-score: 0.5366
# Epoch 49/100
# 5/5 [==============================] - 4s 875ms/step - loss: 0.2969 - iou_score: 0.7551 - f1-score: 0.8604 - val_loss: 0.5911 - val_iou_score: 0.4725 - val_f1-score: 0.5579
# Epoch 50/100
# 5/5 [==============================] - 4s 888ms/step - loss: 0.2877 - iou_score: 0.7641 - f1-score: 0.8660 - val_loss: 0.6009 - val_iou_score: 0.4459 - val_f1-score: 0.5161
# Epoch 51/100
# 5/5 [==============================] - 4s 881ms/step - loss: 0.2959 - iou_score: 0.7618 - f1-score: 0.8645 - val_loss: 0.5975 - val_iou_score: 0.4589 - val_f1-score: 0.5398
# Epoch 52/100
# 5/5 [==============================] - 4s 877ms/step - loss: 0.2759 - iou_score: 0.7683 - f1-score: 0.8687 - val_loss: 0.5923 - val_iou_score: 0.4599 - val_f1-score: 0.5364
# Epoch 53/100
# 5/5 [==============================] - 4s 878ms/step - loss: 0.2835 - iou_score: 0.7604 - f1-score: 0.8634 - val_loss: 0.5879 - val_iou_score: 0.4673 - val_f1-score: 0.5455
# Epoch 54/100
# 5/5 [==============================] - 4s 883ms/step - loss: 0.2838 - iou_score: 0.7670 - f1-score: 0.8680 - val_loss: 0.5962 - val_iou_score: 0.4576 - val_f1-score: 0.5258
# Epoch 55/100
# 5/5 [==============================] - 4s 882ms/step - loss: 0.2907 - iou_score: 0.7576 - f1-score: 0.8619 - val_loss: 0.5701 - val_iou_score: 0.4878 - val_f1-score: 0.5746
# Epoch 56/100
# 5/5 [==============================] - 4s 880ms/step - loss: 0.3029 - iou_score: 0.7384 - f1-score: 0.8488 - val_loss: 0.5725 - val_iou_score: 0.4746 - val_f1-score: 0.5492
# Epoch 57/100
# 5/5 [==============================] - 4s 883ms/step - loss: 0.2699 - iou_score: 0.7701 - f1-score: 0.8699 - val_loss: 0.5499 - val_iou_score: 0.5007 - val_f1-score: 0.5882
# Epoch 58/100
# 5/5 [==============================] - 4s 881ms/step - loss: 0.3038 - iou_score: 0.7520 - f1-score: 0.8583 - val_loss: 0.5511 - val_iou_score: 0.5083 - val_f1-score: 0.6069
# Epoch 59/100
# 5/5 [==============================] - 4s 887ms/step - loss: 0.2722 - iou_score: 0.7712 - f1-score: 0.8703 - val_loss: 0.5546 - val_iou_score: 0.4952 - val_f1-score: 0.5807
# Epoch 60/100
# 5/5 [==============================] - 4s 880ms/step - loss: 0.2773 - iou_score: 0.7706 - f1-score: 0.8703 - val_loss: 0.5491 - val_iou_score: 0.4937 - val_f1-score: 0.5794
# Epoch 61/100
# 5/5 [==============================] - 4s 882ms/step - loss: 0.2687 - iou_score: 0.7805 - f1-score: 0.8766 - val_loss: 0.5453 - val_iou_score: 0.5070 - val_f1-score: 0.6014
# Epoch 62/100
# 5/5 [==============================] - 4s 876ms/step - loss: 0.2603 - iou_score: 0.7899 - f1-score: 0.8826 - val_loss: 0.5441 - val_iou_score: 0.4990 - val_f1-score: 0.5824
# Epoch 63/100
# 5/5 [==============================] - 4s 879ms/step - loss: 0.2786 - iou_score: 0.7546 - f1-score: 0.8594 - val_loss: 0.5611 - val_iou_score: 0.4832 - val_f1-score: 0.5542
# Epoch 64/100
# 5/5 [==============================] - 4s 880ms/step - loss: 0.2634 - iou_score: 0.7805 - f1-score: 0.8766 - val_loss: 0.5426 - val_iou_score: 0.4951 - val_f1-score: 0.5686
# Epoch 65/100
# 5/5 [==============================] - 4s 877ms/step - loss: 0.2919 - iou_score: 0.7601 - f1-score: 0.8632 - val_loss: 0.5362 - val_iou_score: 0.4944 - val_f1-score: 0.5678
# Epoch 66/100
# 5/5 [==============================] - 4s 873ms/step - loss: 0.2674 - iou_score: 0.7679 - f1-score: 0.8680 - val_loss: 0.5274 - val_iou_score: 0.5084 - val_f1-score: 0.5878
# Epoch 67/100
# 5/5 [==============================] - 4s 886ms/step - loss: 0.2474 - iou_score: 0.7849 - f1-score: 0.8788 - val_loss: 0.5379 - val_iou_score: 0.4909 - val_f1-score: 0.5607
# Epoch 68/100
# 5/5 [==============================] - 4s 877ms/step - loss: 0.2675 - iou_score: 0.7799 - f1-score: 0.8761 - val_loss: 0.5418 - val_iou_score: 0.5051 - val_f1-score: 0.5899
# Epoch 69/100
# 5/5 [==============================] - 4s 878ms/step - loss: 0.2626 - iou_score: 0.7738 - f1-score: 0.8721 - val_loss: 0.5137 - val_iou_score: 0.5233 - val_f1-score: 0.6137
# Epoch 70/100
# 5/5 [==============================] - 4s 885ms/step - loss: 0.2853 - iou_score: 0.7638 - f1-score: 0.8658 - val_loss: 0.5030 - val_iou_score: 0.5251 - val_f1-score: 0.6076
# Epoch 71/100
# 5/5 [==============================] - 4s 882ms/step - loss: 0.2635 - iou_score: 0.7605 - f1-score: 0.8631 - val_loss: 0.4948 - val_iou_score: 0.5397 - val_f1-score: 0.6241
# Epoch 72/100
# 5/5 [==============================] - 4s 884ms/step - loss: 0.2699 - iou_score: 0.7662 - f1-score: 0.8676 - val_loss: 0.5053 - val_iou_score: 0.5199 - val_f1-score: 0.5951
# Epoch 73/100
# 5/5 [==============================] - 4s 887ms/step - loss: 0.2589 - iou_score: 0.7762 - f1-score: 0.8736 - val_loss: 0.4906 - val_iou_score: 0.5437 - val_f1-score: 0.6308
# Epoch 74/100
# 5/5 [==============================] - 4s 882ms/step - loss: 0.2726 - iou_score: 0.7721 - f1-score: 0.8713 - val_loss: 0.5004 - val_iou_score: 0.5272 - val_f1-score: 0.6111
# Epoch 75/100
# 5/5 [==============================] - 4s 881ms/step - loss: 0.2517 - iou_score: 0.7808 - f1-score: 0.8756 - val_loss: 0.5313 - val_iou_score: 0.4873 - val_f1-score: 0.5585
# Epoch 76/100
# 5/5 [==============================] - 4s 881ms/step - loss: 0.2741 - iou_score: 0.7628 - f1-score: 0.8651 - val_loss: 0.5623 - val_iou_score: 0.4615 - val_f1-score: 0.5253
# Epoch 77/100
# 5/5 [==============================] - 4s 872ms/step - loss: 0.2434 - iou_score: 0.7974 - f1-score: 0.8872 - val_loss: 0.4853 - val_iou_score: 0.5372 - val_f1-score: 0.6220
# Epoch 78/100
# 5/5 [==============================] - 4s 879ms/step - loss: 0.2458 - iou_score: 0.7984 - f1-score: 0.8878 - val_loss: 0.4844 - val_iou_score: 0.5568 - val_f1-score: 0.6485
# Epoch 79/100
# 5/5 [==============================] - 4s 880ms/step - loss: 0.2678 - iou_score: 0.7602 - f1-score: 0.8637 - val_loss: 0.5360 - val_iou_score: 0.4745 - val_f1-score: 0.5456
# Epoch 80/100
# 5/5 [==============================] - 4s 883ms/step - loss: 0.2658 - iou_score: 0.7733 - f1-score: 0.8719 - val_loss: 0.4986 - val_iou_score: 0.5216 - val_f1-score: 0.6030
# Epoch 81/100
# 5/5 [==============================] - 4s 872ms/step - loss: 0.2628 - iou_score: 0.7754 - f1-score: 0.8731 - val_loss: 0.5041 - val_iou_score: 0.5173 - val_f1-score: 0.5960
# Epoch 82/100
# 5/5 [==============================] - 4s 880ms/step - loss: 0.2389 - iou_score: 0.7919 - f1-score: 0.8838 - val_loss: 0.4892 - val_iou_score: 0.5478 - val_f1-score: 0.6378
# Epoch 83/100
# 5/5 [==============================] - 4s 874ms/step - loss: 0.2738 - iou_score: 0.7683 - f1-score: 0.8688 - val_loss: 0.4878 - val_iou_score: 0.5545 - val_f1-score: 0.6464
# Epoch 84/100
# 5/5 [==============================] - 4s 873ms/step - loss: 0.2785 - iou_score: 0.7583 - f1-score: 0.8613 - val_loss: 0.4904 - val_iou_score: 0.5563 - val_f1-score: 0.6474
# Epoch 85/100
# 5/5 [==============================] - 4s 876ms/step - loss: 0.2330 - iou_score: 0.7992 - f1-score: 0.8880 - val_loss: 0.4989 - val_iou_score: 0.5293 - val_f1-score: 0.6156
# Epoch 86/100
# 5/5 [==============================] - 4s 877ms/step - loss: 0.2532 - iou_score: 0.7793 - f1-score: 0.8758 - val_loss: 0.5040 - val_iou_score: 0.5181 - val_f1-score: 0.5999
# Epoch 87/100
# 5/5 [==============================] - 4s 880ms/step - loss: 0.2682 - iou_score: 0.7805 - f1-score: 0.8764 - val_loss: 0.4937 - val_iou_score: 0.5328 - val_f1-score: 0.6194
# Epoch 88/100
# 5/5 [==============================] - 4s 877ms/step - loss: 0.2589 - iou_score: 0.7789 - f1-score: 0.8754 - val_loss: 0.4798 - val_iou_score: 0.5595 - val_f1-score: 0.6505
# Epoch 89/100
# 5/5 [==============================] - 4s 879ms/step - loss: 0.2461 - iou_score: 0.7869 - f1-score: 0.8803 - val_loss: 0.4748 - val_iou_score: 0.5584 - val_f1-score: 0.6479
# Epoch 90/100
# 5/5 [==============================] - 4s 873ms/step - loss: 0.2587 - iou_score: 0.7747 - f1-score: 0.8725 - val_loss: 0.4839 - val_iou_score: 0.5460 - val_f1-score: 0.6317
# Epoch 91/100
# 5/5 [==============================] - 4s 887ms/step - loss: 0.2180 - iou_score: 0.8060 - f1-score: 0.8926 - val_loss: 0.4878 - val_iou_score: 0.5375 - val_f1-score: 0.6233
# Epoch 92/100
# 5/5 [==============================] - 4s 871ms/step - loss: 0.2279 - iou_score: 0.8094 - f1-score: 0.8946 - val_loss: 0.4817 - val_iou_score: 0.5496 - val_f1-score: 0.6374
# Epoch 93/100
# 5/5 [==============================] - 4s 878ms/step - loss: 0.2450 - iou_score: 0.7825 - f1-score: 0.8777 - val_loss: 0.4749 - val_iou_score: 0.5578 - val_f1-score: 0.6465
# Epoch 94/100
# 5/5 [==============================] - 4s 869ms/step - loss: 0.2257 - iou_score: 0.8050 - f1-score: 0.8916 - val_loss: 0.4806 - val_iou_score: 0.5531 - val_f1-score: 0.6384
# Epoch 95/100
# 5/5 [==============================] - 4s 883ms/step - loss: 0.2302 - iou_score: 0.8017 - f1-score: 0.8899 - val_loss: 0.4674 - val_iou_score: 0.5678 - val_f1-score: 0.6611
# Epoch 96/100
# 5/5 [==============================] - 4s 883ms/step - loss: 0.2395 - iou_score: 0.7869 - f1-score: 0.8800 - val_loss: 0.4756 - val_iou_score: 0.5583 - val_f1-score: 0.6488
# Epoch 97/100
# 5/5 [==============================] - 4s 877ms/step - loss: 0.2416 - iou_score: 0.7942 - f1-score: 0.8851 - val_loss: 0.4656 - val_iou_score: 0.5690 - val_f1-score: 0.6636
# Epoch 98/100
# 5/5 [==============================] - 4s 882ms/step - loss: 0.2653 - iou_score: 0.7767 - f1-score: 0.8736 - val_loss: 0.4707 - val_iou_score: 0.5698 - val_f1-score: 0.6604
# Epoch 99/100
# 5/5 [==============================] - 4s 879ms/step - loss: 0.2466 - iou_score: 0.7798 - f1-score: 0.8760 - val_loss: 0.4995 - val_iou_score: 0.5223 - val_f1-score: 0.6041
# Epoch 100/100
# 5/5 [==============================] - 4s 879ms/step - loss: 0.2229 - iou_score: 0.8070 - f1-score: 0.8931 - val_loss: 0.4768 - val_iou_score: 0.5554 - val_f1-score: 0.6393
